# %% [markdown]
# ## PREDICTION EXPANDING TOTALPOWER

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 

import requests
# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

# >>> initial_trend(series, 12)
# -0.7847222222222222

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT total_watt FROM thesis.load WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
#     print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)

def notify(msg):
    URL = "https://notify-api.line.me/api/notify"
    ACCESS_TOKEN = "vxm278yAqFQcXbo2DlTbLD7pqO0QWU2McdNbiwhJWwp"
    MESSAGE_FIELD = {"message" : msg}
    LINE_HEADERS = { "Authorization": "Bearer " + ACCESS_TOKEN }
    try:
        response = requests.post( url=URL,headers=LINE_HEADERS,data=MESSAGE_FIELD)
#         print("Response HTTP Status Code: {status_code}".format( status_code=response.status_code))
    except requests.exceptions.RequestException:
        print("HTTP Request failed")

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp, total_watt FROM thesis.load WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2016-09-01 00:14:59","2016-11-30 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = 31
day =0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

time_a_last = pd.date_range('2016-09-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-09-30 23:44:59', periods=96*d, freq='15T')

# set databases to empty 
query_empty = """truncate table thesis.predict2""" 
c.execute(query_empty)

while (j < 96*d ) :    
    if (j%96 == 0):    
        day += 1
        print "________DAY:" , day
    
    print "\ndata at :" , j,">>>", time_b[j]
    query_last = "SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a_last[j],time_b_last[j])
    print query_last
    df = pd.read_sql(query_last, conn)
    conn.commit()
    data_y = df['total_watt'].values.tolist()
    ans_fiting = fittingparameter(data_y,j)
    
    query_last_new = "SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
    query_last_new_1 = "SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
    print "\n",query_last_new  
    print query_last_new_1
    print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
    df_last_new = pd.read_sql(query_last_new, conn)
    conn.commit()
    
    data_y = df_last_new['total_watt'].values.tolist()     
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]   
    pred_watt = abs(pred_data[0])

    c.execute("INSERT INTO thesis.predict2 (Timestamp, watt) VALUES ( %s, %s)",(time_b[j],abs(pred_data[0])))
    conn.commit()  
    
    if ( j == 0 or j == 500 or j == 1000 or j == 1500 or j == 2000 or j == 2500 or j == 2880):
        notify("moving")  
        notify(j)  
            
    j += 1 
print "DONE!!"
# Out:
# ________DAY: 1
#
# data at : 0 >>> 2016-10-01 00:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-09-30 23:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-09-30 23:59:59' ;
# 0.00308141136391 0.8 0.4 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-09-30 23:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:14:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.4
#
# data at : 1 >>> 2016-10-01 00:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:29:59'   AND TimeStamp <= '2016-09-30 23:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:14:59' ;
# 0.0239772336216 0.4 0.1 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:29:59'AND Timestamp<='2016-10-01 00:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:29:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.9
#
# data at : 2 >>> 2016-10-01 00:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:44:59'   AND TimeStamp <= '2016-10-01 00:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:29:59' ;
# 9.68788266719e-05 0.7 0.1 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:44:59'AND Timestamp<='2016-10-01 00:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:44:59' ;
# BY USE alpha = 0.7 beta = 0.1 gamma = 0.0
#
# data at : 3 >>> 2016-10-01 00:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:59:59'   AND TimeStamp <= '2016-10-01 00:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:44:59' ;
# 0.0805943028151 0.1 0.2 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:59:59'AND Timestamp<='2016-10-01 00:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:59:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.7
#
# data at : 4 >>> 2016-10-01 01:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 01:14:59'   AND TimeStamp <= '2016-10-01 00:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:59:59' ;
# 0.00380961873074 0.4 0.3 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 01:14:59'AND Timestamp<='2016-10-01 00:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:14:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.0
#
# data at : 5 >>> 2016-10-01 01:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 01:29:59'   AND TimeStamp <= '2016-10-01 00:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:14:59' ;
# 0.044256732218 0.2 0.4 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 01:29:59'AND Timestamp<='2016-10-01 01:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:29:59' ;
# BY USE alpha = 0.2 beta = 0.4 gamma = 0.7
#
# data at : 6 >>> 2016-10-01 01:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 01:44:59'   AND TimeStamp <= '2016-10-01 01:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:29:59' ;
# 0.111730496592 0.3 0.4 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 01:44:59'AND Timestamp<='2016-10-01 01:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:44:59' ;
# BY USE alpha = 0.3 beta = 0.4 gamma = 0.8
#
# data at : 7 >>> 2016-10-01 01:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 01:59:59'   AND TimeStamp <= '2016-10-01 01:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:44:59' ;
# 0.103123664303 0.4 0.5 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 01:59:59'AND Timestamp<='2016-10-01 01:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:59:59' ;
# BY USE alpha = 0.4 beta = 0.5 gamma = 0.9
#
# data at : 8 >>> 2016-10-01 02:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 02:14:59'   AND TimeStamp <= '2016-10-01 01:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:59:59' ;
# 0.130324445018 0.3 1.0 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 02:14:59'AND Timestamp<='2016-10-01 01:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:14:59' ;
# BY USE alpha = 0.3 beta = 1.0 gamma = 0.5
#
# data at : 9 >>> 2016-10-01 02:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 02:29:59'   AND TimeStamp <= '2016-10-01 01:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:14:59' ;
# 0.00538887021869 0.2 0.5 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 02:29:59'AND Timestamp<='2016-10-01 02:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:29:59' ;
# BY USE alpha = 0.2 beta = 0.5 gamma = 0.3
#
# data at : 10 >>> 2016-10-01 02:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 02:44:59'   AND TimeStamp <= '2016-10-01 02:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:29:59' ;
# 9.98211832008e-05 0.3 0.7 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 02:44:59'AND Timestamp<='2016-10-01 02:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:44:59' ;
# BY USE alpha = 0.3 beta = 0.7 gamma = 0.0
#
# data at : 11 >>> 2016-10-01 02:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 02:59:59'   AND TimeStamp <= '2016-10-01 02:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:44:59' ;
# 4.89586774182 0.3 0.5 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 02:59:59'AND Timestamp<='2016-10-01 02:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:59:59' ;
# BY USE alpha = 0.3 beta = 0.5 gamma = 0.6
#
# data at : 12 >>> 2016-10-01 03:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 03:14:59'   AND TimeStamp <= '2016-10-01 02:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:59:59' ;
# 0.0657431224445 0.2 0.9 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 03:14:59'AND Timestamp<='2016-10-01 02:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:14:59' ;
# BY USE alpha = 0.2 beta = 0.9 gamma = 0.1
#
# data at : 13 >>> 2016-10-01 03:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 03:29:59'   AND TimeStamp <= '2016-10-01 02:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:14:59' ;
# 0.000514641201705 0.7 0.7 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 03:29:59'AND Timestamp<='2016-10-01 03:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:29:59' ;
# BY USE alpha = 0.7 beta = 0.7 gamma = 0.1
#
# data at : 14 >>> 2016-10-01 03:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 03:44:59'   AND TimeStamp <= '2016-10-01 03:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:29:59' ;
# 0.0093308802464 0.1 0.8 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 03:44:59'AND Timestamp<='2016-10-01 03:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:44:59' ;
# BY USE alpha = 0.1 beta = 0.8 gamma = 0.3
#
# data at : 15 >>> 2016-10-01 03:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 03:59:59'   AND TimeStamp <= '2016-10-01 03:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:44:59' ;
# 0.004298673865 0.7 0.5 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 03:59:59'AND Timestamp<='2016-10-01 03:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:59:59' ;
# BY USE alpha = 0.7 beta = 0.5 gamma = 1.0
#
# data at : 16 >>> 2016-10-01 04:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 04:14:59'   AND TimeStamp <= '2016-10-01 03:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:59:59' ;
# 0.0502573150213 0.3 0.2 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 04:14:59'AND Timestamp<='2016-10-01 03:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:14:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.9
#
# data at : 17 >>> 2016-10-01 04:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 04:29:59'   AND TimeStamp <= '2016-10-01 03:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:14:59' ;
# 0.000517306654194 0.6 0.7 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 04:29:59'AND Timestamp<='2016-10-01 04:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:29:59' ;
# BY USE alpha = 0.6 beta = 0.7 gamma = 0.2
#
# data at : 18 >>> 2016-10-01 04:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 04:44:59'   AND TimeStamp <= '2016-10-01 04:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:29:59' ;
# 0.0134819975188 0.4 1.0 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 04:44:59'AND Timestamp<='2016-10-01 04:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:44:59' ;
# BY USE alpha = 0.4 beta = 1.0 gamma = 0.5
#
# data at : 19 >>> 2016-10-01 04:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 04:59:59'   AND TimeStamp <= '2016-10-01 04:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:44:59' ;
# 0.0192292364566 0.9 0.9 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 04:59:59'AND Timestamp<='2016-10-01 04:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:59:59' ;
# BY USE alpha = 0.9 beta = 0.9 gamma = 0.8
#
# data at : 20 >>> 2016-10-01 05:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 05:14:59'   AND TimeStamp <= '2016-10-01 04:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:59:59' ;
# 0.00599524166028 0.9 0.4 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 05:14:59'AND Timestamp<='2016-10-01 04:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:14:59' ;
# BY USE alpha = 0.9 beta = 0.4 gamma = 0.1
#
# data at : 21 >>> 2016-10-01 05:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 05:29:59'   AND TimeStamp <= '2016-10-01 04:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:14:59' ;
# 7.97415485022e-05 0.4 0.6 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 05:29:59'AND Timestamp<='2016-10-01 05:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:29:59' ;
# BY USE alpha = 0.4 beta = 0.6 gamma = 0.2
#
# data at : 22 >>> 2016-10-01 05:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 05:44:59'   AND TimeStamp <= '2016-10-01 05:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:29:59' ;
# 0.00892001865855 0.4 0.7 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 05:44:59'AND Timestamp<='2016-10-01 05:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:44:59' ;
# BY USE alpha = 0.4 beta = 0.7 gamma = 0.7
#
# data at : 23 >>> 2016-10-01 05:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 05:59:59'   AND TimeStamp <= '2016-10-01 05:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:44:59' ;
# 1.17874044954e-06 0.8 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 05:59:59'AND Timestamp<='2016-10-01 05:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:59:59' ;
# BY USE alpha = 0.8 beta = 0.2 gamma = 0.4
#
# data at : 24 >>> 2016-10-01 06:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 06:14:59'   AND TimeStamp <= '2016-10-01 05:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:59:59' ;
# 0.000259430244688 0.7 0.0 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 06:14:59'AND Timestamp<='2016-10-01 05:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:14:59' ;
# BY USE alpha = 0.7 beta = 0.0 gamma = 0.6
#
# data at : 25 >>> 2016-10-01 06:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 06:29:59'   AND TimeStamp <= '2016-10-01 05:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:14:59' ;
# 1.38832084297 0.1 0.4 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 06:29:59'AND Timestamp<='2016-10-01 06:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:29:59' ;
# BY USE alpha = 0.1 beta = 0.4 gamma = 0.4
#
# data at : 26 >>> 2016-10-01 06:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 06:44:59'   AND TimeStamp <= '2016-10-01 06:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:29:59' ;
# 0.00136225318752 0.8 0.5 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 06:44:59'AND Timestamp<='2016-10-01 06:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:44:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.7
#
# data at : 27 >>> 2016-10-01 06:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 06:59:59'   AND TimeStamp <= '2016-10-01 06:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:44:59' ;
# 0.00553265693453 0.0 0.0 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 06:59:59'AND Timestamp<='2016-10-01 06:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:59:59' ;
# BY USE alpha = 0.0 beta = 0.0 gamma = 0.5
#
# data at : 28 >>> 2016-10-01 07:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 07:14:59'   AND TimeStamp <= '2016-10-01 06:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:59:59' ;
# 7.82860652018e-05 0.8 0.2 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 07:14:59'AND Timestamp<='2016-10-01 06:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:14:59' ;
# BY USE alpha = 0.8 beta = 0.2 gamma = 0.8
#
# data at : 29 >>> 2016-10-01 07:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 07:29:59'   AND TimeStamp <= '2016-10-01 06:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:14:59' ;
# 0.000337140157083 0.5 0.9 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 07:29:59'AND Timestamp<='2016-10-01 07:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:29:59' ;
# BY USE alpha = 0.5 beta = 0.9 gamma = 0.6
#
# data at : 30 >>> 2016-10-01 07:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 07:44:59'   AND TimeStamp <= '2016-10-01 07:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:29:59' ;
# 0.00346886271035 0.4 0.2 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 07:44:59'AND Timestamp<='2016-10-01 07:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:44:59' ;
# BY USE alpha = 0.4 beta = 0.2 gamma = 0.7
#
# data at : 31 >>> 2016-10-01 07:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 07:59:59'   AND TimeStamp <= '2016-10-01 07:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:44:59' ;
# 0.00101224453209 0.9 0.5 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 07:59:59'AND Timestamp<='2016-10-01 07:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:59:59' ;
# BY USE alpha = 0.9 beta = 0.5 gamma = 1.0
#
# data at : 32 >>> 2016-10-01 08:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 08:14:59'   AND TimeStamp <= '2016-10-01 07:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:59:59' ;
# 0.00163530557245 0.9 0.7 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 08:14:59'AND Timestamp<='2016-10-01 07:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:14:59' ;
# BY USE alpha = 0.9 beta = 0.7 gamma = 0.8
#
# data at : 33 >>> 2016-10-01 08:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 08:29:59'   AND TimeStamp <= '2016-10-01 07:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:14:59' ;
# 2.77646529439e-05 0.8 0.4 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 08:29:59'AND Timestamp<='2016-10-01 08:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:29:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.6
#
# data at : 34 >>> 2016-10-01 08:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 08:44:59'   AND TimeStamp <= '2016-10-01 08:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:29:59' ;
# 2.08518593433e-05 0.4 0.6 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 08:44:59'AND Timestamp<='2016-10-01 08:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:44:59' ;
# BY USE alpha = 0.4 beta = 0.6 gamma = 0.4
#
# data at : 35 >>> 2016-10-01 08:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 08:59:59'   AND TimeStamp <= '2016-10-01 08:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:44:59' ;
# 0.0783206999225 0.3 0.7 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 08:59:59'AND Timestamp<='2016-10-01 08:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:59:59' ;
# BY USE alpha = 0.3 beta = 0.7 gamma = 1.0
#
# data at : 36 >>> 2016-10-01 09:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 09:14:59'   AND TimeStamp <= '2016-10-01 08:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:59:59' ;
# 0.165707366849 0.1 0.8 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 09:14:59'AND Timestamp<='2016-10-01 08:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:14:59' ;
# BY USE alpha = 0.1 beta = 0.8 gamma = 0.4
#
# data at : 37 >>> 2016-10-01 09:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 09:29:59'   AND TimeStamp <= '2016-10-01 08:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:14:59' ;
# 0.000465739554605 0.7 0.8 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 09:29:59'AND Timestamp<='2016-10-01 09:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:29:59' ;
# BY USE alpha = 0.7 beta = 0.8 gamma = 0.1
#
# data at : 38 >>> 2016-10-01 09:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 09:44:59'   AND TimeStamp <= '2016-10-01 09:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:29:59' ;
# 0.0169706518701 0.3 0.1 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 09:44:59'AND Timestamp<='2016-10-01 09:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:44:59' ;
# BY USE alpha = 0.3 beta = 0.1 gamma = 0.8
#
# data at : 39 >>> 2016-10-01 09:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 09:59:59'   AND TimeStamp <= '2016-10-01 09:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:44:59' ;
# 1161.82878073 0.2 0.9 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 09:59:59'AND Timestamp<='2016-10-01 09:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:59:59' ;
# BY USE alpha = 0.2 beta = 0.9 gamma = 0.7
#
# data at : 40 >>> 2016-10-01 10:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 10:14:59'   AND TimeStamp <= '2016-10-01 09:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:59:59' ;
# 0.580470793686 0.4 0.2 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 10:14:59'AND Timestamp<='2016-10-01 09:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:14:59' ;
# BY USE alpha = 0.4 beta = 0.2 gamma = 0.2
#
# data at : 41 >>> 2016-10-01 10:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 10:29:59'   AND TimeStamp <= '2016-10-01 09:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:14:59' ;
# 1.88300731469 0.0 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 10:29:59'AND Timestamp<='2016-10-01 10:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:29:59' ;
# BY USE alpha = 0.0 beta = 0.2 gamma = 0.4
#
# data at : 42 >>> 2016-10-01 10:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 10:44:59'   AND TimeStamp <= '2016-10-01 10:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:29:59' ;
# 0.00155096851072 0.9 0.3 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 10:44:59'AND Timestamp<='2016-10-01 10:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:44:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.7
#
# data at : 43 >>> 2016-10-01 10:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 10:59:59'   AND TimeStamp <= '2016-10-01 10:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:44:59' ;
# 0.000216882752947 0.4 0.8 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 10:59:59'AND Timestamp<='2016-10-01 10:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:59:59' ;
# BY USE alpha = 0.4 beta = 0.8 gamma = 1.0
#
# data at : 44 >>> 2016-10-01 11:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 11:14:59'   AND TimeStamp <= '2016-10-01 10:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:59:59' ;
# 0.00174418887912 0.4 0.3 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 11:14:59'AND Timestamp<='2016-10-01 10:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:14:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.8
#
# data at : 45 >>> 2016-10-01 11:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 11:29:59'   AND TimeStamp <= '2016-10-01 10:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:14:59' ;
# 5.05947198509e-06 0.7 0.1 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 11:29:59'AND Timestamp<='2016-10-01 11:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:29:59' ;
# BY USE alpha = 0.7 beta = 0.1 gamma = 0.8
#
# data at : 46 >>> 2016-10-01 11:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 11:44:59'   AND TimeStamp <= '2016-10-01 11:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:29:59' ;
# 0.00645532380632 0.6 0.2 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 11:44:59'AND Timestamp<='2016-10-01 11:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:44:59' ;
# BY USE alpha = 0.6 beta = 0.2 gamma = 0.6
#
# data at : 47 >>> 2016-10-01 11:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 11:59:59'   AND TimeStamp <= '2016-10-01 11:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:44:59' ;
# 0.00684536304092 0.6 0.0 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 11:59:59'AND Timestamp<='2016-10-01 11:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:59:59' ;
# BY USE alpha = 0.6 beta = 0.0 gamma = 0.7
#
# data at : 48 >>> 2016-10-01 12:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 12:14:59'   AND TimeStamp <= '2016-10-01 11:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:59:59' ;
# 0.000269861208591 0.3 0.2 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 12:14:59'AND Timestamp<='2016-10-01 11:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:14:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.8
#
# data at : 49 >>> 2016-10-01 12:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 12:29:59'   AND TimeStamp <= '2016-10-01 11:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:14:59' ;
# 0.00592211938488 0.6 0.4 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 12:29:59'AND Timestamp<='2016-10-01 12:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:29:59' ;
# BY USE alpha = 0.6 beta = 0.4 gamma = 0.6
#
# data at : 50 >>> 2016-10-01 12:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 12:44:59'   AND TimeStamp <= '2016-10-01 12:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:29:59' ;
# 2.10656806468e-05 0.3 0.2 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 12:44:59'AND Timestamp<='2016-10-01 12:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:44:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.2
#
# data at : 51 >>> 2016-10-01 12:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 12:59:59'   AND TimeStamp <= '2016-10-01 12:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:44:59' ;
# 0.0427725107327 0.4 0.9 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 12:59:59'AND Timestamp<='2016-10-01 12:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:59:59' ;
# BY USE alpha = 0.4 beta = 0.9 gamma = 0.5
#
# data at : 52 >>> 2016-10-01 13:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 13:14:59'   AND TimeStamp <= '2016-10-01 12:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:59:59' ;
# 0.000151989589817 0.8 0.5 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 13:14:59'AND Timestamp<='2016-10-01 12:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:14:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.5
#
# data at : 53 >>> 2016-10-01 13:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 13:29:59'   AND TimeStamp <= '2016-10-01 12:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:14:59' ;
# 0.173191067352 0.5 0.7 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 13:29:59'AND Timestamp<='2016-10-01 13:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:29:59' ;
# BY USE alpha = 0.5 beta = 0.7 gamma = 0.7
#
# data at : 54 >>> 2016-10-01 13:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 13:44:59'   AND TimeStamp <= '2016-10-01 13:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:29:59' ;
# 4.24113219571e-05 0.2 0.1 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 13:44:59'AND Timestamp<='2016-10-01 13:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:44:59' ;
# BY USE alpha = 0.2 beta = 0.1 gamma = 1.0
#
# data at : 55 >>> 2016-10-01 13:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 13:59:59'   AND TimeStamp <= '2016-10-01 13:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:44:59' ;
# 0.000584621491624 0.9 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 13:59:59'AND Timestamp<='2016-10-01 13:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:59:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.9
#
# data at : 56 >>> 2016-10-01 14:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 14:14:59'   AND TimeStamp <= '2016-10-01 13:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:59:59' ;
# 0.000464769123521 0.4 0.4 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 14:14:59'AND Timestamp<='2016-10-01 13:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:14:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 0.1
#
# data at : 57 >>> 2016-10-01 14:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 14:29:59'   AND TimeStamp <= '2016-10-01 13:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:14:59' ;
# 0.00069786575388 0.7 0.7 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 14:29:59'AND Timestamp<='2016-10-01 14:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:29:59' ;
# BY USE alpha = 0.7 beta = 0.7 gamma = 0.5
#
# data at : 58 >>> 2016-10-01 14:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 14:44:59'   AND TimeStamp <= '2016-10-01 14:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:29:59' ;
# 0.016979174126 0.8 1.0 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 14:44:59'AND Timestamp<='2016-10-01 14:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:44:59' ;
# BY USE alpha = 0.8 beta = 1.0 gamma = 0.3
#
# data at : 59 >>> 2016-10-01 14:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 14:59:59'   AND TimeStamp <= '2016-10-01 14:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:44:59' ;
# 0.00124261310684 0.6 0.8 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 14:59:59'AND Timestamp<='2016-10-01 14:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:59:59' ;
# BY USE alpha = 0.6 beta = 0.8 gamma = 1.0
#
# data at : 60 >>> 2016-10-01 15:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 15:14:59'   AND TimeStamp <= '2016-10-01 14:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:59:59' ;
# 0.014592925781 0.4 0.7 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 15:14:59'AND Timestamp<='2016-10-01 14:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:14:59' ;
# BY USE alpha = 0.4 beta = 0.7 gamma = 0.6
#
# data at : 61 >>> 2016-10-01 15:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 15:29:59'   AND TimeStamp <= '2016-10-01 14:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:14:59' ;
# 0.00447809439147 0.1 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 15:29:59'AND Timestamp<='2016-10-01 15:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:29:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.4
#
# data at : 62 >>> 2016-10-01 15:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 15:44:59'   AND TimeStamp <= '2016-10-01 15:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:29:59' ;
# 0.000429689669554 0.7 0.6 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 15:44:59'AND Timestamp<='2016-10-01 15:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:44:59' ;
# BY USE alpha = 0.7 beta = 0.6 gamma = 0.6
#
# data at : 63 >>> 2016-10-01 15:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 15:59:59'   AND TimeStamp <= '2016-10-01 15:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:44:59' ;
# 0.0499056206818 0.7 0.0 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 15:59:59'AND Timestamp<='2016-10-01 15:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:59:59' ;
# BY USE alpha = 0.7 beta = 0.0 gamma = 0.9
#
# data at : 64 >>> 2016-10-01 16:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 16:14:59'   AND TimeStamp <= '2016-10-01 15:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:59:59' ;
# 0.000845417669601 0.1 0.0 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 16:14:59'AND Timestamp<='2016-10-01 15:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:14:59' ;
# BY USE alpha = 0.1 beta = 0.0 gamma = 0.7
#
# data at : 65 >>> 2016-10-01 16:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 16:29:59'   AND TimeStamp <= '2016-10-01 15:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:14:59' ;
# 0.000273544868526 0.3 0.4 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 16:29:59'AND Timestamp<='2016-10-01 16:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:29:59' ;
# BY USE alpha = 0.3 beta = 0.4 gamma = 0.6
#
# data at : 66 >>> 2016-10-01 16:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 16:44:59'   AND TimeStamp <= '2016-10-01 16:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:29:59' ;
# 0.00121255056545 0.9 0.3 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 16:44:59'AND Timestamp<='2016-10-01 16:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:44:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.7
#
# data at : 67 >>> 2016-10-01 16:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 16:59:59'   AND TimeStamp <= '2016-10-01 16:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:44:59' ;
# 5.04967773896e-06 0.6 0.5 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 16:59:59'AND Timestamp<='2016-10-01 16:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:59:59' ;
# BY USE alpha = 0.6 beta = 0.5 gamma = 0.3
#
# data at : 68 >>> 2016-10-01 17:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 17:14:59'   AND TimeStamp <= '2016-10-01 16:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:59:59' ;
# 0.000150430150972 0.9 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 17:14:59'AND Timestamp<='2016-10-01 16:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:14:59' ;
# BY USE alpha = 0.9 beta = 0.2 gamma = 0.4
#
# data at : 69 >>> 2016-10-01 17:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 17:29:59'   AND TimeStamp <= '2016-10-01 16:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:14:59' ;
# 3.94997434014e-05 0.8 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 17:29:59'AND Timestamp<='2016-10-01 17:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:29:59' ;
# BY USE alpha = 0.8 beta = 0.3 gamma = 0.9
#
# data at : 70 >>> 2016-10-01 17:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 17:44:59'   AND TimeStamp <= '2016-10-01 17:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:29:59' ;
# 0.000350166619077 0.5 0.2 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 17:44:59'AND Timestamp<='2016-10-01 17:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:44:59' ;
# BY USE alpha = 0.5 beta = 0.2 gamma = 0.9
#
# data at : 71 >>> 2016-10-01 17:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 17:59:59'   AND TimeStamp <= '2016-10-01 17:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:44:59' ;
# 0.361700916069 0.1 0.4 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 17:59:59'AND Timestamp<='2016-10-01 17:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:59:59' ;
# BY USE alpha = 0.1 beta = 0.4 gamma = 0.4
#
# data at : 72 >>> 2016-10-01 18:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 18:14:59'   AND TimeStamp <= '2016-10-01 17:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:59:59' ;
# 0.000157457907666 0.2 0.6 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 18:14:59'AND Timestamp<='2016-10-01 17:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:14:59' ;
# BY USE alpha = 0.2 beta = 0.6 gamma = 0.6
#
# data at : 73 >>> 2016-10-01 18:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 18:29:59'   AND TimeStamp <= '2016-10-01 17:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:14:59' ;
# 0.235429840863 0.3 0.6 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 18:29:59'AND Timestamp<='2016-10-01 18:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:29:59' ;
# BY USE alpha = 0.3 beta = 0.6 gamma = 1.0
#
# data at : 74 >>> 2016-10-01 18:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 18:44:59'   AND TimeStamp <= '2016-10-01 18:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:29:59' ;
# 154.582383121 0.1 0.6 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 18:44:59'AND Timestamp<='2016-10-01 18:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:44:59' ;
# BY USE alpha = 0.1 beta = 0.6 gamma = 0.8
#
# data at : 75 >>> 2016-10-01 18:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 18:59:59'   AND TimeStamp <= '2016-10-01 18:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:44:59' ;
# 0.000284070394307 0.8 0.2 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 18:59:59'AND Timestamp<='2016-10-01 18:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:59:59' ;
# BY USE alpha = 0.8 beta = 0.2 gamma = 0.7
#
# data at : 76 >>> 2016-10-01 19:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 19:14:59'   AND TimeStamp <= '2016-10-01 18:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:59:59' ;
# 0.00027816355834 0.1 0.9 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 19:14:59'AND Timestamp<='2016-10-01 18:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:14:59' ;
# BY USE alpha = 0.1 beta = 0.9 gamma = 0.2
#
# data at : 77 >>> 2016-10-01 19:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 19:29:59'   AND TimeStamp <= '2016-10-01 18:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:14:59' ;
# 0.163135209999 0.0 0.0 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 19:29:59'AND Timestamp<='2016-10-01 19:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:29:59' ;
# BY USE alpha = 0.0 beta = 0.0 gamma = 1.0
#
# data at : 78 >>> 2016-10-01 19:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 19:44:59'   AND TimeStamp <= '2016-10-01 19:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:29:59' ;
# 0.000869340038168 0.8 0.5 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 19:44:59'AND Timestamp<='2016-10-01 19:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:44:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.5
#
# data at : 79 >>> 2016-10-01 19:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 19:59:59'   AND TimeStamp <= '2016-10-01 19:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:44:59' ;
# 0.021006023673 0.3 1.0 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 19:59:59'AND Timestamp<='2016-10-01 19:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:59:59' ;
# BY USE alpha = 0.3 beta = 1.0 gamma = 0.8
#
# data at : 80 >>> 2016-10-01 20:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 20:14:59'   AND TimeStamp <= '2016-10-01 19:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:59:59' ;
# 0.000132406654592 0.9 0.2 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 20:14:59'AND Timestamp<='2016-10-01 19:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:14:59' ;
# BY USE alpha = 0.9 beta = 0.2 gamma = 0.6
#
# data at : 81 >>> 2016-10-01 20:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 20:29:59'   AND TimeStamp <= '2016-10-01 19:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:14:59' ;
# 0.0258964616663 0.1 0.4 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 20:29:59'AND Timestamp<='2016-10-01 20:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:29:59' ;
# BY USE alpha = 0.1 beta = 0.4 gamma = 0.4
#
# data at : 82 >>> 2016-10-01 20:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 20:44:59'   AND TimeStamp <= '2016-10-01 20:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:29:59' ;
# 0.078326781637 0.4 0.4 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 20:44:59'AND Timestamp<='2016-10-01 20:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:44:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 0.5
#
# data at : 83 >>> 2016-10-01 20:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 20:59:59'   AND TimeStamp <= '2016-10-01 20:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:44:59' ;
# 0.124952077357 0.1 0.2 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 20:59:59'AND Timestamp<='2016-10-01 20:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:59:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.1
#
# data at : 84 >>> 2016-10-01 21:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 21:14:59'   AND TimeStamp <= '2016-10-01 20:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:59:59' ;
# 0.000275856533765 0.7 0.3 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 21:14:59'AND Timestamp<='2016-10-01 20:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:14:59' ;
# BY USE alpha = 0.7 beta = 0.3 gamma = 1.0
#
# data at : 85 >>> 2016-10-01 21:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 21:29:59'   AND TimeStamp <= '2016-10-01 20:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:14:59' ;
# 0.111822603748 0.4 0.5 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 21:29:59'AND Timestamp<='2016-10-01 21:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:29:59' ;
# BY USE alpha = 0.4 beta = 0.5 gamma = 0.4
#
# data at : 86 >>> 2016-10-01 21:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 21:44:59'   AND TimeStamp <= '2016-10-01 21:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:29:59' ;
# 0.00927228404606 0.7 0.0 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 21:44:59'AND Timestamp<='2016-10-01 21:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:44:59' ;
# BY USE alpha = 0.7 beta = 0.0 gamma = 0.4
#
# data at : 87 >>> 2016-10-01 21:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 21:59:59'   AND TimeStamp <= '2016-10-01 21:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:44:59' ;
# 0.00218056507064 0.6 0.2 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 21:59:59'AND Timestamp<='2016-10-01 21:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:59:59' ;
# BY USE alpha = 0.6 beta = 0.2 gamma = 1.0
#
# data at : 88 >>> 2016-10-01 22:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 22:14:59'   AND TimeStamp <= '2016-10-01 21:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:59:59' ;
# 0.00344090037494 0.8 0.4 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 22:14:59'AND Timestamp<='2016-10-01 21:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 22:14:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.0
#
# data at : 89 >>> 2016-10-01 22:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 22:29:59'   AND TimeStamp <= '2016-10-01 21:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 22:14:59' ;
# 0.0112401384139 0.8 0.5 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 22:29:59'AND Timestamp<='2016-10-01 22:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 22:29:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.5
#
# data at : 90 >>> 2016-10-01 22:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 22:44:59'   AND TimeStamp <= '2016-10-01 22:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 22:29:59' ;
# 5.04951899588e-05 0.6 0.7 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 22:44:59'AND Timestamp<='2016-10-01 22:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 22:44:59' ;
# BY USE alpha = 0.6 beta = 0.7 gamma = 0.5
#
# data at : 91 >>> 2016-10-01 22:59:59
# ...
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 16:29:59' ;
# BY USE alpha = 0.1 beta = 0.0 gamma = 0.2
#
# data at : 2946 >>> 2016-10-31 16:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 16:44:59'   AND TimeStamp <= '2016-10-31 16:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 16:29:59' ;
# 3.6975461339e-07 0.4 1.0 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 16:44:59'AND Timestamp<='2016-10-31 16:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 16:44:59' ;
# BY USE alpha = 0.4 beta = 1.0 gamma = 0.2
#
# data at : 2947 >>> 2016-10-31 16:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 16:59:59'   AND TimeStamp <= '2016-10-31 16:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 16:44:59' ;
# 3.82139677518e-05 0.4 1.0 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 16:59:59'AND Timestamp<='2016-10-31 16:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 16:59:59' ;
# BY USE alpha = 0.4 beta = 1.0 gamma = 0.4
#
# data at : 2948 >>> 2016-10-31 17:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 17:14:59'   AND TimeStamp <= '2016-10-31 16:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 16:59:59' ;
# 0.000194321425779 0.9 1.0 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 17:14:59'AND Timestamp<='2016-10-31 16:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 17:14:59' ;
# BY USE alpha = 0.9 beta = 1.0 gamma = 0.5
#
# data at : 2949 >>> 2016-10-31 17:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 17:29:59'   AND TimeStamp <= '2016-10-31 16:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 17:14:59' ;
# 0.000970946947419 0.3 0.1 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 17:29:59'AND Timestamp<='2016-10-31 17:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 17:29:59' ;
# BY USE alpha = 0.3 beta = 0.1 gamma = 1.0
#
# data at : 2950 >>> 2016-10-31 17:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 17:44:59'   AND TimeStamp <= '2016-10-31 17:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 17:29:59' ;
# 0.000429654302061 0.4 0.7 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 17:44:59'AND Timestamp<='2016-10-31 17:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 17:44:59' ;
# BY USE alpha = 0.4 beta = 0.7 gamma = 0.0
#
# data at : 2951 >>> 2016-10-31 17:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 17:59:59'   AND TimeStamp <= '2016-10-31 17:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 17:44:59' ;
# 0.000908043119342 0.4 0.1 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 17:59:59'AND Timestamp<='2016-10-31 17:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 17:59:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.7
#
# data at : 2952 >>> 2016-10-31 18:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 18:14:59'   AND TimeStamp <= '2016-10-31 17:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 17:59:59' ;
# 0.00217037314434 0.2 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 18:14:59'AND Timestamp<='2016-10-31 17:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 18:14:59' ;
# BY USE alpha = 0.2 beta = 0.3 gamma = 0.9
#
# data at : 2953 >>> 2016-10-31 18:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 18:29:59'   AND TimeStamp <= '2016-10-31 17:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 18:14:59' ;
# 0.00326863201492 0.4 1.0 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 18:29:59'AND Timestamp<='2016-10-31 18:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 18:29:59' ;
# BY USE alpha = 0.4 beta = 1.0 gamma = 0.9
#
# data at : 2954 >>> 2016-10-31 18:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 18:44:59'   AND TimeStamp <= '2016-10-31 18:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 18:29:59' ;
# 0.00043935098405 0.4 0.9 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 18:44:59'AND Timestamp<='2016-10-31 18:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 18:44:59' ;
# BY USE alpha = 0.4 beta = 0.9 gamma = 0.3
#
# data at : 2955 >>> 2016-10-31 18:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 18:59:59'   AND TimeStamp <= '2016-10-31 18:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 18:44:59' ;
# 0.0102337932876 0.1 0.1 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 18:59:59'AND Timestamp<='2016-10-31 18:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 18:59:59' ;
# BY USE alpha = 0.1 beta = 0.1 gamma = 1.0
#
# data at : 2956 >>> 2016-10-31 19:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 19:14:59'   AND TimeStamp <= '2016-10-31 18:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 18:59:59' ;
# 2.06119131442 0.1 0.3 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 19:14:59'AND Timestamp<='2016-10-31 18:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 19:14:59' ;
# BY USE alpha = 0.1 beta = 0.3 gamma = 0.6
#
# data at : 2957 >>> 2016-10-31 19:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 19:29:59'   AND TimeStamp <= '2016-10-31 18:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 19:14:59' ;
# 4.02680632154 0.0 0.0 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 19:29:59'AND Timestamp<='2016-10-31 19:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 19:29:59' ;
# BY USE alpha = 0.0 beta = 0.0 gamma = 0.0
#
# data at : 2958 >>> 2016-10-31 19:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 19:44:59'   AND TimeStamp <= '2016-10-31 19:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 19:29:59' ;
# 0.027323092564 0.8 0.8 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 19:44:59'AND Timestamp<='2016-10-31 19:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 19:44:59' ;
# BY USE alpha = 0.8 beta = 0.8 gamma = 0.3
#
# data at : 2959 >>> 2016-10-31 19:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 19:59:59'   AND TimeStamp <= '2016-10-31 19:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 19:44:59' ;
# 0.00723491452264 0.9 0.3 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 19:59:59'AND Timestamp<='2016-10-31 19:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 19:59:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 1.0
#
# data at : 2960 >>> 2016-10-31 20:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 20:14:59'   AND TimeStamp <= '2016-10-31 19:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 19:59:59' ;
# 0.0418543875762 0.5 0.6 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 20:14:59'AND Timestamp<='2016-10-31 19:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 20:14:59' ;
# BY USE alpha = 0.5 beta = 0.6 gamma = 0.5
#
# data at : 2961 >>> 2016-10-31 20:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 20:29:59'   AND TimeStamp <= '2016-10-31 19:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 20:14:59' ;
# 0.0956448306741 0.9 0.7 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 20:29:59'AND Timestamp<='2016-10-31 20:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 20:29:59' ;
# BY USE alpha = 0.9 beta = 0.7 gamma = 0.3
#
# data at : 2962 >>> 2016-10-31 20:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 20:44:59'   AND TimeStamp <= '2016-10-31 20:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 20:29:59' ;
# 0.156735394388 0.3 0.1 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 20:44:59'AND Timestamp<='2016-10-31 20:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 20:44:59' ;
# BY USE alpha = 0.3 beta = 0.1 gamma = 0.7
#
# data at : 2963 >>> 2016-10-31 20:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 20:59:59'   AND TimeStamp <= '2016-10-31 20:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 20:44:59' ;
# 0.0199455276999 0.8 0.5 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 20:59:59'AND Timestamp<='2016-10-31 20:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 20:59:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.1
#
# data at : 2964 >>> 2016-10-31 21:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 21:14:59'   AND TimeStamp <= '2016-10-31 20:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 20:59:59' ;
# 0.000334860880841 0.8 0.1 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 21:14:59'AND Timestamp<='2016-10-31 20:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 21:14:59' ;
# BY USE alpha = 0.8 beta = 0.1 gamma = 0.6
#
# data at : 2965 >>> 2016-10-31 21:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 21:29:59'   AND TimeStamp <= '2016-10-31 20:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 21:14:59' ;
# 0.00169740443891 0.2 0.3 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 21:29:59'AND Timestamp<='2016-10-31 21:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 21:29:59' ;
# BY USE alpha = 0.2 beta = 0.3 gamma = 1.0
#
# data at : 2966 >>> 2016-10-31 21:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 21:44:59'   AND TimeStamp <= '2016-10-31 21:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 21:29:59' ;
# 0.00170397188104 0.4 0.4 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 21:44:59'AND Timestamp<='2016-10-31 21:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 21:44:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 0.7
#
# data at : 2967 >>> 2016-10-31 21:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 21:59:59'   AND TimeStamp <= '2016-10-31 21:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 21:44:59' ;
# 2.18678183849 0.5 0.6 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 21:59:59'AND Timestamp<='2016-10-31 21:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 21:59:59' ;
# BY USE alpha = 0.5 beta = 0.6 gamma = 0.7
#
# data at : 2968 >>> 2016-10-31 22:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 22:14:59'   AND TimeStamp <= '2016-10-31 21:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 21:59:59' ;
# 0.00052113944336 0.3 0.8 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 22:14:59'AND Timestamp<='2016-10-31 21:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 22:14:59' ;
# BY USE alpha = 0.3 beta = 0.8 gamma = 0.4
#
# data at : 2969 >>> 2016-10-31 22:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 22:29:59'   AND TimeStamp <= '2016-10-31 21:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 22:14:59' ;
# 0.000436318747897 0.4 0.1 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 22:29:59'AND Timestamp<='2016-10-31 22:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 22:29:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 1.0
#
# data at : 2970 >>> 2016-10-31 22:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 22:44:59'   AND TimeStamp <= '2016-10-31 22:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 22:29:59' ;
# 0.00110216327714 0.7 0.9 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 22:44:59'AND Timestamp<='2016-10-31 22:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 22:44:59' ;
# BY USE alpha = 0.7 beta = 0.9 gamma = 0.6
#
# data at : 2971 >>> 2016-10-31 22:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 22:59:59'   AND TimeStamp <= '2016-10-31 22:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 22:44:59' ;
# 0.00338371409321 0.5 0.8 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 22:59:59'AND Timestamp<='2016-10-31 22:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 22:59:59' ;
# BY USE alpha = 0.5 beta = 0.8 gamma = 1.0
#
# data at : 2972 >>> 2016-10-31 23:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 23:14:59'   AND TimeStamp <= '2016-10-31 22:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 22:59:59' ;
# 0.000167380909668 0.6 1.0 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 23:14:59'AND Timestamp<='2016-10-31 22:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 23:14:59' ;
# BY USE alpha = 0.6 beta = 1.0 gamma = 0.0
#
# data at : 2973 >>> 2016-10-31 23:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 23:29:59'   AND TimeStamp <= '2016-10-31 22:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 23:14:59' ;
# 0.00133556226982 0.8 0.1 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-10-01 23:29:59'AND Timestamp<='2016-10-31 23:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-31 23:29:59' ;
# BY USE alpha = 0.8 beta = 0.1 gamma = 0.9
#
# data at : 2974 >>> 2016-10-31 23:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-10-01 23:44:59'   AND TimeStamp <= '2016-10-31 23:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-31 23:29:59' ;
# 5.73901930295e-05 0.4 0.9 0.5
# IndexErrorTraceback (most recent call last)
# <ipython-input-2-15acc6dd330f> in <module>()
#      37
#      38     query_last_new = "SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
# ---> 39     query_last_new_1 = "SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
#      40     print "\n",query_last_new
#      41     print query_last_new_1
#
# /usr/local/lib/python2.7/dist-packages/pandas/tseries/base.pyc in __getitem__(self, key)
#     249         getitem = self._data.__getitem__
#     250         if is_int:
# --> 251             val = getitem(key)
#     252             return self._box_func(val)
#     253         else:
#
# IndexError: index 2976 is out of bounds for axis 0 with size 2976
