# %% [markdown]
# ## PREDICTION EXPANDING TOTALPOWER

# %%
#http://stackoverflow.com/questions/11845055/predicting-from-previous-datevalue-data
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import MySQLdb
import numpy as np
import time
import sys
import datetime 
from datetime import datetime
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
from sklearn.metrics import mean_absolute_error,mean_squared_error
import statistics 

import requests

# %matplotlib inline

import MySQLdb
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

# >>> initial_trend(series, 12)
# -0.7847222222222222

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# # forecast 24 points (i.e. two seasons)
# >>> triple_exponential_smoothing(series, 12, 0.716, 0.029, 0.993, 24)
# [30, 20.34449316666667, 28.410051892109554, 30.438122252647577, 39.466817731253066, ...


def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
##-----------------------------------------------------------------------------------
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []
#     query1 = "SELECT active_power FROM prediction.data15min_4y WHERE Timestamp >= '%s' AND TimeStamp <= '%s';"% (time_b[act+1],time_b[act+96])
    query1 = "SELECT total_watt FROM thesis.load WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query1
    df1 = pd.read_sql(query1, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data, 96*7,alpha,beta ,gamma, pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
#     print min(MSE_holtload)
#     print index_MSE
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
#     print count_alpha,count_beta,count_gamma
    print MSE_min,alpha,beta,gamma
    return (alpha,beta,gamma)


def notify(msg):
    URL = "https://notify-api.line.me/api/notify"
    ACCESS_TOKEN = "vxm278yAqFQcXbo2DlTbLD7pqO0QWU2McdNbiwhJWwp"
    MESSAGE_FIELD = {"message" : msg}
    LINE_HEADERS = { "Authorization": "Bearer " + ACCESS_TOKEN }
    try:
        response = requests.post( url=URL,headers=LINE_HEADERS,data=MESSAGE_FIELD)
#         print("Response HTTP Status Code: {status_code}".format( status_code=response.status_code))
    except requests.exceptions.RequestException:
        print("HTTP Request failed")

# %%
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
query = "SELECT Timestamp, total_watt FROM thesis.load WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% ("2016-09-01 00:14:59","2016-11-30 23:59:59")
df = pd.read_sql(query, conn , index_col=['Timestamp'])

pred_no = 1 # power 1 Data/15min in 1Hr --> 60/15 = 4 and 1day = 4*24 = 96
j = 0
i = 0
d = 31
day =0

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

time_a_last = pd.date_range('2016-09-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-09-30 23:44:59', periods=96*d, freq='15T')

# set databases to empty 
query_empty = """truncate table thesis.predict1""" 
c.execute(query_empty)

while (j <= (96*d) -1) :    
    if (j%96 == 0):    
        day += 1
        print "________DAY:" , day
    
    print "\ndata at :" , j,">>>", time_b[j]
    query_last = "SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '%s'   AND TimeStamp <= '%s';"% (time_a_last[0],time_b_last[j])
    print query_last
    df = pd.read_sql(query_last, conn)
    conn.commit()
    data_y = df['total_watt'].values.tolist()
    ans_fiting = fittingparameter(data_y,j)
    
    query_last_new = "SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[0],time_b_last[j+1])
    query_last_new_1 = "SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
    print "\n",query_last_new  
    print query_last_new_1
    print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
    df_last_new = pd.read_sql(query_last_new, conn)
    conn.commit()
    
    data_y = df_last_new['total_watt'].values.tolist()     
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]   
    pred_watt = abs(pred_data[0])

    c.execute("INSERT INTO thesis.predict1 (Timestamp, watt) VALUES ( %s, %s)",(time_b[j],abs(pred_data[0])))
    conn.commit()   
    
    if ( j == 0 or j == 500 or j == 1000 or j == 1500 or j == 2000 or j == 2500 or j == 2880):
        notify("expand")  
        notify(j)  
        
    j += 1 
print "DONE!!"
# Out:
# ________DAY: 1
#
# data at : 0 >>> 2016-10-01 00:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-09-30 23:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-09-30 23:59:59' ;
# 0.00308141136391 0.8 0.4 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-09-30 23:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:14:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.4
#
# data at : 1 >>> 2016-10-01 00:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-09-30 23:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:14:59' ;
# 0.0239772340198 0.4 0.1 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 00:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:29:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.9
#
# data at : 2 >>> 2016-10-01 00:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 00:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:29:59' ;
# 9.68788482281e-05 0.7 0.1 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 00:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:44:59' ;
# BY USE alpha = 0.7 beta = 0.1 gamma = 0.0
#
# data at : 3 >>> 2016-10-01 00:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 00:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:44:59' ;
# 0.862624244229 0.1 0.2 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 00:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 00:59:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.7
#
# data at : 4 >>> 2016-10-01 01:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 00:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 00:59:59' ;
# 0.00380961873074 0.4 0.3 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 00:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:14:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.0
#
# data at : 5 >>> 2016-10-01 01:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 00:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:14:59' ;
# 0.0443544191211 0.2 0.4 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 01:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:29:59' ;
# BY USE alpha = 0.2 beta = 0.4 gamma = 0.7
#
# data at : 6 >>> 2016-10-01 01:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 01:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:29:59' ;
# 0.111730497877 0.3 0.4 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 01:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:44:59' ;
# BY USE alpha = 0.3 beta = 0.4 gamma = 0.8
#
# data at : 7 >>> 2016-10-01 01:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 01:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:44:59' ;
# 0.103123664303 0.4 0.5 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 01:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 01:59:59' ;
# BY USE alpha = 0.4 beta = 0.5 gamma = 0.9
#
# data at : 8 >>> 2016-10-01 02:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 01:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 01:59:59' ;
# 0.130324443523 0.3 1.0 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 01:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:14:59' ;
# BY USE alpha = 0.3 beta = 1.0 gamma = 0.5
#
# data at : 9 >>> 2016-10-01 02:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 01:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:14:59' ;
# 0.00539151294511 0.2 0.5 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 02:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:29:59' ;
# BY USE alpha = 0.2 beta = 0.5 gamma = 0.3
#
# data at : 10 >>> 2016-10-01 02:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 02:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:29:59' ;
# 9.98211832031e-05 0.3 0.7 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 02:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:44:59' ;
# BY USE alpha = 0.3 beta = 0.7 gamma = 0.0
#
# data at : 11 >>> 2016-10-01 02:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 02:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:44:59' ;
# 4.89586773654 0.3 0.5 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 02:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 02:59:59' ;
# BY USE alpha = 0.3 beta = 0.5 gamma = 0.6
#
# data at : 12 >>> 2016-10-01 03:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 02:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 02:59:59' ;
# 0.065742773303 0.2 0.9 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 02:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:14:59' ;
# BY USE alpha = 0.2 beta = 0.9 gamma = 0.1
#
# data at : 13 >>> 2016-10-01 03:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 02:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:14:59' ;
# 0.000514641201707 0.7 0.7 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 03:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:29:59' ;
# BY USE alpha = 0.7 beta = 0.7 gamma = 0.1
#
# data at : 14 >>> 2016-10-01 03:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 03:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:29:59' ;
# 0.0104929943657 0.1 0.6 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 03:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:44:59' ;
# BY USE alpha = 0.1 beta = 0.6 gamma = 0.1
#
# data at : 15 >>> 2016-10-01 03:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 03:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:44:59' ;
# 0.004298673865 0.7 0.5 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 03:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 03:59:59' ;
# BY USE alpha = 0.7 beta = 0.5 gamma = 1.0
#
# data at : 16 >>> 2016-10-01 04:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 03:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 03:59:59' ;
# 0.0502573146145 0.3 0.2 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 03:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:14:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.9
#
# data at : 17 >>> 2016-10-01 04:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 03:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:14:59' ;
# 0.000517306654193 0.6 0.7 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 04:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:29:59' ;
# BY USE alpha = 0.6 beta = 0.7 gamma = 0.2
#
# data at : 18 >>> 2016-10-01 04:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 04:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:29:59' ;
# 0.0134819975189 0.4 1.0 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 04:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:44:59' ;
# BY USE alpha = 0.4 beta = 1.0 gamma = 0.5
#
# data at : 19 >>> 2016-10-01 04:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 04:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:44:59' ;
# 0.0192292364566 0.9 0.9 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 04:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 04:59:59' ;
# BY USE alpha = 0.9 beta = 0.9 gamma = 0.8
#
# data at : 20 >>> 2016-10-01 05:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 04:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 04:59:59' ;
# 0.00599524166028 0.9 0.4 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 04:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:14:59' ;
# BY USE alpha = 0.9 beta = 0.4 gamma = 0.1
#
# data at : 21 >>> 2016-10-01 05:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 04:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:14:59' ;
# 7.97415485022e-05 0.4 0.6 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 05:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:29:59' ;
# BY USE alpha = 0.4 beta = 0.6 gamma = 0.2
#
# data at : 22 >>> 2016-10-01 05:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 05:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:29:59' ;
# 0.00892001865854 0.4 0.7 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 05:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:44:59' ;
# BY USE alpha = 0.4 beta = 0.7 gamma = 0.7
#
# data at : 23 >>> 2016-10-01 05:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 05:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:44:59' ;
# 1.17874044954e-06 0.8 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 05:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 05:59:59' ;
# BY USE alpha = 0.8 beta = 0.2 gamma = 0.4
#
# data at : 24 >>> 2016-10-01 06:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 05:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 05:59:59' ;
# 2.65225571063e-05 0.7 0.0 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 05:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:14:59' ;
# BY USE alpha = 0.7 beta = 0.0 gamma = 0.6
#
# data at : 25 >>> 2016-10-01 06:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 05:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:14:59' ;
# 2.79255246647 0.4 1.0 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 06:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:29:59' ;
# BY USE alpha = 0.4 beta = 1.0 gamma = 1.0
#
# data at : 26 >>> 2016-10-01 06:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 06:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:29:59' ;
# 0.00136225318752 0.8 0.5 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 06:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:44:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.7
#
# data at : 27 >>> 2016-10-01 06:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 06:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:44:59' ;
# 0.0213509604437 0.9 0.4 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 06:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 06:59:59' ;
# BY USE alpha = 0.9 beta = 0.4 gamma = 0.8
#
# data at : 28 >>> 2016-10-01 07:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 06:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 06:59:59' ;
# 7.82860652021e-05 0.8 0.2 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 06:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:14:59' ;
# BY USE alpha = 0.8 beta = 0.2 gamma = 0.8
#
# data at : 29 >>> 2016-10-01 07:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 06:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:14:59' ;
# 0.000337140157083 0.5 0.9 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 07:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:29:59' ;
# BY USE alpha = 0.5 beta = 0.9 gamma = 0.6
#
# data at : 30 >>> 2016-10-01 07:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 07:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:29:59' ;
# 0.00346886271034 0.4 0.2 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 07:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:44:59' ;
# BY USE alpha = 0.4 beta = 0.2 gamma = 0.7
#
# data at : 31 >>> 2016-10-01 07:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 07:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:44:59' ;
# 0.0010122445321 0.9 0.5 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 07:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 07:59:59' ;
# BY USE alpha = 0.9 beta = 0.5 gamma = 1.0
#
# data at : 32 >>> 2016-10-01 08:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 07:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 07:59:59' ;
# 0.00163530557245 0.9 0.7 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 07:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:14:59' ;
# BY USE alpha = 0.9 beta = 0.7 gamma = 0.8
#
# data at : 33 >>> 2016-10-01 08:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 07:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:14:59' ;
# 2.77646529436e-05 0.8 0.4 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 08:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:29:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.6
#
# data at : 34 >>> 2016-10-01 08:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 08:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:29:59' ;
# 2.08518593435e-05 0.4 0.6 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 08:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:44:59' ;
# BY USE alpha = 0.4 beta = 0.6 gamma = 0.4
#
# data at : 35 >>> 2016-10-01 08:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 08:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:44:59' ;
# 0.0783207111689 0.3 0.7 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 08:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 08:59:59' ;
# BY USE alpha = 0.3 beta = 0.7 gamma = 1.0
#
# data at : 36 >>> 2016-10-01 09:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 08:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 08:59:59' ;
# 2.7848452883 0.1 0.8 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 08:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:14:59' ;
# BY USE alpha = 0.1 beta = 0.8 gamma = 0.4
#
# data at : 37 >>> 2016-10-01 09:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 08:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:14:59' ;
# 0.000465739554604 0.7 0.8 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 09:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:29:59' ;
# BY USE alpha = 0.7 beta = 0.8 gamma = 0.1
#
# data at : 38 >>> 2016-10-01 09:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 09:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:29:59' ;
# 0.0169706538201 0.3 0.1 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 09:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:44:59' ;
# BY USE alpha = 0.3 beta = 0.1 gamma = 0.8
#
# data at : 39 >>> 2016-10-01 09:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 09:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:44:59' ;
# 373.178553231 0.1 0.4 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 09:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 09:59:59' ;
# BY USE alpha = 0.1 beta = 0.4 gamma = 0.8
#
# data at : 40 >>> 2016-10-01 10:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 09:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 09:59:59' ;
# 0.580470793686 0.4 0.2 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 09:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:14:59' ;
# BY USE alpha = 0.4 beta = 0.2 gamma = 0.2
#
# data at : 41 >>> 2016-10-01 10:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 09:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:14:59' ;
# 0.0532574572388 0.1 0.7 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 10:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:29:59' ;
# BY USE alpha = 0.1 beta = 0.7 gamma = 0.7
#
# data at : 42 >>> 2016-10-01 10:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 10:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:29:59' ;
# 0.00155096851072 0.9 0.3 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 10:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:44:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.7
#
# data at : 43 >>> 2016-10-01 10:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 10:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:44:59' ;
# 0.000216882752943 0.4 0.8 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 10:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 10:59:59' ;
# BY USE alpha = 0.4 beta = 0.8 gamma = 1.0
#
# data at : 44 >>> 2016-10-01 11:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 10:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 10:59:59' ;
# 0.00174418887912 0.4 0.3 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 10:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:14:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.8
#
# data at : 45 >>> 2016-10-01 11:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 10:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:14:59' ;
# 5.05948716541e-06 0.7 0.1 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 11:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:29:59' ;
# BY USE alpha = 0.7 beta = 0.1 gamma = 0.8
#
# data at : 46 >>> 2016-10-01 11:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 11:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:29:59' ;
# 0.00645532380632 0.6 0.2 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 11:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:44:59' ;
# BY USE alpha = 0.6 beta = 0.2 gamma = 0.6
#
# data at : 47 >>> 2016-10-01 11:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 11:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:44:59' ;
# 0.00485242673541 0.6 0.0 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 11:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 11:59:59' ;
# BY USE alpha = 0.6 beta = 0.0 gamma = 0.7
#
# data at : 48 >>> 2016-10-01 12:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 11:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 11:59:59' ;
# 0.000269861104856 0.3 0.2 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 11:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:14:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.8
#
# data at : 49 >>> 2016-10-01 12:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 11:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:14:59' ;
# 0.00592211938488 0.6 0.4 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 12:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:29:59' ;
# BY USE alpha = 0.6 beta = 0.4 gamma = 0.6
#
# data at : 50 >>> 2016-10-01 12:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 12:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:29:59' ;
# 2.10656803495e-05 0.3 0.2 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 12:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:44:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.2
#
# data at : 51 >>> 2016-10-01 12:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 12:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:44:59' ;
# 0.0106696907907 0.1 0.5 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 12:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 12:59:59' ;
# BY USE alpha = 0.1 beta = 0.5 gamma = 0.4
#
# data at : 52 >>> 2016-10-01 13:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 12:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 12:59:59' ;
# 0.000151989589818 0.8 0.5 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 12:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:14:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.5
#
# data at : 53 >>> 2016-10-01 13:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 12:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:14:59' ;
# 0.173191067352 0.5 0.7 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 13:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:29:59' ;
# BY USE alpha = 0.5 beta = 0.7 gamma = 0.7
#
# data at : 54 >>> 2016-10-01 13:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 13:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:29:59' ;
# 3.95847919715e-05 0.2 0.1 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 13:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:44:59' ;
# BY USE alpha = 0.2 beta = 0.1 gamma = 1.0
#
# data at : 55 >>> 2016-10-01 13:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 13:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:44:59' ;
# 0.000584621491626 0.9 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 13:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 13:59:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.9
#
# data at : 56 >>> 2016-10-01 14:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 13:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 13:59:59' ;
# 0.000464769123522 0.4 0.4 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 13:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:14:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 0.1
#
# data at : 57 >>> 2016-10-01 14:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 13:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:14:59' ;
# 0.000697865753879 0.7 0.7 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 14:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:29:59' ;
# BY USE alpha = 0.7 beta = 0.7 gamma = 0.5
#
# data at : 58 >>> 2016-10-01 14:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 14:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:29:59' ;
# 0.016979174126 0.8 1.0 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 14:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:44:59' ;
# BY USE alpha = 0.8 beta = 1.0 gamma = 0.3
#
# data at : 59 >>> 2016-10-01 14:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 14:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:44:59' ;
# 0.00124261310685 0.6 0.8 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 14:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 14:59:59' ;
# BY USE alpha = 0.6 beta = 0.8 gamma = 1.0
#
# data at : 60 >>> 2016-10-01 15:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 14:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 14:59:59' ;
# 0.014592925781 0.4 0.7 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 14:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:14:59' ;
# BY USE alpha = 0.4 beta = 0.7 gamma = 0.6
#
# data at : 61 >>> 2016-10-01 15:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 14:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:14:59' ;
# 0.000286574297976 0.1 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 15:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:29:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.4
#
# data at : 62 >>> 2016-10-01 15:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 15:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:29:59' ;
# 0.000429689669552 0.7 0.6 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 15:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:44:59' ;
# BY USE alpha = 0.7 beta = 0.6 gamma = 0.6
#
# data at : 63 >>> 2016-10-01 15:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 15:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:44:59' ;
# 0.0550299264595 0.7 0.0 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 15:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 15:59:59' ;
# BY USE alpha = 0.7 beta = 0.0 gamma = 0.9
#
# data at : 64 >>> 2016-10-01 16:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 15:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 15:59:59' ;
# 0.00121481368077 0.2 0.4 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 15:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:14:59' ;
# BY USE alpha = 0.2 beta = 0.4 gamma = 0.2
#
# data at : 65 >>> 2016-10-01 16:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 15:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:14:59' ;
# 9.65763534301e-05 0.9 0.0 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 16:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:29:59' ;
# BY USE alpha = 0.9 beta = 0.0 gamma = 0.8
#
# data at : 66 >>> 2016-10-01 16:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 16:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:29:59' ;
# 0.000411656954354 0.4 0.0 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 16:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:44:59' ;
# BY USE alpha = 0.4 beta = 0.0 gamma = 1.0
#
# data at : 67 >>> 2016-10-01 16:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 16:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:44:59' ;
# 5.04967773909e-06 0.6 0.5 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 16:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 16:59:59' ;
# BY USE alpha = 0.6 beta = 0.5 gamma = 0.3
#
# data at : 68 >>> 2016-10-01 17:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 16:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 16:59:59' ;
# 0.000150430150972 0.9 0.2 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 16:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:14:59' ;
# BY USE alpha = 0.9 beta = 0.2 gamma = 0.4
#
# data at : 69 >>> 2016-10-01 17:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 16:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:14:59' ;
# 3.94997434011e-05 0.8 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 17:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:29:59' ;
# BY USE alpha = 0.8 beta = 0.3 gamma = 0.9
#
# data at : 70 >>> 2016-10-01 17:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 17:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:29:59' ;
# 0.000350166619078 0.5 0.2 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 17:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:44:59' ;
# BY USE alpha = 0.5 beta = 0.2 gamma = 0.9
#
# data at : 71 >>> 2016-10-01 17:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 17:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:44:59' ;
# 1.03081865157 0.2 0.7 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 17:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 17:59:59' ;
# BY USE alpha = 0.2 beta = 0.7 gamma = 0.3
#
# data at : 72 >>> 2016-10-01 18:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 17:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 17:59:59' ;
# 0.000158481648093 0.2 0.6 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 17:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:14:59' ;
# BY USE alpha = 0.2 beta = 0.6 gamma = 0.6
#
# data at : 73 >>> 2016-10-01 18:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 17:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:14:59' ;
# 0.235429819176 0.3 0.6 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 18:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:29:59' ;
# BY USE alpha = 0.3 beta = 0.6 gamma = 1.0
#
# data at : 74 >>> 2016-10-01 18:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 18:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:29:59' ;
# 225.29130261 0.2 0.9 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 18:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:44:59' ;
# BY USE alpha = 0.2 beta = 0.9 gamma = 0.8
#
# data at : 75 >>> 2016-10-01 18:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 18:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:44:59' ;
# 0.000284070394307 0.8 0.2 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 18:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 18:59:59' ;
# BY USE alpha = 0.8 beta = 0.2 gamma = 0.7
#
# data at : 76 >>> 2016-10-01 19:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 18:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 18:59:59' ;
# 0.040277523658 0.2 0.2 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 18:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:14:59' ;
# BY USE alpha = 0.2 beta = 0.2 gamma = 0.8
#
# data at : 77 >>> 2016-10-01 19:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 18:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:14:59' ;
# 0.439641128799 1.0 0.9 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 19:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:29:59' ;
# BY USE alpha = 1.0 beta = 0.9 gamma = 0.0
#
# data at : 78 >>> 2016-10-01 19:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 19:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:29:59' ;
# 0.000869340038168 0.8 0.5 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 19:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:44:59' ;
# BY USE alpha = 0.8 beta = 0.5 gamma = 0.5
#
# data at : 79 >>> 2016-10-01 19:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 19:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:44:59' ;
# 0.0210060212061 0.3 1.0 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 19:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 19:59:59' ;
# BY USE alpha = 0.3 beta = 1.0 gamma = 0.8
#
# data at : 80 >>> 2016-10-01 20:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 19:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 19:59:59' ;
# 0.000132406654592 0.9 0.2 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 19:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:14:59' ;
# BY USE alpha = 0.9 beta = 0.2 gamma = 0.6
#
# data at : 81 >>> 2016-10-01 20:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 19:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:14:59' ;
# 0.026690325027 0.4 0.1 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 20:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:29:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.5
#
# data at : 82 >>> 2016-10-01 20:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 20:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:29:59' ;
# 0.078326781637 0.4 0.4 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 20:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:44:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 0.5
#
# data at : 83 >>> 2016-10-01 20:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 20:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:44:59' ;
# 0.113950686355 0.1 0.2 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 20:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 20:59:59' ;
# BY USE alpha = 0.1 beta = 0.2 gamma = 0.1
#
# data at : 84 >>> 2016-10-01 21:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 20:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 20:59:59' ;
# 0.000275856533765 0.7 0.3 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 20:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:14:59' ;
# BY USE alpha = 0.7 beta = 0.3 gamma = 1.0
#
# data at : 85 >>> 2016-10-01 21:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 20:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:14:59' ;
# 0.111822603748 0.4 0.5 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 21:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:29:59' ;
# BY USE alpha = 0.4 beta = 0.5 gamma = 0.4
#
# data at : 86 >>> 2016-10-01 21:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 21:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:29:59' ;
# 0.00507607556431 0.7 0.0 0.4
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 21:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:44:59' ;
# BY USE alpha = 0.7 beta = 0.0 gamma = 0.4
#
# data at : 87 >>> 2016-10-01 21:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 21:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:44:59' ;
# 0.00218056507063 0.6 0.2 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 21:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 21:59:59' ;
# BY USE alpha = 0.6 beta = 0.2 gamma = 1.0
#
# data at : 88 >>> 2016-10-01 22:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 21:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 21:59:59' ;
# 0.00344090037495 0.8 0.4 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 21:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 22:14:59' ;
# BY USE alpha = 0.8 beta = 0.4 gamma = 0.0
#
# data at : 89 >>> 2016-10-01 22:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 21:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 22:14:59' ;
# 0.00181540666436 0.0 0.0 1.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 22:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 22:29:59' ;
# BY USE alpha = 0.0 beta = 0.0 gamma = 1.0
#
# data at : 90 >>> 2016-10-01 22:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-01 22:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-01 22:29:59' ;
# 5.04951899588e-05 0.6 0.7 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-01 22:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-01 22:44:59' ;
# BY USE alpha = 0.6 beta = 0.7 gamma = 0.5
#
# data at : 91 >>> 2016-10-01 22:59:59
# ...
# 8.40998091826e-05 0.2 0.4 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 10:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 10:29:59' ;
# BY USE alpha = 0.2 beta = 0.4 gamma = 0.1
#
# data at : 1674 >>> 2016-10-18 10:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 10:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 10:29:59' ;
# 0.000410483447079 0.5 0.1 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 10:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 10:44:59' ;
# BY USE alpha = 0.5 beta = 0.1 gamma = 0.3
#
# data at : 1675 >>> 2016-10-18 10:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 10:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 10:44:59' ;
# 5.70391768667e-05 0.8 0.8 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 10:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 10:59:59' ;
# BY USE alpha = 0.8 beta = 0.8 gamma = 0.1
#
# data at : 1676 >>> 2016-10-18 11:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 10:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 10:59:59' ;
# 0.00164068711139 0.5 0.3 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 10:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 11:14:59' ;
# BY USE alpha = 0.5 beta = 0.3 gamma = 0.5
#
# data at : 1677 >>> 2016-10-18 11:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 10:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 11:14:59' ;
# 0.00895562964368 0.4 0.3 0.6
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 11:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 11:29:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.6
#
# data at : 1678 >>> 2016-10-18 11:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 11:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 11:29:59' ;
# 2.64014739257e-06 0.6 0.3 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 11:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 11:44:59' ;
# BY USE alpha = 0.6 beta = 0.3 gamma = 0.2
#
# data at : 1679 >>> 2016-10-18 11:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 11:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 11:44:59' ;
# 0.00120799231114 0.3 0.5 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 11:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 11:59:59' ;
# BY USE alpha = 0.3 beta = 0.5 gamma = 0.5
#
# data at : 1680 >>> 2016-10-18 12:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 11:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 11:59:59' ;
# 2.25753611364e-05 0.4 0.0 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 11:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 12:14:59' ;
# BY USE alpha = 0.4 beta = 0.0 gamma = 0.8
#
# data at : 1681 >>> 2016-10-18 12:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 11:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 12:14:59' ;
# 6.82622991139e-07 0.6 0.3 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 12:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 12:29:59' ;
# BY USE alpha = 0.6 beta = 0.3 gamma = 0.2
#
# data at : 1682 >>> 2016-10-18 12:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 12:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 12:29:59' ;
# 0.00629884507184 0.1 0.1 0.3
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 12:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 12:44:59' ;
# BY USE alpha = 0.1 beta = 0.1 gamma = 0.3
#
# data at : 1683 >>> 2016-10-18 12:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 12:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 12:44:59' ;
# 0.000259400306115 0.3 0.6 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 12:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 12:59:59' ;
# BY USE alpha = 0.3 beta = 0.6 gamma = 0.2
#
# data at : 1684 >>> 2016-10-18 13:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 12:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 12:59:59' ;
# 6.98082308612e-09 0.9 0.9 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 12:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 13:14:59' ;
# BY USE alpha = 0.9 beta = 0.9 gamma = 0.5
#
# data at : 1685 >>> 2016-10-18 13:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 12:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 13:14:59' ;
# 0.000770758580166 0.3 0.8 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 13:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 13:29:59' ;
# BY USE alpha = 0.3 beta = 0.8 gamma = 0.2
#
# data at : 1686 >>> 2016-10-18 13:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 13:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 13:29:59' ;
# 1.31983809537e-05 0.3 0.7 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 13:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 13:44:59' ;
# BY USE alpha = 0.3 beta = 0.7 gamma = 0.1
#
# data at : 1687 >>> 2016-10-18 13:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 13:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 13:44:59' ;
# 0.141634612194 0.5 1.0 0.7
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 13:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 13:59:59' ;
# BY USE alpha = 0.5 beta = 1.0 gamma = 0.7
#
# data at : 1688 >>> 2016-10-18 14:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 13:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 13:59:59' ;
# 0.000150014427773 0.3 0.3 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 13:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 14:14:59' ;
# BY USE alpha = 0.3 beta = 0.3 gamma = 0.8
#
# data at : 1689 >>> 2016-10-18 14:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 13:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 14:14:59' ;
# 7.36462467006e-05 0.3 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 14:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 14:29:59' ;
# BY USE alpha = 0.3 beta = 0.3 gamma = 0.9
#
# data at : 1690 >>> 2016-10-18 14:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 14:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 14:29:59' ;
# 0.000642975813959 0.5 0.7 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 14:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 14:44:59' ;
# BY USE alpha = 0.5 beta = 0.7 gamma = 0.9
#
# data at : 1691 >>> 2016-10-18 14:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 14:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 14:44:59' ;
# 6.64386505621e-06 0.4 0.1 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 14:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 14:59:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.2
#
# data at : 1692 >>> 2016-10-18 15:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 14:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 14:59:59' ;
# 4.38248357962e-08 0.6 0.4 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 14:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 15:14:59' ;
# BY USE alpha = 0.6 beta = 0.4 gamma = 0.9
#
# data at : 1693 >>> 2016-10-18 15:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 14:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 15:14:59' ;
# 0.032500702448 0.4 0.2 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 15:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 15:29:59' ;
# BY USE alpha = 0.4 beta = 0.2 gamma = 0.8
#
# data at : 1694 >>> 2016-10-18 15:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 15:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 15:29:59' ;
# 0.00071573555769 0.2 0.5 0.0
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 15:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 15:44:59' ;
# BY USE alpha = 0.2 beta = 0.5 gamma = 0.0
#
# data at : 1695 >>> 2016-10-18 15:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 15:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 15:44:59' ;
# 1.82963884909e-06 0.5 0.6 0.5
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 15:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 15:59:59' ;
# BY USE alpha = 0.5 beta = 0.6 gamma = 0.5
#
# data at : 1696 >>> 2016-10-18 16:14:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 15:44:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 15:59:59' ;
# 0.000257732278177 0.1 0.8 0.1
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 15:59:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 16:14:59' ;
# BY USE alpha = 0.1 beta = 0.8 gamma = 0.1
#
# data at : 1697 >>> 2016-10-18 16:29:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 15:59:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 16:14:59' ;
# 6.45761246335e-08 0.9 0.3 0.2
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 16:14:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 16:29:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.2
#
# data at : 1698 >>> 2016-10-18 16:44:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 16:14:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 16:29:59' ;
# 0.0312507751555 0.4 0.3 0.9
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 16:29:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 16:44:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 0.9
#
# data at : 1699 >>> 2016-10-18 16:59:59
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp >= '2016-09-01 00:14:59'   AND TimeStamp <= '2016-10-18 16:29:59';
# SELECT total_watt FROM thesis.load WHERE Timestamp = '2016-10-18 16:44:59' ;
# 5.76681567392e-05 0.8 0.7 0.8
#
# SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 16:44:59';
# SELECT Timestamp,total_watt FROM  thesis.load  WHERE Timestamp = '2016-10-18 16:59:59' ;
# BY USE alpha = 0.8 beta = 0.7 gamma = 0.8
# DatabaseErrorTraceback (most recent call last)
# <ipython-input-2-05c9a74028ad> in <module>()
#      41     print query_last_new_1
#      42     print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
# ---> 43     df_last_new = pd.read_sql(query_last_new, conn)
#      44     conn.commit()
#      45
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     397             sql, index_col=index_col, params=params,
#     398             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 399             chunksize=chunksize)
#     400
#     401     try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1434
#    1435         args = _convert_params(sql, params)
# -> 1436         cursor = self.execute(*args)
#    1437         columns = [col_desc[0] for col_desc in cursor.description]
#    1438
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1407                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#    1408                                    " to rollback" % (args[0], exc))
# -> 1409                 raise_with_traceback(ex)
#    1410
#    1411             ex = DatabaseError(
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1403         except Exception as exc:
#    1404             try:
# -> 1405                 self.con.rollback()
#    1406             except Exception:  # pragma: no cover
#    1407                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#
# DatabaseError: Execution failed on sql: SELECT Timestamp,total_watt FROM  thesis.load WHERE Timestamp>='2016-09-01 00:14:59'AND Timestamp<='2016-10-18 16:44:59';
# (2006, 'MySQL server has gone away')
# unable to rollback
