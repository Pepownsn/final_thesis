# %% [markdown]
# ### main of month 2 : NOVEMBER (30 days)

# %% [markdown]
# ### EVERY TIME
# #### RESET DATABASE &  RESTART KERNAL & CLAER OUTPUT

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline 

from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
# ____________________________________________________________________________________________________   

'''
##  PRIORITY TABLE
'''
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
      
        return ''.join(html)
 # ____________________________________________________________________________________________________   
    
"""
## CONVERSING  UNIT (kW) >>  BILL (bath)
"""
def bill(allpow,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge
 
    ## Fundamental parameter      
    if allpow <= 0:
        bath = 0
    elif 0 <= allpow <= 150:
        bath = allpow*t1
    elif  151 <= allpow <= 400:
        power = allpow-150
        bath_1 = 150*t1
        bath_2 = power*t2
        bath = bath_1+bath_2
    else:
        power = allpow-150
        bath_1 = 150*t1
        power = power-250
        bath_2 = 250*t2
        bath_3 = power*t3
        bath = bath_1+bath_2+bath_3   
    service_price = 38.22  #permonth (fixed)   
    ## FT -33.2 satang/unit
    FT_price = allpow*Ft
    ## VAT 7%
    VAT_price = ((service_price+bath)+FT_price)*0.07
    bill = bath+service_price+FT_price+VAT_price
    return round(bill,2)
 # ____________________________________________________________________________________________________   

"""
## CONVERSING  BILL (bath) >>  UNIT (kW) >> 
"""
def inbill(bath,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge  
    u = symbols('u')
    test_1 = solve(Eq((u*t1)+ser+(u*Ft)+(0.07*((u*t1)+ser))+(0.07*(u*Ft)),bath))
    test_2 = solve(Eq((150*t1)+((u-150)*t2)+ser+(u*Ft)+(0.07*((150*t1)+((u-150)*t2)+ser))+(0.07*(u*Ft)),bath))
    test_3 = solve(Eq((150*t1)+(250*t2)+((u-400)*t3)+ser+(u*Ft)+(0.07*((150*t1)+(250*t2)+((u-400)*t3)+ser))+(0.07*(u*Ft)),bath))
    if 1 <=  test_1[0] <= 150:
        unit = test_1[0]
    elif 151 <=  test_2[0] <=  400:
        unit = test_2[0]
    else:
        unit = test_3[0]
    return (round(unit))
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The ENDING POSITION OF EACH APPLIANCES
"""
def end_air(j): 
    check = 1  
    m_air = j+1   
    while (check == 1):
        while df1.aircont[ m_air] > 0 and m_air < (96*31)-1:
            m_air += 1
        check = 0
    return  m_air

def end_com(j): 
    check = 1  
    m_com = j+1   
    while (check == 1):
        while df1.computer[m_com] > 0 and m_com < (96*31)-1:
            m_com += 1  
        check = 0
    return  m_com

def end_elec(j): 
    check = 1  
    m_elec = j+1   
    while (check == 1):
        while df1.elec_thermo[m_elec] > 0 and m_elec < (96*31)-1:
            m_elec += 1  
        check = 0
    return  m_elec

def end_hair(j): 
    check = 1  
    m_hair = j+1   
    while (check == 1):
        while df1.hair_dryer[m_hair] > 0 and m_hair < (96*31)-1:
            m_hair += 1  
        check = 0
    return  m_hair

def end_iphon(j): 
    check = 1  
    m_iphon = j+1   
    while (check == 1):
        while df1.iphonecharger[ m_iphon] > 0 and m_iphon < (96*31)-1:
            m_iphon += 1  
        check = 0
    return  m_iphon

def end_fan(j): 
    check = 1  
    m_fan = j+1   
    while (check == 1):
        while df1.fan[m_fan] > 0 and m_fan < (96*31)-1:
            m_fan += 1  
        check = 0
    return  m_fan

def end_tv(j): 
    check = 1  
    m_tv = j+1   
    while (check == 1):
        while df1.tv[m_tv] > 0 and m_tv < (96*31)-1 :
            m_tv += 1  
        check = 0
    return  m_tv

def end_water(j): 
    check = 1  
    m_water = j+1   
    while (check == 1):
        while df1.water_heater[m_water] > 0 and m_water < (96*31)-1:
            m_water += 1  
        check = 0
    return  m_water
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The STATE OF APPLIANCES 
"""    
def state(j,m_air,m_com, m_elec,m_hair,m_iphon, m_fan ,m_tv, m_water) :
    if j <= m_air:
        ans1 = 18    
    else:
        ans1 = 0
    if j <= m_com:
        ans2 = df1.computer[j]
    else:
        ans2 = 0
    if j <= m_elec:
        ans3 = df1.elec_thermo[j]
    else:
        ans3 = 0
    if j <= m_hair:
        ans4 = df1.hair_dryer[j]
    else:
        ans4 = 0
    if j <= m_iphon:
        ans5 = df1.iphonecharger[j]
    else:
        ans5 = 0
    if j <= m_fan:
        ans6 = df1.fan[j]
    else:
        ans6 = 0
    if j <= m_tv:
        ans7 = df1.tv[j]
    else:
        ans7 = 0
    if j <= m_water:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0

    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8
#     print "substact k watt out from watt = ",k,"watt    ||||||" ,ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8
    return (ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8,k) 
 # ____________________________________________________________________________________________________   

"""
## PREDICTION 
"""        
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
 # ____________________________________________________________________________________________________   

"""
## FITTING PARAMETERS FOR PREDICTION
""" 
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []    
    ##############################################################
    ### ??????????????????????????????????????????????????????????
    query_last = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query_last
    df1 = pd.read_sql(query_last, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data,96*7,alpha,beta,gamma,pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print "the minimum MSE of prediction =",MSE_min,"by alpha =",alpha,"beta =",beta,"gamma =",gamma
    return (alpha,beta,gamma)
 # ____________________________________________________________________________________________________   

"""
## CHECKING THE STATUS OF APPLIANCES ON THAT TIME
""" 
def appliances(j):
    ############################################################## (day + table_database)
    ### ??????????????????????????????????????????????????????????
    time_b = pd.date_range('2016-11-01 00:14:59', periods=96*d, freq='15T')
    conn = MySQLdb.connect("localhost","conn","hems")
    c = conn.cursor()
    query1 = "SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '%s'; "% (time_b[j])
    print "Check status of appliances from"
    print query1
    df1 = pd.read_sql(query1, conn) 
    
    for row in df1.iterrows():
        index, data = row
        state = data.tolist()
    i = 1
    status = []
    while(i < len(state)-1):
        dict = { 1:'refrigerator',2:'wireless_router',3:'aircont',4:'computer',5:'electrical_thermo',6:'hair_dryer',7:'microwave',8:'iphone_charger',9:'fan',10:'tv'
                ,11:'washing_machine',12:'iron',13:'rice_cooker',14:'water_heater',15:'light_system'}
        if state[i] != 0:
            a = dict[i]
            status.append(a)
        i +=1  
    print "NOW !! you are turning ON" ,status ,"=",len(status),"items"
    print "______________________________________________________________________________________________\n"
    return(state)
 # ____________________________________________________________________________________________________

# %%
# Set paremeters
j = 0
d = 32   ################################
pred_no = 1
z  = 0 
trinker = [0,0,0,0,0,0,0,0]
batt = float(2.900*1000)     ## SIZE OF BATTERY  2.9 kW 
k = 0
all_power = []
sum_power = []
sum_p = []
sum_pv = []
sum_pvconsumption = []
sum_batt = []
sum_battconsumption = []
sum_grid= []
sum_gridconsumption = []
h = 0

ans_air = 0 
ans_com = 0 
ans_elec = 0 
ans_hair = 0 
ans_iphon = 0 
ans_fan = 0
ans_tv = 0
ans_water = 0
m_air = 0
m_com = 0
m_elec = 0
m_hair = 0
m_iphon = 0
m_fan = 0
m_tv = 0   
m_water = 0
minbatt = batt * 0.2        ## PERIOD OF  BATTERY  USING  2.9*0.2 = 580 - 2900
maxbatt = batt
effi = float(0.96)            ##  EFFICIENTCY OF CHARGING  BATTERY  = 96%
levelbatt = []
levelbatt.append(float(580))  ####################################################
pv_consumption = []
batt_consumption = []
grid_consumption = []
overpv = float(0)
sum_overpv = float(0)
charging_watt = float(0)
count_active = 0 

count_air = 0
count_fan = 0
count_tv = 0
count_com = 0
count_iphon = 0
count_elec = 0
count_hair = 0
count_water = 0
 
# Connect MYSQL
conn= MySQLdb.connect("localhost","conn","hems","power")
c = conn.cursor()

# Read the data of lastest month 
####################################################  DATABASE + DAY
query0 = "SELECT Timestamp,old_watt,grid_consumption,watt FROM thesis.main1st WHERE Timestamp >= '2016-10-01 00:14:59' AND  Timestamp <= '2016-10-30 23:59:59';"
df = pd.read_sql(query0, conn)   
print "\n"
print "Total unit consumption in the last month equal to",df.watt.sum()/1000,"kW"
print "Total unit consumption in the last month equal to",df.old_watt.sum()/1000,"kW"
print "Total unit ""PEA OR GRID"" consumption in the last month equal to",df.grid_consumption.sum()/1000,"kW"
last_bill = bill(df.watt.sum()/1000,-0.048) 
last_bill_pv = bill(df.grid_consumption.sum()/1000,-0.048)    
print "The lastest elctrical bill is about",last_bill,"or",last_bill_pv,"bath with Ft = -0.048"
print "\n______________________________________________________________________________________________\n"
   
x = raw_input('What is about Ft in the next month?',)
Ft = float(x)
    
y = raw_input('How about expected price in electrical bill do you want?')
target_price = float(y)

print "\n______________________________________________________________________________________________"    
print "\nThe expected price in the next electrical bill is about",target_price,"bath with Ft =", Ft
discount = (last_bill-target_price)/last_bill *100
print "To compare with the lastest bill is equal to",round(discount,2),"% cut-off"
target_unit = inbill(target_price,Ft)
print "Total available unit consumption in the next month equal to",target_unit,"kW or unit"
print "______________________________________________________________________________________________\n"


# Show the priority of 15 appliances
name = ['refrigerator','wireless_router','aircont','computer','electrical_thermo','hair_dryer','microwave','iphone_charger','fan','tv','washing_machine','iron','rice_cooker','water_heater','light_system']
types = ['Type1 : always turn on [Dont control]','Type1 : always turn on','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday'
        ,'Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type3 : turn on manytime(1-3) in everyday','Type3 : turn on manytime(1-3) in everyday','Type4 : turn on oncetime in someday'
        ,'Type4 : turn on oncetime in someday','Type4 : turn on oncetime in someday','Type5 : turn on manytime(1-3) in someday','Type6 : monitor power consuming [Dont control]']
prior = ['x','x','1','4','6','7','9','5','2','3','12','11','10','9','x']
table = ListTable()
table.append(['the 15 appliances','Type of appliances','the priority'])
for i in xrange(15):
    x = name[i]
    y = types[i]
    z = prior[i]
    table.append([x, y ,z])
    
print "\n"

table
# Out:
# Total unit consumption in the last month equal to 372.8290459 kW
# Total unit consumption in the last month equal to 372.8290459 kW
# Total unit PEA OR GRID consumption in the last month equal to 310.250268702 kW
# The lastest elctrical bill is about 1549.71 or 1270.23 bath with Ft = -0.048
#
# ______________________________________________________________________________________________
# ______________________________________________________________________________________________
#
# The expected price in the next electrical bill is about 1500.0 bath with Ft = -0.048
# To compare with the lastest bill is equal to 3.21 % cut-off
# Total available unit consumption in the next month equal to 362.0 kW or unit
# ______________________________________________________________________________________________
# [['the 15 appliances', 'Type of appliances', 'the priority'],
#  ['refrigerator', 'Type1 : always turn on [Dont control]', 'x'],
#  ['wireless_router', 'Type1 : always turn on', 'x'],
#  ['aircont', 'Type2 : turn on oncetime&everyday', '1'],
#  ['computer', 'Type2 : turn on oncetime&everyday', '4'],
#  ['electrical_thermo', 'Type2 : turn on oncetime&everyday', '6'],
#  ['hair_dryer', 'Type2 : turn on oncetime&everyday', '7'],
#  ['microwave', 'Type2 : turn on oncetime&everyday', '9'],
#  ['iphone_charger', 'Type2 : turn on oncetime&everyday', '5'],
#  ['fan', 'Type3 : turn on manytime(1-3) in everyday', '2'],
#  ['tv', 'Type3 : turn on manytime(1-3) in everyday', '3'],
#  ['washing_machine', 'Type4 : turn on oncetime in someday', '12'],
#  ['iron', 'Type4 : turn on oncetime in someday', '11'],
#  ['rice_cooker', 'Type4 : turn on oncetime in someday', '10'],
#  ['water_heater', 'Type5 : turn on manytime(1-3) in someday', '9'],
#  ['light_system', 'Type6 : monitor power consuming [Dont control]', 'x']]

# %%
d = 32
####################################################
time_a_last = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-10-31 23:44:59', periods=96*d, freq='15T')
####################################################
time_a = pd.date_range('2016-11-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-11-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query_empty = """truncate table thesis.main""" 
c.execute(query_empty)
print "table thesis.main are Empty!!! \n"

query_last = "SELECT * FROM thesis.measure_15devices WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a_last[j],time_b_last[j])
df_last  = pd.read_sql(query_last, conn)

### DATABASE OPENING DEVICE *****
#################################################### DATABASE
query1 = "SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)

### DATABASE PV *****
#################################################### DAY
query = "SELECT Timestamp,PV FROM thesis.PV WHERE Timestamp>='%s'AND Timestamp<='%s'; "%('2016-11-01 00:00:00','2016-11-30 23:59:59')
df = pd.read_sql(query, conn)
df['PV'] = ((df.PV/10)*2)

while ( j <= (96*d) -1): # 1 month on OCTOBER

    print "data at :" , j
#     print j,
    print "______________________________________________________________________________________________\n",
#     query_last = "\nSELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s'; "%(time_a_last[j],time_b_last[j])
#     print query_last
#     df_last = pd.read_sql(query_last, conn)
#     conn.commit()
#     data_y = df_last['total_watt'].values.tolist()   
#     ans_fiting = fittingparameter(data_y,j)
    
#     query_last_new = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
#     query_last_new_1 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
#     print "______________________________________________________________________________________________"
#     print "\n",query_last_new  
#     print query_last_new_1
#     print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
#     df_last_new = pd.read_sql(query_last_new, conn)
#     conn.commit()
#     data_y = df_last_new['total_watt'].values.tolist()     
#     pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
#     pred_data = pred_h[len(pred_h)-(pred_no):]   
#     pred_watt = abs(pred_data[0])
#     target = pred_watt*(1-(discount/100))
#     print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
#     print "______________________________________________________________________________________________\n"
    if (df.PV[j] != 0):
        if (levelbatt[j] == maxbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]))
#                 sub = target - float(0)
                overpv = df.PV[j] - watt
                sum_overpv += overpv
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
#                     sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
#                     sub = target - lefted_batt     
                                           
        else:
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                charging_watt = df.PV[j] - watt
                missing_watt = maxbatt - levelbatt[j]
                if (charging_watt > missing_watt):
                    charging_watt = missing_watt *effi
                else:
                    charging_watt = charging_watt * effi 
                levelbatt.append(float(levelbatt[j]+(charging_watt)))
#                 sub = target - float(0)
                overpv = df.PV[j] - watt - charging_watt
                sum_overpv += overpv   
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
#                     sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
#                     sub = target - lefted_batt                          
    else :
        if (levelbatt[j] > minbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k 
            if (batt_t > watt):
                pv_consumption.append(float(0))
                batt_consumption.append(float(watt))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]-watt))
#                 sub = target - float(0)
            else:
                lefted_batt = watt - batt_t
                pv_consumption.append(float(0))
                batt_consumption.append(float(batt_t))
                grid_consumption.append(float(lefted_batt))
                levelbatt.append(float(levelbatt[j]-batt_t))
#                 sub = target - float(lefted_batt)                
        else:
            watt = df1.total_watt[j] - k 
            pv_consumption.append(float(0))
            batt_consumption.append(float(0))
            grid_consumption.append(float(watt))
            levelbatt.append(float(levelbatt[j]))
#             sub = target -  watt
            
    print "Consuming watt =",watt       
    print "PV_CONSUMPTION =",pv_consumption[j]
    print "BATT_CONSUMPTION =",batt_consumption[j]
    print "GRID_CONSUMPTION =",grid_consumption[j]
    print "PREVIOUS LEVELBATT =",levelbatt[j],"||| LEFTED LEVELBATT =",levelbatt[j+1]   
    print "PV GENERATION =",df.PV[j],"||| BATT_CHARGING =",charging_watt
    print "______________________________________________________________________________________________\n"
    
    
    print "||| 15 Minutes Lefted You Consumed power from ""PEA"" about",grid_consumption[j],"watt"   
    print "||| NOW YOUR ELECTRICAL BILL IS ABOUT",bill((sum(grid_consumption))/1000,Ft),"bath"   
    print "______________________________________________________________________________________________\n" 
   
       
    c.execute("INSERT INTO thesis.main (Timestamp, old_watt,PV_genarator , levelbatt ,pv_consumption , batt_consumption,grid_consumption,sum_load_watt,watt) VALUES ( %s,  %s,%s, %s, %s, %s,%s, %s, %s)",
              (time_b[j],df1.total_watt[j],df.PV[j],levelbatt[j],pv_consumption[j],batt_consumption[j],grid_consumption[j],pv_consumption[j]+batt_consumption[j]+grid_consumption[j],watt))
    conn.commit()  
  
    check_state = appliances(j) 
   
    c.execute("INSERT INTO thesis.measure_15devices (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt) VALUES ( %s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s)",
              (time_b[j],check_state[1],check_state[2],check_state[3]-ans_air,check_state[4]-ans_com,check_state[5]-ans_elec,check_state[6]-ans_hair,check_state[7],check_state[8]-ans_iphon,check_state[9]-ans_fan,check_state[10]--ans_tv,check_state[11],check_state[12],check_state[13],check_state[14]-ans_water,check_state[15],watt))               
    conn.commit()
    
    all_power.append(watt/1000)
    df_power = pd.DataFrame(all_power)

    ###   [Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt]
#     del check_state[13]   # del  rice_cooker
#     del check_state[12]   # del iron
#     del check_state[11]   # del washing_machine
#     del check_state[7]    # del microwave
#     del check_state[2]    # del wireless_router
#     del check_state[1]    # del refrigerator
#     del check_state[0]    # del Timestamp
#     del check_state[-1]   # del  total_watt
#     del check_state[-1]   # del light_system
#     ###   [ aircont, computer, elec_thermo, hair_dryer, iphonecharger,fan,tv, water_heater]
           
#     if j == 0:
#         sum_sub = sub       
#     else :
#         sum_sub = sum_sub + sub      
    
#     if sum_sub < 0: ##turn OFF devices 
#         print "\n_____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________ "
#         print "\n"
#         print "m_air =",check_state[0] , "m_fan=",check_state[5] , "m_tv =",check_state[6] , "m_com =",check_state[1] , "m_iphon =",check_state[4] , "m_elec=",check_state[2] , "m_hair=",check_state[3] , "m_water =",check_state[7]        
                
#         if  check_state[0] > 0 and trinker[0] == 0:  #air
#             m_air = end_air(j)-1
#             count_air += 1
            
#         elif  check_state[5] > 0 and trinker[5] == 0:        
#             m_fan = end_fan(j)-1
#             count_fan += 1
            
#         elif  check_state[6] > 0 and trinker[6] == 0:        
#             m_tv = end_tv(j)-1
#             count_tv += 1  
            
#         elif  check_state[1] > 0 and trinker[1] == 0:
#             m_com = end_com(j)-1          
#             count_com += 1 
            
#         elif  check_state[4] > 0 and trinker[4] == 0:        
#             m_iphon = end_iphon(j)-1
#             count_iphon += 1
            
#         elif  check_state[2] > 0 and trinker[2] == 0:
#             m_elec = end_elec(j)-1
#             count_elec += 1 
            
#         elif  check_state[3] > 0 and trinker[3] == 0:        
#             m_hair = end_hair(j)-1                    
#             count_hair += 1 
            
#         elif check_state[7] > 0 and trinker[7] == 0:        
#             m_water = end_water(j)-1
#             count_water += 1 
# #         else:
# #             print "No appliances"
            
#         if j <= m_air:
#             trinker[0] = 1
#         else :
#             trinker[0] = 0
            
#         if j <= m_com:
#              trinker[1] = 1
#         else :
#             trinker[1] = 0 
            
#         if j <= m_elec:
#              trinker[2] = 1 
#         else :
#             trinker[2] = 0  
            
#         if j <= m_hair:
#              trinker[3] = 1
#         else :
#             trinker[3] = 0  
            
#         if j <= m_iphon:
#              trinker[4] = 1 
#         else :
#             trinker[4] = 0  
            
#         if j <= m_fan:
#              trinker[5] = 1 
#         else :            
#             trinker[5] = 0  
            
#         if j <= m_tv:
#              trinker[6] = 1
#         else :
#             trinker[6] = 0
            
#         if j <= m_water:
#              trinker[7] = 1 
#         else :
#             trinker[7] = 0                
# #         print "             ",   m_air   , "           ",   m_fan  , "          ",    m_tv   , "             ",  m_com  , "               ", m_iphon , "            ", m_elec  , "            ",m_hair     , "               ",m_water                 
# #         print "             ",trinker[0] , "           ",trinker[5] , "         ",trinker[6] , "             ",trinker[7] , "               ",trinker[4] , "           ",trinker[2] , "            ",trinker[3] , "               ",trinker[7]                 
      
#         j += 1  
#         k = state(j,m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)
#         ans_air = k[0] 
#         ans_com = k[1] 
#         ans_elec = k[2] 
#         ans_hair = k[3] 
#         ans_iphon = k[4] 
#         ans_fan = k[5]
#         ans_tv = k[6] 
#         ans_water = k[7] 
#         k = k[8]          
#     else: 
#         print "\n______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________ "
#         j += 1
#         k = state(j, m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)  
#         ans_air = k[0] 
#         ans_com = k[1] 
#         ans_elec = k[2] 
#         ans_hair = k[3] 
#         ans_iphon = k[4] 
#         ans_fan = k[5]
#         ans_tv = k[6] 
#         ans_water = k[7] 
#         k = k[8]
    j += 1
    print "\n"              
    charging_watt = float(0)     
    print "                                                               -------------------------------------                                                            \n"
      
    while ( h < (len(df_power)/96) ) : 
        print """\n. . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .\n"""
#         print (k*24),"to",(k+1)*24
        sum_p =  df_power[(h*96):((h+1)*96)].sum()
        sum_power.append(sum_p)
        
        sum_pv = sum(pv_consumption[(h*96):((h+1)*96)])
        sum_pvconsumption.append(sum_pv/1000)
        
        sum_batt = sum(batt_consumption[(h*96):((h+1)*96)])
        sum_battconsumption.append(sum_batt/1000)
        
        sum_grid = sum(grid_consumption[(h*96):((h+1)*96)])
        sum_gridconsumption.append(sum_grid/1000)
        
        df_power2 = pd.DataFrame(sum_power)  
        df_power3 = pd.DataFrame(sum_pvconsumption)  
        df_power4 = pd.DataFrame(sum_battconsumption)  
        df_power5 = pd.DataFrame(sum_gridconsumption)           
        result = pd.concat([df_power2, df_power3, df_power4, df_power5], axis=1)
        result.columns = ['power consumption','From PV','From BATTERY','From PEA']
        print result
        print "Power consuming between" ,time_a[h*96], "to" ,time_b[(h+1)*96-1], "equal to", result.iloc[h]['power consumption']," kW. -->> equal to",bill(float(result.iloc[h]['From PEA']),Ft),"bath"
        print """///////////////////////////////////////////////////////////////////////////////////////////////////////////////\n"""
        h +=1 
         
print "-------------YOUR PROGRAM IS DONE-----------------"
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
# Out:
# table thesis.main are Empty!!!
#
# data at : 0
# ______________________________________________________________________________________________
# Consuming watt = 333.322
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 333.322
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 333.322 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 42.04 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'fan', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 1
# ______________________________________________________________________________________________
# Consuming watt = 333.973
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 333.973
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 333.973 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 43.18 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'fan', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2
# ______________________________________________________________________________________________
# Consuming watt = 330.859
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 330.859
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 330.859 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 44.31 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'fan', 'tv'] = 6 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 3
# ______________________________________________________________________________________________
# Consuming watt = 307.548
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 307.548
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 307.548 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 45.37 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'tv'] = 5 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 4
# ______________________________________________________________________________________________
# Consuming watt = 211.645
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 211.645
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 211.645 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 46.09 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'tv'] = 5 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 5
# ______________________________________________________________________________________________
# Consuming watt = 313.184
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 313.184
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 313.184 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.16 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 6
# ______________________________________________________________________________________________
# Consuming watt = 246.163
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 246.163
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 246.163 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 7
# ______________________________________________________________________________________________
# Consuming watt = 253.256
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 253.256
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 253.256 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.87 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 8
# ______________________________________________________________________________________________
# Consuming watt = 293.233
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 293.233
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 293.233 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 49.88 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 9
# ______________________________________________________________________________________________
# Consuming watt = 174.767
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 174.767
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 174.767 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.48 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 10
# ______________________________________________________________________________________________
# Consuming watt = 265.188
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 265.188
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 265.188 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.38 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 11
# ______________________________________________________________________________________________
# Consuming watt = 205.529
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 205.529
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 205.529 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 52.09 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 12
# ______________________________________________________________________________________________
# Consuming watt = 210.837
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 210.837
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 210.837 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 52.81 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 13
# ______________________________________________________________________________________________
# Consuming watt = 234.646
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 234.646
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 234.646 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 53.61 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 14
# ______________________________________________________________________________________________
# Consuming watt = 187.583
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 187.583
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 187.583 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.26 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 15
# ______________________________________________________________________________________________
# Consuming watt = 145.117
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 145.117
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 145.117 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.75 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 16
# ______________________________________________________________________________________________
# Consuming watt = 240.742
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 240.742
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 240.742 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 55.58 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 17
# ______________________________________________________________________________________________
# Consuming watt = 187.529
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 187.529
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 187.529 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 56.22 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 18
# ______________________________________________________________________________________________
# Consuming watt = 138.579
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 138.579
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 138.579 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 56.69 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 19
# ______________________________________________________________________________________________
# Consuming watt = 137.033
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 137.033
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 137.033 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 57.16 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 20
# ______________________________________________________________________________________________
# Consuming watt = 155.113
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 155.113
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 155.113 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 57.7 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 21
# ______________________________________________________________________________________________
# Consuming watt = 170.788
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 170.788
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 170.788 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.28 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 22
# ______________________________________________________________________________________________
# Consuming watt = 175.712
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 175.712
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 175.712 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.88 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 23
# ______________________________________________________________________________________________
# Consuming watt = 172.117
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 172.117
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 172.117 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 59.47 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 24
# ______________________________________________________________________________________________
# Consuming watt = 156.512
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 156.512
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 156.512 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 06:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 25
# ______________________________________________________________________________________________
# Consuming watt = 93.9625
# PV_CONSUMPTION = 0.3
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 93.6625
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.3 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 93.6625 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.33 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 06:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 26
# ______________________________________________________________________________________________
# Consuming watt = 40.35
# PV_CONSUMPTION = 3.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 37.35
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 3.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 37.35 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.46 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 06:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'tv'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 27
# ______________________________________________________________________________________________
# Consuming watt = 29.5875
# PV_CONSUMPTION = 6.1
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 23.4875
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 6.1 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 23.4875 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.54 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 06:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 28
# ______________________________________________________________________________________________
# Consuming watt = 29.2542
# PV_CONSUMPTION = 10.1
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 19.1542
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 10.1 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 19.1542 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.6 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 07:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 29
# ______________________________________________________________________________________________
# Consuming watt = 32.8583
# PV_CONSUMPTION = 12.1
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 20.7583
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 12.1 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 20.7583 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.67 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 07:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 30
# ______________________________________________________________________________________________
# Consuming watt = 30.0625
# PV_CONSUMPTION = 15.8
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 14.2625
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 15.8 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 14.2625 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.72 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 07:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 31
# ______________________________________________________________________________________________
# Consuming watt = 30.3542
# PV_CONSUMPTION = 15.6
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 14.7542
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 15.6 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 14.7542 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.77 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 07:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 32
# ______________________________________________________________________________________________
# Consuming watt = 31.2875
# PV_CONSUMPTION = 18.1
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 13.1875
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 18.1 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 13.1875 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.82 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 08:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 33
# ______________________________________________________________________________________________
# Consuming watt = 34.3667
# PV_CONSUMPTION = 26.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 8.3667
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 26.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 8.3667 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.85 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 08:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 34
# ______________________________________________________________________________________________
# Consuming watt = 34.2625
# PV_CONSUMPTION = 34.2625
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 600.964
# PV GENERATION = 56.1 ||| BATT_CHARGING = 20.964
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.85 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 08:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 35
# ______________________________________________________________________________________________
# Consuming watt = 104.933
# PV_CONSUMPTION = 60.4
# BATT_CONSUMPTION = 20.964
# GRID_CONSUMPTION = 23.569
# PREVIOUS LEVELBATT = 600.964 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 60.4 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 23.569 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.93 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 08:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 36
# ______________________________________________________________________________________________
# Consuming watt = 98.9958
# PV_CONSUMPTION = 84.2
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 14.7958
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 84.2 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 14.7958 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 09:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 37
# ______________________________________________________________________________________________
# Consuming watt = 48.475
# PV_CONSUMPTION = 48.475
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 614.296
# PV GENERATION = 84.2 ||| BATT_CHARGING = 34.296
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 09:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 38
# ______________________________________________________________________________________________
# Consuming watt = 28.95
# PV_CONSUMPTION = 28.95
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 614.296 ||| LEFTED LEVELBATT = 659.848
# PV GENERATION = 76.4 ||| BATT_CHARGING = 45.552
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 09:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 39
# ______________________________________________________________________________________________
# Consuming watt = 30.0542
# PV_CONSUMPTION = 30.0542
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 659.848 ||| LEFTED LEVELBATT = 675.923968
# PV GENERATION = 46.8 ||| BATT_CHARGING = 16.075968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 09:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 40
# ______________________________________________________________________________________________
# Consuming watt = 32.3083
# PV_CONSUMPTION = 32.3083
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 675.923968 ||| LEFTED LEVELBATT = 722.86
# PV GENERATION = 81.2 ||| BATT_CHARGING = 46.936032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 10:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 41
# ______________________________________________________________________________________________
# Consuming watt = 27.7625
# PV_CONSUMPTION = 27.7625
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 722.86 ||| LEFTED LEVELBATT = 797.584
# PV GENERATION = 105.6 ||| BATT_CHARGING = 74.724
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 10:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 42
# ______________________________________________________________________________________________
# Consuming watt = 26.8958
# PV_CONSUMPTION = 26.8958
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 797.584 ||| LEFTED LEVELBATT = 873.332032
# PV GENERATION = 105.8 ||| BATT_CHARGING = 75.748032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 10:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 43
# ______________________________________________________________________________________________
# Consuming watt = 29.0083
# PV_CONSUMPTION = 29.0083
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 873.332032 ||| LEFTED LEVELBATT = 941.580064
# PV GENERATION = 100.1 ||| BATT_CHARGING = 68.248032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 10:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 44
# ______________________________________________________________________________________________
# Consuming watt = 33.7167
# PV_CONSUMPTION = 33.7167
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 941.580064 ||| LEFTED LEVELBATT = 992.060032
# PV GENERATION = 86.3 ||| BATT_CHARGING = 50.479968
# ...
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1305.6 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 21:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2870
# ______________________________________________________________________________________________
# Consuming watt = 364.467
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 364.467
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 364.467 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1307.22 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 21:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2871
# ______________________________________________________________________________________________
# Consuming watt = 504.958
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 504.958
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 504.958 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1309.48 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 21:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2872
# ______________________________________________________________________________________________
# Consuming watt = 524.362
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 524.362
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 524.362 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1311.82 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 22:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2873
# ______________________________________________________________________________________________
# Consuming watt = 518.721
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 518.721
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 518.721 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1314.14 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 22:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2874
# ______________________________________________________________________________________________
# Consuming watt = 455.671
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 455.671
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 455.671 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1316.17 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 22:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2875
# ______________________________________________________________________________________________
# Consuming watt = 540.425
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 540.425
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 540.425 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1318.59 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 22:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'tv', 'water_heater', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2876
# ______________________________________________________________________________________________
# Consuming watt = 1013.84
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 1013.84
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 1013.84 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1323.11 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 23:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'tv', 'water_heater', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2877
# ______________________________________________________________________________________________
# Consuming watt = 1002.48
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 1002.48
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 1002.48 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1327.59 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 23:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'tv', 'water_heater', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2878
# ______________________________________________________________________________________________
# Consuming watt = 994.596
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 994.596
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 994.596 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1332.03 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 23:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'water_heater', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2879
# ______________________________________________________________________________________________
# Consuming watt = 697.15
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 697.15
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 697.15 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1335.15 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-30 23:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'water_heater', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
#
# . . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .
#
#     power consumption   From PV  From BATTERY   From PEA
# 0           12.495665  1.220579      0.990532  10.284554
# 1           14.252880  1.356671      0.971836  11.924373
# 2           12.216684  1.103725      0.206568  10.906391
# 3           11.720082  1.417685      0.650703   9.651695
# 4           10.800878  1.095917      1.064624   8.640337
# 5           13.529703  0.843038      0.435708  12.250958
# 6           12.315598  0.982375      0.160728  11.172495
# 7           14.419682  1.077975      0.439704  12.902003
# 8           15.319146  0.989109      0.568408  13.761630
# 9           13.063622  1.452667      0.826784  10.784172
# 10          11.942590  1.298295      0.702533   9.941762
# 11          13.878147  1.470887      1.047756  11.359503
# 12          12.261864  1.097317      0.948272  10.216275
# 13          13.855320  1.249712      1.248468  11.357139
# 14          11.962488  1.150963      1.159428   9.652097
# 15          11.745568  1.216754      1.513676   9.015138
# 16          10.873134  1.222687      1.542924   8.107523
# 17          15.892119  1.456690      1.037770  13.397659
# 18          12.867548  1.122763      0.618859  11.125926
# 19          15.639668  1.227738      0.668316  13.743615
# 20          16.108367  1.112446      0.364180  14.631741
# 21           8.590856  1.200621      1.284556   6.105679
# 22          13.305342  1.068171      0.646300  11.590871
# 23          12.810752  1.070488      0.757548  10.982716
# 24          13.295603  1.052193      0.614599  11.628811
# 25          10.839959  1.214103      0.872013   8.753843
# 26          14.059180  1.194258      1.480648  11.384274
# 27          11.232591  1.232258      0.539800   9.460532
# 28          10.309891  1.221812      1.449060   7.639018
# 29          14.840196  1.154596      1.272580  12.413020
# Power consuming between 2016-11-30 00:00:00 to 2016-11-30 23:59:59 equal to 14.8401956  kW. -->> equal to 83.4 bath
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# data at : 2880
# ______________________________________________________________________________________________
# KeyErrorTraceback (most recent call last)
# <ipython-input-4-7c64165dbd32> in <module>()
#      55 #     print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
#      56 #     print "______________________________________________________________________________________________\n"
# ---> 57     if (df.PV[j] != 0):
#      58         if (levelbatt[j] == maxbatt):
#      59             batt_t = levelbatt[j] - minbatt
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    2167         try:
#    2168             return self._engine.get_value(s, k,
# -> 2169                                           tz=getattr(series.dtype, 'tz', None))
#    2170         except KeyError as e1:
#    2171             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3567)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3250)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8555)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8499)()
#
# KeyError: 2880

# %%
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
print "control_air-cont (times) ="      , count_air
print "control_fan (times) ="           , count_fan
print "control_tv (times) ="            , count_tv
print "control_computer (times) ="      , count_com
print "control_iphone_charger (times) =", count_iphon
print "control_elec_thermo (times) ="   , count_elec
print "control_hair_dryer (times) ="    , count_hair
print "control_water_heater (times) ="  , count_water
print sum_overpv/1000
# Out:
# count_active = 0
# control_air-cont (times) = 0
# control_fan (times) = 0
# control_tv (times) = 0
# control_computer (times) = 0
# control_iphone_charger (times) = 0
# control_elec_thermo (times) = 0
# control_hair_dryer (times) = 0
# control_water_heater (times) = 0
# 1.086870016
