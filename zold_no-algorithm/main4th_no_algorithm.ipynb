# %% [markdown]
# ### main of month 4 : January (31 days)

# %% [markdown]
# ### EVERY TIME
# #### RESET DATABASE &  RESTART KERNAL & CLAER OUTPUT

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline 

from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
# ____________________________________________________________________________________________________   

'''
##  PRIORITY TABLE
'''
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
      
        return ''.join(html)
 # ____________________________________________________________________________________________________   
    
"""
## CONVERSING  UNIT (kW) >>  BILL (bath)
"""
def bill(allpow,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge
 
    ## Fundamental parameter      
    if allpow <= 0:
        bath = 0
    elif 0 <= allpow <= 150:
        bath = allpow*t1
    elif  151 <= allpow <= 400:
        power = allpow-150
        bath_1 = 150*t1
        bath_2 = power*t2
        bath = bath_1+bath_2
    else:
        power = allpow-150
        bath_1 = 150*t1
        power = power-250
        bath_2 = 250*t2
        bath_3 = power*t3
        bath = bath_1+bath_2+bath_3   
    service_price = 38.22  #permonth (fixed)   
    ## FT -33.2 satang/unit
    FT_price = allpow*Ft
    ## VAT 7%
    VAT_price = ((service_price+bath)+FT_price)*0.07
    bill = bath+service_price+FT_price+VAT_price
    return round(bill,2)
 # ____________________________________________________________________________________________________   

"""
## CONVERSING  BILL (bath) >>  UNIT (kW) >> 
"""
def inbill(bath,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge  
    u = symbols('u')
    test_1 = solve(Eq((u*t1)+ser+(u*Ft)+(0.07*((u*t1)+ser))+(0.07*(u*Ft)),bath))
    test_2 = solve(Eq((150*t1)+((u-150)*t2)+ser+(u*Ft)+(0.07*((150*t1)+((u-150)*t2)+ser))+(0.07*(u*Ft)),bath))
    test_3 = solve(Eq((150*t1)+(250*t2)+((u-400)*t3)+ser+(u*Ft)+(0.07*((150*t1)+(250*t2)+((u-400)*t3)+ser))+(0.07*(u*Ft)),bath))
    if 1 <=  test_1[0] <= 150:
        unit = test_1[0]
    elif 151 <=  test_2[0] <=  400:
        unit = test_2[0]
    else:
        unit = test_3[0]
    return (round(unit))
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The ENDING POSITION OF EACH APPLIANCES
"""
def end_air(j): 
    check = 1  
    m_air = j+1   
    while (check == 1):
        while df1.aircont[ m_air] > 0 and m_air < (96*31)-1:
            m_air += 1
        check = 0
    return  m_air

def end_com(j): 
    check = 1  
    m_com = j+1   
    while (check == 1):
        while df1.computer[m_com] > 0 and m_com < (96*31)-1:
            m_com += 1  
        check = 0
    return  m_com

def end_elec(j): 
    check = 1  
    m_elec = j+1   
    while (check == 1):
        while df1.elec_thermo[m_elec] > 0 and m_elec < (96*31)-1:
            m_elec += 1  
        check = 0
    return  m_elec

def end_hair(j): 
    check = 1  
    m_hair = j+1   
    while (check == 1):
        while df1.hair_dryer[m_hair] > 0 and m_hair < (96*31)-1:
            m_hair += 1  
        check = 0
    return  m_hair

def end_iphon(j): 
    check = 1  
    m_iphon = j+1   
    while (check == 1):
        while df1.iphonecharger[ m_iphon] > 0 and m_iphon < (96*31)-1:
            m_iphon += 1  
        check = 0
    return  m_iphon

def end_fan(j): 
    check = 1  
    m_fan = j+1   
    while (check == 1):
        while df1.fan[m_fan] > 0 and m_fan < (96*31)-1:
            m_fan += 1  
        check = 0
    return  m_fan

def end_tv(j): 
    check = 1  
    m_tv = j+1   
    while (check == 1):
        while df1.tv[m_tv] > 0 and m_tv < (96*31)-1 :
            m_tv += 1  
        check = 0
    return  m_tv

def end_water(j): 
    check = 1  
    m_water = j+1   
    while (check == 1):
        while df1.water_heater[m_water] > 0 and m_water < (96*31)-1:
            m_water += 1  
        check = 0
    return  m_water
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The STATE OF APPLIANCES 
"""    
def state(j,m_air,m_com, m_elec,m_hair,m_iphon, m_fan ,m_tv, m_water) :
    if j <= m_air:
        ans1 = 18    
    else:
        ans1 = 0
    if j <= m_com:
        ans2 = df1.computer[j]
    else:
        ans2 = 0
    if j <= m_elec:
        ans3 = df1.elec_thermo[j]
    else:
        ans3 = 0
    if j <= m_hair:
        ans4 = df1.hair_dryer[j]
    else:
        ans4 = 0
    if j <= m_iphon:
        ans5 = df1.iphonecharger[j]
    else:
        ans5 = 0
    if j <= m_fan:
        ans6 = df1.fan[j]
    else:
        ans6 = 0
    if j <= m_tv:
        ans7 = df1.tv[j]
    else:
        ans7 = 0
    if j <= m_water:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0

    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8
#     print "substact k watt out from watt = ",k,"watt    ||||||" ,ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8
    return (ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8,k) 
 # ____________________________________________________________________________________________________   

"""
## PREDICTION 
"""        
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
 # ____________________________________________________________________________________________________   

"""
## FITTING PARAMETERS FOR PREDICTION
""" 
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []    
    ##############################################################
    ### ??????????????????????????????????????????????????????????
    query_last = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query_last
    df1 = pd.read_sql(query_last, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data,96*7,alpha,beta,gamma,pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print "the minimum MSE of prediction =",MSE_min,"by alpha =",alpha,"beta =",beta,"gamma =",gamma
    return (alpha,beta,gamma)
 # ____________________________________________________________________________________________________   

"""
## CHECKING THE STATUS OF APPLIANCES ON THAT TIME
""" 
def appliances(j):
    ############################################################## (day + table_database)
    ### ??????????????????????????????????????????????????????????
    time_b = pd.date_range('2017-01-01 00:14:59', periods=96*d, freq='15T')
    conn = MySQLdb.connect("localhost","conn","hems")
    c = conn.cursor()
    query1 = "SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '%s'; "% (time_b[j])
    print "Check status of appliances from"
    print query1
    df1 = pd.read_sql(query1, conn) 
    
    for row in df1.iterrows():
        index, data = row
        state = data.tolist()
    i = 1
    status = []
    while(i < len(state)-1):
        dict = { 1:'refrigerator',2:'wireless_router',3:'aircont',4:'computer',5:'electrical_thermo',6:'hair_dryer',7:'microwave',8:'iphone_charger',9:'fan',10:'tv'
                ,11:'washing_machine',12:'iron',13:'rice_cooker',14:'water_heater',15:'light_system'}
        if state[i] != 0:
            a = dict[i]
            status.append(a)
        i +=1  
    print "NOW !! you are turning ON" ,status ,"=",len(status),"items"
    print "______________________________________________________________________________________________\n"
    return(state)
 # ____________________________________________________________________________________________________

# %%
# Set paremeters
j = 0
d = 32   ################################
pred_no = 1
z  = 0 
trinker = [0,0,0,0,0,0,0,0]
batt = float(2.900*1000)     ## SIZE OF BATTERY  2.9 kW 
k = 0
all_power = []
sum_power = []
sum_p = []
sum_pv = []
sum_pvconsumption = []
sum_batt = []
sum_battconsumption = []
sum_grid= []
sum_gridconsumption = []
h = 0

ans_air = 0 
ans_com = 0 
ans_elec = 0 
ans_hair = 0 
ans_iphon = 0 
ans_fan = 0
ans_tv = 0
ans_water = 0
m_air = 0
m_com = 0
m_elec = 0
m_hair = 0
m_iphon = 0
m_fan = 0
m_tv = 0   
m_water = 0
minbatt = batt * 0.2        ## PERIOD OF  BATTERY  USING  2.9*0.2 = 580 - 2900
maxbatt = batt
effi = float(0.96)            ##  EFFICIENTCY OF CHARGING  BATTERY  = 96%
levelbatt = []
levelbatt.append(float(580))  ####################################################
pv_consumption = []
batt_consumption = []
grid_consumption = []
overpv = float(0)
sum_overpv = float(0)
charging_watt = float(0)
count_active = 0 

count_air = 0
count_fan = 0
count_tv = 0
count_com = 0
count_iphon = 0
count_elec = 0
count_hair = 0
count_water = 0
 
# Connect MYSQL
conn= MySQLdb.connect("localhost","conn","hems","power")
c = conn.cursor()

# Read the data of lastest month 
####################################################  DATABASE + DAY
query0 = "SELECT Timestamp,old_watt,grid_consumption,watt FROM thesis.main3rd_no_algorithm WHERE Timestamp >= '2016-12-01 00:14:59' AND  Timestamp <= '2016-12-31 23:59:59';"
df = pd.read_sql(query0, conn)   
print "\n"
print "Total unit consumption in the last month equal to",df.watt.sum()/1000,"kW"
print "Total unit consumption in the last month equal to",df.old_watt.sum()/1000,"kW"
print "Total unit ""PEA OR GRID"" consumption in the last month equal to",df.grid_consumption.sum()/1000,"kW"
last_bill = bill(df.watt.sum()/1000,-0.048) 
last_bill_pv = bill(df.grid_consumption.sum()/1000,-0.048)    
print "The lastest elctrical bill is about",last_bill,"or",last_bill_pv,"bath with Ft = -0.048"
print "\n______________________________________________________________________________________________\n"
   
x = raw_input('What is about Ft in the next month?',)
Ft = float(x)
    
y = raw_input('How about expected price in electrical bill do you want?')
target_price = float(y)

print "\n______________________________________________________________________________________________"    
print "\nThe expected price in the next electrical bill is about",target_price,"bath with Ft =", Ft
discount = (last_bill-target_price)/last_bill *100
print "To compare with the lastest bill is equal to",round(discount,2),"% cut-off"
target_unit = inbill(target_price,Ft)
print "Total available unit consumption in the next month equal to",target_unit,"kW or unit"
print "______________________________________________________________________________________________\n"


# Show the priority of 15 appliances
name = ['refrigerator','wireless_router','aircont','computer','electrical_thermo','hair_dryer','microwave','iphone_charger','fan','tv','washing_machine','iron','rice_cooker','water_heater','light_system']
types = ['Type1 : always turn on [Dont control]','Type1 : always turn on','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday'
        ,'Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type3 : turn on manytime(1-3) in everyday','Type3 : turn on manytime(1-3) in everyday','Type4 : turn on oncetime in someday'
        ,'Type4 : turn on oncetime in someday','Type4 : turn on oncetime in someday','Type5 : turn on manytime(1-3) in someday','Type6 : monitor power consuming [Dont control]']
prior = ['x','x','1','4','6','7','9','5','2','3','12','11','10','9','x']
table = ListTable()
table.append(['the 15 appliances','Type of appliances','the priority'])
for i in xrange(15):
    x = name[i]
    y = types[i]
    z = prior[i]
    table.append([x, y ,z])
    
print "\n"

table
# Out:
# Total unit consumption in the last month equal to 404.8734149 kW
# Total unit consumption in the last month equal to 404.8734149 kW
# Total unit PEA OR GRID consumption in the last month equal to 341.361137806 kW
# The lastest elctrical bill is about 1693.86 or 1409.17 bath with Ft = -0.048
#
# ______________________________________________________________________________________________
# ______________________________________________________________________________________________
#
# The expected price in the next electrical bill is about 1500.0 bath with Ft = -0.048
# To compare with the lastest bill is equal to 11.44 % cut-off
# Total available unit consumption in the next month equal to 362.0 kW or unit
# ______________________________________________________________________________________________
# [['the 15 appliances', 'Type of appliances', 'the priority'],
#  ['refrigerator', 'Type1 : always turn on [Dont control]', 'x'],
#  ['wireless_router', 'Type1 : always turn on', 'x'],
#  ['aircont', 'Type2 : turn on oncetime&everyday', '1'],
#  ['computer', 'Type2 : turn on oncetime&everyday', '4'],
#  ['electrical_thermo', 'Type2 : turn on oncetime&everyday', '6'],
#  ['hair_dryer', 'Type2 : turn on oncetime&everyday', '7'],
#  ['microwave', 'Type2 : turn on oncetime&everyday', '9'],
#  ['iphone_charger', 'Type2 : turn on oncetime&everyday', '5'],
#  ['fan', 'Type3 : turn on manytime(1-3) in everyday', '2'],
#  ['tv', 'Type3 : turn on manytime(1-3) in everyday', '3'],
#  ['washing_machine', 'Type4 : turn on oncetime in someday', '12'],
#  ['iron', 'Type4 : turn on oncetime in someday', '11'],
#  ['rice_cooker', 'Type4 : turn on oncetime in someday', '10'],
#  ['water_heater', 'Type5 : turn on manytime(1-3) in someday', '9'],
#  ['light_system', 'Type6 : monitor power consuming [Dont control]', 'x']]

# %%
d = 32
####################################################
time_a_last = pd.date_range('2016-12-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-12-31 23:44:59', periods=96*d, freq='15T')
####################################################
time_a = pd.date_range('2017-01-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2017-01-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query_empty = """truncate table thesis.main""" 
c.execute(query_empty)
print "table thesis.main are Empty!!! \n"

query_last = "SELECT * FROM thesis.measure_15devices WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a_last[j],time_b_last[j])
df_last  = pd.read_sql(query_last, conn)

### DATABASE OPENING DEVICE *****
#################################################### DATABASE
query1 = "SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)

### DATABASE PV *****
#################################################### DAY
query = "SELECT Timestamp,PV FROM thesis.PV WHERE Timestamp>='%s'AND Timestamp<='%s'; "%('2017-01-01 00:00:00','2017-01-31 23:59:59')
df = pd.read_sql(query, conn)
df['PV'] = ((df.PV/10)*2)

while ( j <= (96*d) -1): # 1 month on OCTOBER

    print "data at :" , j
#     print j,
    print "______________________________________________________________________________________________\n",
#     query_last = "\nSELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s'; "%(time_a_last[j],time_b_last[j])
#     print query_last
#     df_last = pd.read_sql(query_last, conn)
#     conn.commit()
#     data_y = df_last['total_watt'].values.tolist()   
#     ans_fiting = fittingparameter(data_y,j)
    
#     query_last_new = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
#     query_last_new_1 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
#     print "______________________________________________________________________________________________"
#     print "\n",query_last_new  
#     print query_last_new_1
#     print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
#     df_last_new = pd.read_sql(query_last_new, conn)
#     conn.commit()
#     data_y = df_last_new['total_watt'].values.tolist()     
#     pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
#     pred_data = pred_h[len(pred_h)-(pred_no):]   
#     pred_watt = abs(pred_data[0])
#     target = pred_watt*(1-(discount/100))
#     print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
#     print "______________________________________________________________________________________________\n"
    if (df.PV[j] != 0):
        if (levelbatt[j] == maxbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]))
#                 sub = target - float(0)
                overpv = df.PV[j] - watt
                sum_overpv += overpv
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
#                     sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
#                     sub = target - lefted_batt     
                                           
        else:
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                charging_watt = df.PV[j] - watt
                missing_watt = maxbatt - levelbatt[j]
                if (charging_watt > missing_watt):
                    charging_watt = missing_watt *effi
                else:
                    charging_watt = charging_watt * effi 
                levelbatt.append(float(levelbatt[j]+(charging_watt)))
#                 sub = target - float(0)
                overpv = df.PV[j] - watt - charging_watt
                sum_overpv += overpv   
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
#                     sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
#                     sub = target - lefted_batt                          
    else :
        if (levelbatt[j] > minbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k 
            if (batt_t > watt):
                pv_consumption.append(float(0))
                batt_consumption.append(float(watt))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]-watt))
#                 sub = target - float(0)
            else:
                lefted_batt = watt - batt_t
                pv_consumption.append(float(0))
                batt_consumption.append(float(batt_t))
                grid_consumption.append(float(lefted_batt))
                levelbatt.append(float(levelbatt[j]-batt_t))
#                 sub = target - float(lefted_batt)                
        else:
            watt = df1.total_watt[j] - k 
            pv_consumption.append(float(0))
            batt_consumption.append(float(0))
            grid_consumption.append(float(watt))
            levelbatt.append(float(levelbatt[j]))
#             sub = target -  watt
            
    print "Consuming watt =",watt       
    print "PV_CONSUMPTION =",pv_consumption[j]
    print "BATT_CONSUMPTION =",batt_consumption[j]
    print "GRID_CONSUMPTION =",grid_consumption[j]
    print "PREVIOUS LEVELBATT =",levelbatt[j],"||| LEFTED LEVELBATT =",levelbatt[j+1]   
    print "PV GENERATION =",df.PV[j],"||| BATT_CHARGING =",charging_watt
    print "______________________________________________________________________________________________\n"
    
    
    print "||| 15 Minutes Lefted You Consumed power from ""PEA"" about",grid_consumption[j],"watt"   
    print "||| NOW YOUR ELECTRICAL BILL IS ABOUT",bill((sum(grid_consumption))/1000,Ft),"bath"   
    print "______________________________________________________________________________________________\n" 
   
       
    c.execute("INSERT INTO thesis.main (Timestamp, old_watt,PV_genarator , levelbatt ,pv_consumption , batt_consumption,grid_consumption,sum_load_watt,watt) VALUES ( %s,  %s,%s, %s, %s, %s,%s, %s, %s)",
              (time_b[j],df1.total_watt[j],df.PV[j],levelbatt[j],pv_consumption[j],batt_consumption[j],grid_consumption[j],pv_consumption[j]+batt_consumption[j]+grid_consumption[j],watt))
    conn.commit()  
  
    check_state = appliances(j) 
   
    c.execute("INSERT INTO thesis.measure_15devices (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt) VALUES ( %s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s)",
              (time_b[j],check_state[1],check_state[2],check_state[3]-ans_air,check_state[4]-ans_com,check_state[5]-ans_elec,check_state[6]-ans_hair,check_state[7],check_state[8]-ans_iphon,check_state[9]-ans_fan,check_state[10]--ans_tv,check_state[11],check_state[12],check_state[13],check_state[14]-ans_water,check_state[15],watt))               
    conn.commit()
    
    all_power.append(watt/1000)
    df_power = pd.DataFrame(all_power)

    ###   [Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt]
#     del check_state[13]   # del  rice_cooker
#     del check_state[12]   # del iron
#     del check_state[11]   # del washing_machine
#     del check_state[7]    # del microwave
#     del check_state[2]    # del wireless_router
#     del check_state[1]    # del refrigerator
#     del check_state[0]    # del Timestamp
#     del check_state[-1]   # del  total_watt
#     del check_state[-1]   # del light_system
#     ###   [ aircont, computer, elec_thermo, hair_dryer, iphonecharger,fan,tv, water_heater]
           
#     if j == 0:
#         sum_sub = sub       
#     else :
#         sum_sub = sum_sub + sub      
    
#     if sum_sub < 0: ##turn OFF devices 
#         print "\n_____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________ "
#         print "\n"
#         print "m_air =",check_state[0] , "m_fan=",check_state[5] , "m_tv =",check_state[6] , "m_com =",check_state[1] , "m_iphon =",check_state[4] , "m_elec=",check_state[2] , "m_hair=",check_state[3] , "m_water =",check_state[7]        
                
#         if  check_state[0] > 0 and trinker[0] == 0:  #air
#             m_air = end_air(j)-1
#             count_air += 1
            
#         elif  check_state[5] > 0 and trinker[5] == 0:        
#             m_fan = end_fan(j)-1
#             count_fan += 1
            
#         elif  check_state[6] > 0 and trinker[6] == 0:        
#             m_tv = end_tv(j)-1
#             count_tv += 1  
            
#         elif  check_state[1] > 0 and trinker[1] == 0:
#             m_com = end_com(j)-1          
#             count_com += 1 
            
#         elif  check_state[4] > 0 and trinker[4] == 0:        
#             m_iphon = end_iphon(j)-1
#             count_iphon += 1
            
#         elif  check_state[2] > 0 and trinker[2] == 0:
#             m_elec = end_elec(j)-1
#             count_elec += 1 
            
#         elif  check_state[3] > 0 and trinker[3] == 0:        
#             m_hair = end_hair(j)-1                    
#             count_hair += 1 
            
#         elif check_state[7] > 0 and trinker[7] == 0:        
#             m_water = end_water(j)-1
#             count_water += 1 
# #         else:
# #             print "No appliances"
            
#         if j <= m_air:
#             trinker[0] = 1
#         else :
#             trinker[0] = 0
            
#         if j <= m_com:
#              trinker[1] = 1
#         else :
#             trinker[1] = 0 
            
#         if j <= m_elec:
#              trinker[2] = 1 
#         else :
#             trinker[2] = 0  
            
#         if j <= m_hair:
#              trinker[3] = 1
#         else :
#             trinker[3] = 0  
            
#         if j <= m_iphon:
#              trinker[4] = 1 
#         else :
#             trinker[4] = 0  
            
#         if j <= m_fan:
#              trinker[5] = 1 
#         else :            
#             trinker[5] = 0  
            
#         if j <= m_tv:
#              trinker[6] = 1
#         else :
#             trinker[6] = 0
            
#         if j <= m_water:
#              trinker[7] = 1 
#         else :
#             trinker[7] = 0                
# #         print "             ",   m_air   , "           ",   m_fan  , "          ",    m_tv   , "             ",  m_com  , "               ", m_iphon , "            ", m_elec  , "            ",m_hair     , "               ",m_water                 
# #         print "             ",trinker[0] , "           ",trinker[5] , "         ",trinker[6] , "             ",trinker[7] , "               ",trinker[4] , "           ",trinker[2] , "            ",trinker[3] , "               ",trinker[7]                 
      
#         j += 1  
#         k = state(j,m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)
#         ans_air = k[0] 
#         ans_com = k[1] 
#         ans_elec = k[2] 
#         ans_hair = k[3] 
#         ans_iphon = k[4] 
#         ans_fan = k[5]
#         ans_tv = k[6] 
#         ans_water = k[7] 
#         k = k[8]          
#     else: 
#         print "\n______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________ "
#         j += 1
#         k = state(j, m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)  
#         ans_air = k[0] 
#         ans_com = k[1] 
#         ans_elec = k[2] 
#         ans_hair = k[3] 
#         ans_iphon = k[4] 
#         ans_fan = k[5]
#         ans_tv = k[6] 
#         ans_water = k[7] 
#         k = k[8]
    j += 1
    print "\n"              
    charging_watt = float(0)     
    print "                                                               -------------------------------------                                                            \n"
      
    while ( h < (len(df_power)/96) ) : 
        print """\n. . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .\n"""
#         print (k*24),"to",(k+1)*24
        sum_p =  df_power[(h*96):((h+1)*96)].sum()
        sum_power.append(sum_p)
        
        sum_pv = sum(pv_consumption[(h*96):((h+1)*96)])
        sum_pvconsumption.append(sum_pv/1000)
        
        sum_batt = sum(batt_consumption[(h*96):((h+1)*96)])
        sum_battconsumption.append(sum_batt/1000)
        
        sum_grid = sum(grid_consumption[(h*96):((h+1)*96)])
        sum_gridconsumption.append(sum_grid/1000)
        
        df_power2 = pd.DataFrame(sum_power)  
        df_power3 = pd.DataFrame(sum_pvconsumption)  
        df_power4 = pd.DataFrame(sum_battconsumption)  
        df_power5 = pd.DataFrame(sum_gridconsumption)           
        result = pd.concat([df_power2, df_power3, df_power4, df_power5], axis=1)
        result.columns = ['power consumption','From PV','From BATTERY','From PEA']
        print result
        print "Power consuming between" ,time_a[h*96], "to" ,time_b[(h+1)*96-1], "equal to", result.iloc[h]['power consumption']," kW. -->> equal to",bill(float(result.iloc[h]['From PEA']),Ft),"bath"
        print """///////////////////////////////////////////////////////////////////////////////////////////////////////////////\n"""
        h +=1 
         
print "-------------YOUR PROGRAM IS DONE-----------------"
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
# Out:
# table thesis.main are Empty!!!
#
# data at : 0
# ______________________________________________________________________________________________
# Consuming watt = 320.362
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 320.362
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 320.362 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 41.99 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 00:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv', 'light_system'] = 5 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 1
# ______________________________________________________________________________________________
# Consuming watt = 323.91
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 323.91
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 323.91 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 43.1 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 00:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv', 'light_system'] = 5 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2
# ______________________________________________________________________________________________
# Consuming watt = 310.282
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 310.282
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 310.282 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 44.16 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 00:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv', 'light_system'] = 5 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 3
# ______________________________________________________________________________________________
# Consuming watt = 302.75
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 302.75
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 302.75 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 45.2 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 00:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'light_system'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 4
# ______________________________________________________________________________________________
# Consuming watt = 298.077
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 298.077
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 298.077 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 46.22 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 01:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 5
# ______________________________________________________________________________________________
# Consuming watt = 297.632
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 297.632
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 297.632 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.24 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 01:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 6
# ______________________________________________________________________________________________
# Consuming watt = 294.571
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 294.571
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 294.571 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.25 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 01:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 7
# ______________________________________________________________________________________________
# Consuming watt = 296.173
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 296.173
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 296.173 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 49.26 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 01:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 8
# ______________________________________________________________________________________________
# Consuming watt = 293.979
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 293.979
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 293.979 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.27 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 02:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 9
# ______________________________________________________________________________________________
# Consuming watt = 291.188
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 291.188
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 291.188 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.27 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 02:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 10
# ______________________________________________________________________________________________
# Consuming watt = 301.09
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 301.09
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 301.09 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 52.3 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 02:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 11
# ______________________________________________________________________________________________
# Consuming watt = 297.047
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 297.047
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 297.047 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 53.32 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 02:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 12
# ______________________________________________________________________________________________
# Consuming watt = 297.632
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 297.632
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 297.632 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.34 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 03:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 13
# ______________________________________________________________________________________________
# Consuming watt = 296.857
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 296.857
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 296.857 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 55.35 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 03:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 14
# ______________________________________________________________________________________________
# Consuming watt = 300.53
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 300.53
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 300.53 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 56.38 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 03:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 15
# ______________________________________________________________________________________________
# Consuming watt = 290.139
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 290.139
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 290.139 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 57.37 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 03:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 16
# ______________________________________________________________________________________________
# Consuming watt = 294.575
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 294.575
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 294.575 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.38 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 04:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 17
# ______________________________________________________________________________________________
# Consuming watt = 296.948
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 296.948
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 296.948 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 59.4 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 04:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 18
# ______________________________________________________________________________________________
# Consuming watt = 296.101
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 296.101
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 296.101 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.41 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 04:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 19
# ______________________________________________________________________________________________
# Consuming watt = 296.99
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 296.99
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 296.99 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 61.43 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 04:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 20
# ______________________________________________________________________________________________
# Consuming watt = 294.244
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 294.244
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 294.244 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 62.44 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 05:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 21
# ______________________________________________________________________________________________
# Consuming watt = 193.984
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 193.984
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 193.984 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.1 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 05:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 22
# ______________________________________________________________________________________________
# Consuming watt = 34.0958
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 34.0958
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 34.0958 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.22 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 05:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 23
# ______________________________________________________________________________________________
# Consuming watt = 31.2917
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.2917
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 31.2917 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.33 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 05:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 24
# ______________________________________________________________________________________________
# Consuming watt = 31.2583
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.2583
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 31.2583 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.43 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 06:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 25
# ______________________________________________________________________________________________
# Consuming watt = 32.4708
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 32.4708
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 32.4708 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.55 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 06:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 26
# ______________________________________________________________________________________________
# Consuming watt = 28.4292
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 28.4292
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 28.4292 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.64 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 06:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 27
# ______________________________________________________________________________________________
# Consuming watt = 31.0583
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.0583
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 31.0583 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.75 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 06:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 28
# ______________________________________________________________________________________________
# Consuming watt = 31.6792
# PV_CONSUMPTION = 2.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 29.6792
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 2.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 29.6792 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.85 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 07:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 29
# ______________________________________________________________________________________________
# Consuming watt = 42.3125
# PV_CONSUMPTION = 4.5
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 37.8125
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 4.5 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 37.8125 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 07:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'fan'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 30
# ______________________________________________________________________________________________
# Consuming watt = 164.008
# PV_CONSUMPTION = 6.8
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 157.208
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 6.8 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 157.208 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.52 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 07:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo', 'fan'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 31
# ______________________________________________________________________________________________
# Consuming watt = 67.4375
# PV_CONSUMPTION = 12.3
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 55.1375
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 12.3 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 55.1375 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.71 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 07:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo', 'fan'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 32
# ______________________________________________________________________________________________
# Consuming watt = 65.5583
# PV_CONSUMPTION = 14.9
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 50.6583
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 14.9 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 50.6583 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.88 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 08:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo', 'fan'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 33
# ______________________________________________________________________________________________
# Consuming watt = 34.3167
# PV_CONSUMPTION = 19.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 15.3167
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 19.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 15.3167 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.93 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 08:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo', 'fan'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 34
# ______________________________________________________________________________________________
# Consuming watt = 30.325
# PV_CONSUMPTION = 22.2
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 8.125
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 22.2 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 8.125 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.96 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 08:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 35
# ______________________________________________________________________________________________
# Consuming watt = 32.0958
# PV_CONSUMPTION = 22.6
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 9.4958
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 22.6 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 9.4958 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.99 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 08:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 36
# ______________________________________________________________________________________________
# Consuming watt = 31.5917
# PV_CONSUMPTION = 26.1
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 5.4917
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 26.1 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 5.4917 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 65.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 09:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 37
# ______________________________________________________________________________________________
# Consuming watt = 28.3625
# PV_CONSUMPTION = 28.3625
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 592.9
# PV GENERATION = 41.8 ||| BATT_CHARGING = 12.9
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 65.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 09:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 38
# ______________________________________________________________________________________________
# Consuming watt = 32.0
# PV_CONSUMPTION = 32.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 592.9 ||| LEFTED LEVELBATT = 609.22
# PV GENERATION = 49.0 ||| BATT_CHARGING = 16.32
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 65.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 09:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 39
# ______________________________________________________________________________________________
# Consuming watt = 31.625
# PV_CONSUMPTION = 31.625
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 609.22 ||| LEFTED LEVELBATT = 647.788
# PV GENERATION = 71.8 ||| BATT_CHARGING = 38.568
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 65.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 09:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 40
# ______________________________________________________________________________________________
# Consuming watt = 587.754
# PV_CONSUMPTION = 74.7
# BATT_CONSUMPTION = 67.788
# GRID_CONSUMPTION = 445.266
# PREVIOUS LEVELBATT = 647.788 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 74.7 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 445.266 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 66.54 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 10:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'water_heater', 'light_system'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 41
# ______________________________________________________________________________________________
# Consuming watt = 206.621
# PV_CONSUMPTION = 78.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 128.621
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 78.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 128.621 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 66.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 10:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'water_heater', 'light_system'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 42
# ______________________________________________________________________________________________
# Consuming watt = 31.5875
# PV_CONSUMPTION = 31.5875
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 629.164
# PV GENERATION = 82.8 ||| BATT_CHARGING = 49.164
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 66.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 10:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 43
# ______________________________________________________________________________________________
# Consuming watt = 33.975
# PV_CONSUMPTION = 33.975
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 629.164 ||| LEFTED LEVELBATT = 670.276
# PV GENERATION = 76.8 ||| BATT_CHARGING = 41.112
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 66.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-01 10:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 44
# ______________________________________________________________________________________________
# Consuming watt = 33.8917
# PV_CONSUMPTION = 33.8917
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 670.276 ||| LEFTED LEVELBATT = 705.995968
# PV GENERATION = 71.1 ||| BATT_CHARGING = 35.719968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ...
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 246.353768 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1382.59 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 21:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'fan', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2966
# ______________________________________________________________________________________________
# Consuming watt = 513.892
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 513.892
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 513.892 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1384.89 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 21:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'fan', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2967
# ______________________________________________________________________________________________
# Consuming watt = 398.962
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 398.962
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 398.962 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1386.67 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 21:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'fan', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2968
# ______________________________________________________________________________________________
# Consuming watt = 339.292
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 339.292
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 339.292 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1388.19 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 22:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'fan', 'light_system'] = 6 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2969
# ______________________________________________________________________________________________
# Consuming watt = 344.179
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 344.179
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 344.179 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1389.72 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 22:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'fan', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2970
# ______________________________________________________________________________________________
# Consuming watt = 348.275
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 348.275
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 348.275 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1391.28 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 22:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'fan', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2971
# ______________________________________________________________________________________________
# Consuming watt = 334.071
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 334.071
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 334.071 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1392.77 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 22:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2972
# ______________________________________________________________________________________________
# Consuming watt = 337.875
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 337.875
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 337.875 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1394.28 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 23:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2973
# ______________________________________________________________________________________________
# Consuming watt = 280.867
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 280.867
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 280.867 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1395.53 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 23:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2974
# ______________________________________________________________________________________________
# Consuming watt = 339.983
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 339.983
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 339.983 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1397.05 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 23:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2975
# ______________________________________________________________________________________________
# Consuming watt = 325.217
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 325.217
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 325.217 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1398.5 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month4 WHERE  Timestamp = '2017-01-31 23:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'tv', 'light_system'] = 6 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
#
# . . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .
#
#     power consumption   From PV  From BATTERY   From PEA
# 0           16.810975  1.190540      0.726490  14.893945
# 1           11.723955  1.071746      1.078516   9.573694
# 2           11.842693  1.049742      0.590360  10.202591
# 3           13.938062  1.123013      0.453732  12.361318
# 4           11.226805  0.936367      0.545792   9.744646
# 5           11.028184  0.809171      0.285148   9.933865
# 6           12.262218  0.887408      0.326152  11.048657
# 7           14.707092  0.507392      0.002120  14.197580
# 8           16.557149  0.586117      0.027920  15.943112
# 9            8.024999  0.649113      0.037812   7.338075
# 10          13.799784  1.164746      0.913300  11.721738
# 11           9.327790  1.190658      0.967048   7.170084
# 12          14.058853  1.123250      0.464784  12.470819
# 13          14.328483  1.217529      1.038116  12.072838
# 14          12.857138  1.272729      0.925796  10.658613
# 15          11.378011  1.099267      1.164128   9.114617
# 16          15.055863  0.952833      0.183040  13.919990
# 17          13.124109  1.131675      1.373304  10.619130
# 18          13.042020  1.141233      1.318624  10.582162
# 19           9.932352  1.346906      1.290523   7.294924
# 20          14.229041  1.209629      1.321220  11.698192
# 21          12.758093  1.633565      1.070817  10.053710
# 22          15.202555  1.106308      0.996568  13.099678
# 23          10.720593  1.151363      1.256772   8.312458
# 24          15.024496  1.144513      0.997428  12.882556
# 25          14.114300  1.119771      0.835996  12.158533
# 26          11.485251  1.206450      1.533264   8.745537
# 27          14.590615  1.235105      1.412635  11.942875
# 28          13.808441  1.294787      1.156716  11.356937
# 29          12.003398  1.141833      1.235296   9.626269
# 30          10.870037  1.208283      1.428496   8.233257
# Power consuming between 2017-01-31 00:00:00 to 2017-01-31 23:59:59 equal to 10.8700368  kW. -->> equal to 69.09 bath
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# data at : 2976
# ______________________________________________________________________________________________
# KeyErrorTraceback (most recent call last)
# <ipython-input-4-3ebafc211e47> in <module>()
#      55 #     print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
#      56 #     print "______________________________________________________________________________________________\n"
# ---> 57     if (df.PV[j] != 0):
#      58         if (levelbatt[j] == maxbatt):
#      59             batt_t = levelbatt[j] - minbatt
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    2167         try:
#    2168             return self._engine.get_value(s, k,
# -> 2169                                           tz=getattr(series.dtype, 'tz', None))
#    2170         except KeyError as e1:
#    2171             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3567)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3250)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8555)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8499)()
#
# KeyError: 2976

# %%
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
print "control_air-cont (times) ="      , count_air
print "control_fan (times) ="           , count_fan
print "control_tv (times) ="            , count_tv
print "control_computer (times) ="      , count_com
print "control_iphone_charger (times) =", count_iphon
print "control_elec_thermo (times) ="   , count_elec
print "control_hair_dryer (times) ="    , count_hair
print "control_water_heater (times) ="  , count_water
print sum_overpv/1000
# Out:
# count_active = 0
# control_air-cont (times) = 0
# control_fan (times) = 0
# control_tv (times) = 0
# control_computer (times) = 0
# control_iphone_charger (times) = 0
# control_elec_thermo (times) = 0
# control_hair_dryer (times) = 0
# control_water_heater (times) = 0
# 1.123246344
