# %% [markdown]
# ### main of month 1 : OCTOBER (31 days)

# %% [markdown]
# ### EVERY TIME
# #### RESET DATABASE &  RESTART KERNAL & CLAER OUTPUT

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline 

from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
# ____________________________________________________________________________________________________   

'''
##  PRIORITY TABLE
'''
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
      
        return ''.join(html)
 # ____________________________________________________________________________________________________   
    
"""
## CONVERSING  UNIT (kW) >>  BILL (bath)
"""
def bill(allpow,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge
 
    ## Fundamental parameter      
    if allpow <= 0:
        bath = 0
    elif 0 <= allpow <= 150:
        bath = allpow*t1
    elif  151 <= allpow <= 400:
        power = allpow-150
        bath_1 = 150*t1
        bath_2 = power*t2
        bath = bath_1+bath_2
    else:
        power = allpow-150
        bath_1 = 150*t1
        power = power-250
        bath_2 = 250*t2
        bath_3 = power*t3
        bath = bath_1+bath_2+bath_3   
    service_price = 38.22  #permonth (fixed)   
    ## FT -33.2 satang/unit
    FT_price = allpow*Ft
    ## VAT 7%
    VAT_price = ((service_price+bath)+FT_price)*0.07
    bill = bath+service_price+FT_price+VAT_price
    return round(bill,2)
 # ____________________________________________________________________________________________________   

"""
## CONVERSING  BILL (bath) >>  UNIT (kW) >> 
"""
def inbill(bath,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge  
    u = symbols('u')
    test_1 = solve(Eq((u*t1)+ser+(u*Ft)+(0.07*((u*t1)+ser))+(0.07*(u*Ft)),bath))
    test_2 = solve(Eq((150*t1)+((u-150)*t2)+ser+(u*Ft)+(0.07*((150*t1)+((u-150)*t2)+ser))+(0.07*(u*Ft)),bath))
    test_3 = solve(Eq((150*t1)+(250*t2)+((u-400)*t3)+ser+(u*Ft)+(0.07*((150*t1)+(250*t2)+((u-400)*t3)+ser))+(0.07*(u*Ft)),bath))
    if 1 <=  test_1[0] <= 150:
        unit = test_1[0]
    elif 151 <=  test_2[0] <=  400:
        unit = test_2[0]
    else:
        unit = test_3[0]
    return (round(unit))
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The ENDING POSITION OF EACH APPLIANCES
"""
def end_air(j): 
    check = 1  
    m_air = j+1   
    while (check == 1):
        while df1.aircont[ m_air] > 0 and m_air < (96*31)-1:
            m_air += 1
        check = 0
    return  m_air

def end_com(j): 
    check = 1  
    m_com = j+1   
    while (check == 1):
        while df1.computer[m_com] > 0 and m_com < (96*31)-1:
            m_com += 1  
        check = 0
    return  m_com

def end_elec(j): 
    check = 1  
    m_elec = j+1   
    while (check == 1):
        while df1.elec_thermo[m_elec] > 0 and m_elec < (96*31)-1:
            m_elec += 1  
        check = 0
    return  m_elec

def end_hair(j): 
    check = 1  
    m_hair = j+1   
    while (check == 1):
        while df1.hair_dryer[m_hair] > 0 and m_hair < (96*31)-1:
            m_hair += 1  
        check = 0
    return  m_hair

def end_iphon(j): 
    check = 1  
    m_iphon = j+1   
    while (check == 1):
        while df1.iphonecharger[ m_iphon] > 0 and m_iphon < (96*31)-1:
            m_iphon += 1  
        check = 0
    return  m_iphon

def end_fan(j): 
    check = 1  
    m_fan = j+1   
    while (check == 1):
        while df1.fan[m_fan] > 0 and m_fan < (96*31)-1:
            m_fan += 1  
        check = 0
    return  m_fan

def end_tv(j): 
    check = 1  
    m_tv = j+1   
    while (check == 1):
        while df1.tv[m_tv] > 0 and m_tv < (96*31)-1 :
            m_tv += 1  
        check = 0
    return  m_tv

def end_water(j): 
    check = 1  
    m_water = j+1   
    while (check == 1):
        while df1.water_heater[m_water] > 0 and m_water < (96*31)-1:
            m_water += 1  
        check = 0
    return  m_water
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The STATE OF APPLIANCES 
"""    
def state(j,m_air,m_com, m_elec,m_hair,m_iphon, m_fan ,m_tv, m_water) :
    if j <= m_air:
        ans1 = 18    
    else:
        ans1 = 0
    if j <= m_com:
        ans2 = df1.computer[j]
    else:
        ans2 = 0
    if j <= m_elec:
        ans3 = df1.elec_thermo[j]
    else:
        ans3 = 0
    if j <= m_hair:
        ans4 = df1.hair_dryer[j]
    else:
        ans4 = 0
    if j <= m_iphon:
        ans5 = df1.iphonecharger[j]
    else:
        ans5 = 0
    if j <= m_fan:
        ans6 = df1.fan[j]
    else:
        ans6 = 0
    if j <= m_tv:
        ans7 = df1.tv[j]
    else:
        ans7 = 0
    if j <= m_water:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0

    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8
#     print "substact k watt out from watt = ",k,"watt    ||||||" ,ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8
    return (ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8,k) 
 # ____________________________________________________________________________________________________   

"""
## PREDICTION 
"""        
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
 # ____________________________________________________________________________________________________   

"""
## FITTING PARAMETERS FOR PREDICTION
""" 
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []    
    ##############################################################
    ### ??????????????????????????????????????????????????????????
    query_last = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query_last
    df1 = pd.read_sql(query_last, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data,96*7,alpha,beta,gamma,pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print "the minimum MSE of prediction =",MSE_min,"by alpha =",alpha,"beta =",beta,"gamma =",gamma
    return (alpha,beta,gamma)
 # ____________________________________________________________________________________________________   

"""
## CHECKING THE STATUS OF APPLIANCES ON THAT TIME
""" 
def appliances(j):
    ############################################################## (day + table_database)
    ### ??????????????????????????????????????????????????????????
    time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')
    conn = MySQLdb.connect("localhost","conn","hems")
    c = conn.cursor()
    query1 = "SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '%s'; "% (time_b[j])
    print "Check status of appliances from"
    print query1
    df1 = pd.read_sql(query1, conn) 
    
    for row in df1.iterrows():
        index, data = row
        state = data.tolist()
    i = 1
    status = []
    while(i < len(state)-1):
        dict = { 1:'refrigerator',2:'wireless_router',3:'aircont',4:'computer',5:'electrical_thermo',6:'hair_dryer',7:'microwave',8:'iphone_charger',9:'fan',10:'tv'
                ,11:'washing_machine',12:'iron',13:'rice_cooker',14:'water_heater',15:'light_system'}
        if state[i] != 0:
            a = dict[i]
            status.append(a)
        i +=1  
    print "NOW !! you are turning ON" ,status ,"=",len(status),"items"
    print "______________________________________________________________________________________________\n"
    return(state)
 # ____________________________________________________________________________________________________

# %%
# Set paremeters
j = 0
d = 32   ################################
pred_no = 1
z  = 0 
trinker = [0,0,0,0,0,0,0,0]
batt = float(2.900*1000)     ## SIZE OF BATTERY  2.9 kW 
k = 0
all_power = []
sum_power = []
sum_p = []
sum_pv = []
sum_pvconsumption = []
sum_batt = []
sum_battconsumption = []
sum_grid= []
sum_gridconsumption = []
h = 0

ans_air = 0 
ans_com = 0 
ans_elec = 0 
ans_hair = 0 
ans_iphon = 0 
ans_fan = 0
ans_tv = 0
ans_water = 0
m_air = 0
m_com = 0
m_elec = 0
m_hair = 0
m_iphon = 0
m_fan = 0
m_tv = 0   
m_water = 0
minbatt = batt * 0.2        ## PERIOD OF  BATTERY  USING  2.9*0.2 = 580 - 2900
maxbatt = batt
effi = float(0.96)            ##  EFFICIENTCY OF CHARGING  BATTERY  = 96%
levelbatt = []
levelbatt.append(float(batt))  ####################################################
pv_consumption = []
batt_consumption = []
grid_consumption = []
overpv = float(0)
sum_overpv = float(0)
charging_watt = float(0)
count_active = 0 

count_air = 0
count_fan = 0
count_tv = 0
count_com = 0
count_iphon = 0
count_elec = 0
count_hair = 0
count_water = 0
 
# Connect MYSQL
conn= MySQLdb.connect("localhost","conn","hems","power")
c = conn.cursor()

# Read the data of lastest month 
query0 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp >= '2016-09-01 00:14:59' AND  Timestamp <= '2016-09-30 23:59:59';"
df = pd.read_sql(query0, conn)   
print "\n"
print "Total unit consumption in the last month equal to",df.total_watt.sum()/1000,"kW"
last_bill = bill(df.total_watt.sum()/1000,-0.048)    
print "The lastest elctrical bill is about",last_bill,"bath with Ft = -0.048"
print "\n______________________________________________________________________________________________\n"
   
x = raw_input('What is about Ft in the next month?',)
Ft = float(x)
    
y = raw_input('How about expected price in electrical bill do you want?')
target_price = float(y)

print "\n______________________________________________________________________________________________"    
print "\nThe expected price in the next electrical bill is about",target_price,"bath with Ft =", Ft
discount = (last_bill-target_price)/last_bill *100
print "To compare with the lastest bill is equal to",round(discount,2),"% cut-off"
target_unit = inbill(target_price,Ft)
print "Total available unit consumption in the next month equal to",target_unit,"kW or unit"
print "______________________________________________________________________________________________\n"


# Show the priority of 15 appliances
name = ['refrigerator','wireless_router','aircont','computer','electrical_thermo','hair_dryer','microwave','iphone_charger','fan','tv','washing_machine','iron','rice_cooker','water_heater','light_system']
types = ['Type1 : always turn on [Dont control]','Type1 : always turn on','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday'
        ,'Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type3 : turn on manytime(1-3) in everyday','Type3 : turn on manytime(1-3) in everyday','Type4 : turn on oncetime in someday'
        ,'Type4 : turn on oncetime in someday','Type4 : turn on oncetime in someday','Type5 : turn on manytime(1-3) in someday','Type6 : monitor power consuming [Dont control]']
prior = ['x','x','1','4','6','7','9','5','2','3','12','11','10','9','x']
table = ListTable()
table.append(['the 15 appliances','Type of appliances','the priority'])
for i in xrange(15):
    x = name[i]
    y = types[i]
    z = prior[i]
    table.append([x, y ,z])
    
print "\n"

table
# Out:
# Total unit consumption in the last month equal to 370.1870531 kW
# The lastest elctrical bill is about 1537.91 bath with Ft = -0.048
#
# ______________________________________________________________________________________________
# ______________________________________________________________________________________________
#
# The expected price in the next electrical bill is about 1500.0 bath with Ft = -0.048
# To compare with the lastest bill is equal to 2.47 % cut-off
# Total available unit consumption in the next month equal to 362.0 kW or unit
# ______________________________________________________________________________________________
# [['the 15 appliances', 'Type of appliances', 'the priority'],
#  ['refrigerator', 'Type1 : always turn on [Dont control]', 'x'],
#  ['wireless_router', 'Type1 : always turn on', 'x'],
#  ['aircont', 'Type2 : turn on oncetime&everyday', '1'],
#  ['computer', 'Type2 : turn on oncetime&everyday', '4'],
#  ['electrical_thermo', 'Type2 : turn on oncetime&everyday', '6'],
#  ['hair_dryer', 'Type2 : turn on oncetime&everyday', '7'],
#  ['microwave', 'Type2 : turn on oncetime&everyday', '9'],
#  ['iphone_charger', 'Type2 : turn on oncetime&everyday', '5'],
#  ['fan', 'Type3 : turn on manytime(1-3) in everyday', '2'],
#  ['tv', 'Type3 : turn on manytime(1-3) in everyday', '3'],
#  ['washing_machine', 'Type4 : turn on oncetime in someday', '12'],
#  ['iron', 'Type4 : turn on oncetime in someday', '11'],
#  ['rice_cooker', 'Type4 : turn on oncetime in someday', '10'],
#  ['water_heater', 'Type5 : turn on manytime(1-3) in someday', '9'],
#  ['light_system', 'Type6 : monitor power consuming [Dont control]', 'x']]

# %%
d = 32
time_a_last = pd.date_range('2016-09-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-09-30 23:44:59', periods=96*d, freq='15T')

time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query_empty = """truncate table thesis.main""" 
c.execute(query_empty)
print "table thesis.main are Empty!!! \n"

query_last = "SELECT * FROM thesis.measure_15devices WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a_last[j],time_b_last[j])
df_last  = pd.read_sql(query_last, conn)

### DATABASE OPENING DEVICE *****
query1 = "SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)

### DATABASE PV *****
query = "SELECT Timestamp,PV FROM thesis.old_PV WHERE Timestamp>='%s'AND Timestamp<='%s'; "%('2016-10-01 00:00:00','2016-10-31 23:59:59')
df = pd.read_sql(query, conn)
df['PV'] = ((df.PV/10)*2)

while ( j <= (96*d) -1): # 1 month on OCTOBER

    print "data at :" , j
#     print j,
    print "______________________________________________________________________________________________\n",
#     query_last = "\nSELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s'; "%(time_a_last[j],time_b_last[j])
#     print query_last
#     df_last = pd.read_sql(query_last, conn)
#     conn.commit()
#     data_y = df_last['total_watt'].values.tolist()   
#     ans_fiting = fittingparameter(data_y,j)
    
#     query_last_new = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
#     query_last_new_1 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
#     print "______________________________________________________________________________________________"
#     print "\n",query_last_new  
#     print query_last_new_1
#     print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
#     df_last_new = pd.read_sql(query_last_new, conn)
#     conn.commit()
#     data_y = df_last_new['total_watt'].values.tolist()     
#     pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
#     pred_data = pred_h[len(pred_h)-(pred_no):]   
#     pred_watt = abs(pred_data[0])
#     target = pred_watt*(1-(discount/100))
#     print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
#     print "______________________________________________________________________________________________\n"
    if (df.PV[j] != 0):
        if (levelbatt[j] == maxbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]))
#                 sub = target - float(0)
                overpv = df.PV[j] - watt
                sum_overpv += overpv
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
#                     sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
#                     sub = target - lefted_batt     
                                           
        else:
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                charging_watt = df.PV[j] - watt
                missing_watt = maxbatt - levelbatt[j]
                if (charging_watt > missing_watt):
                    charging_watt = missing_watt *effi
                else:
                    charging_watt = charging_watt * effi 
                levelbatt.append(float(levelbatt[j]+(charging_watt)))
#                 sub = target - float(0)
                overpv = df.PV[j] - watt - charging_watt
                sum_overpv += overpv   
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
#                     sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
#                     sub = target - lefted_batt                          
    else :
        if (levelbatt[j] > minbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k 
            if (batt_t > watt):
                pv_consumption.append(float(0))
                batt_consumption.append(float(watt))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]-watt))
#                 sub = target - float(0)
            else:
                lefted_batt = watt - batt_t
                pv_consumption.append(float(0))
                batt_consumption.append(float(batt_t))
                grid_consumption.append(float(lefted_batt))
                levelbatt.append(float(levelbatt[j]-batt_t))
#                 sub = target - float(lefted_batt)                
        else:
            watt = df1.total_watt[j] - k 
            pv_consumption.append(float(0))
            batt_consumption.append(float(0))
            grid_consumption.append(float(watt))
            levelbatt.append(float(levelbatt[j]))
#             sub = target -  watt
            
    print "Consuming watt =",watt       
    print "PV_CONSUMPTION =",pv_consumption[j]
    print "BATT_CONSUMPTION =",batt_consumption[j]
    print "GRID_CONSUMPTION =",grid_consumption[j]
    print "PREVIOUS LEVELBATT =",levelbatt[j],"||| LEFTED LEVELBATT =",levelbatt[j+1]   
    print "PV GENERATION =",df.PV[j],"||| BATT_CHARGING =",charging_watt
    print "______________________________________________________________________________________________\n"
    
    
    print "||| 15 Minutes Lefted You Consumed power from ""PEA"" about",grid_consumption[j],"watt"   
    print "||| NOW YOUR ELECTRICAL BILL IS ABOUT",bill((sum(grid_consumption))/1000,Ft),"bath"   
    print "______________________________________________________________________________________________\n" 
   
       
    c.execute("INSERT INTO thesis.main (Timestamp, old_watt,PV_genarator , levelbatt ,pv_consumption , batt_consumption,grid_consumption,sum_load_watt,watt) VALUES ( %s,  %s,%s, %s, %s, %s,%s, %s, %s)",
              (time_b[j],df1.total_watt[j],df.PV[j],levelbatt[j],pv_consumption[j],batt_consumption[j],grid_consumption[j],pv_consumption[j]+batt_consumption[j]+grid_consumption[j],watt))
    conn.commit()  
  
    check_state = appliances(j) 
   
    c.execute("INSERT INTO thesis.measure_15devices (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt) VALUES ( %s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s)",
              (time_b[j],check_state[1],check_state[2],check_state[3]-ans_air,check_state[4]-ans_com,check_state[5]-ans_elec,check_state[6]-ans_hair,check_state[7],check_state[8]-ans_iphon,check_state[9]-ans_fan,check_state[10]--ans_tv,check_state[11],check_state[12],check_state[13],check_state[14]-ans_water,check_state[15],watt))               
    conn.commit()
    
    all_power.append(watt/1000)
    df_power = pd.DataFrame(all_power)

    ###   [Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt]
#     del check_state[13]   # del  rice_cooker
#     del check_state[12]   # del iron
#     del check_state[11]   # del washing_machine
#     del check_state[7]    # del microwave
#     del check_state[2]    # del wireless_router
#     del check_state[1]    # del refrigerator
#     del check_state[0]    # del Timestamp
#     del check_state[-1]   # del  total_watt
#     del check_state[-1]   # del light_system
#     ###   [ aircont, computer, elec_thermo, hair_dryer, iphonecharger,fan,tv, water_heater]
           
#     if j == 0:
#         sum_sub = sub       
#     else :
#         sum_sub = sum_sub + sub      
    
#     if sum_sub < 0: ##turn OFF devices 
#         print "\n_____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________ "
#         print "\n"
#         print "m_air =",check_state[0] , "m_fan=",check_state[5] , "m_tv =",check_state[6] , "m_com =",check_state[1] , "m_iphon =",check_state[4] , "m_elec=",check_state[2] , "m_hair=",check_state[3] , "m_water =",check_state[7]        
                
#         if  check_state[0] > 0 and trinker[0] == 0:  #air
#             m_air = end_air(j)-1
#             count_air += 1
            
#         elif  check_state[5] > 0 and trinker[5] == 0:        
#             m_fan = end_fan(j)-1
#             count_fan += 1
            
#         elif  check_state[6] > 0 and trinker[6] == 0:        
#             m_tv = end_tv(j)-1
#             count_tv += 1  
            
#         elif  check_state[1] > 0 and trinker[1] == 0:
#             m_com = end_com(j)-1          
#             count_com += 1 
            
#         elif  check_state[4] > 0 and trinker[4] == 0:        
#             m_iphon = end_iphon(j)-1
#             count_iphon += 1
            
#         elif  check_state[2] > 0 and trinker[2] == 0:
#             m_elec = end_elec(j)-1
#             count_elec += 1 
            
#         elif  check_state[3] > 0 and trinker[3] == 0:        
#             m_hair = end_hair(j)-1                    
#             count_hair += 1 
            
#         elif check_state[7] > 0 and trinker[7] == 0:        
#             m_water = end_water(j)-1
#             count_water += 1 
# #         else:
# #             print "No appliances"
            
#         if j <= m_air:
#             trinker[0] = 1
#         else :
#             trinker[0] = 0
            
#         if j <= m_com:
#              trinker[1] = 1
#         else :
#             trinker[1] = 0 
            
#         if j <= m_elec:
#              trinker[2] = 1 
#         else :
#             trinker[2] = 0  
            
#         if j <= m_hair:
#              trinker[3] = 1
#         else :
#             trinker[3] = 0  
            
#         if j <= m_iphon:
#              trinker[4] = 1 
#         else :
#             trinker[4] = 0  
            
#         if j <= m_fan:
#              trinker[5] = 1 
#         else :            
#             trinker[5] = 0  
            
#         if j <= m_tv:
#              trinker[6] = 1
#         else :
#             trinker[6] = 0
            
#         if j <= m_water:
#              trinker[7] = 1 
#         else :
#             trinker[7] = 0                
# #         print "             ",   m_air   , "           ",   m_fan  , "          ",    m_tv   , "             ",  m_com  , "               ", m_iphon , "            ", m_elec  , "            ",m_hair     , "               ",m_water                 
# #         print "             ",trinker[0] , "           ",trinker[5] , "         ",trinker[6] , "             ",trinker[7] , "               ",trinker[4] , "           ",trinker[2] , "            ",trinker[3] , "               ",trinker[7]                 
      
#         j += 1  
#         k = state(j,m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)
#         ans_air = k[0] 
#         ans_com = k[1] 
#         ans_elec = k[2] 
#         ans_hair = k[3] 
#         ans_iphon = k[4] 
#         ans_fan = k[5]
#         ans_tv = k[6] 
#         ans_water = k[7] 
#         k = k[8]          
#     else: 
#         print "\n______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________ "
#         j += 1
#         k = state(j, m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)  
#         ans_air = k[0] 
#         ans_com = k[1] 
#         ans_elec = k[2] 
#         ans_hair = k[3] 
#         ans_iphon = k[4] 
#         ans_fan = k[5]
#         ans_tv = k[6] 
#         ans_water = k[7] 
#         k = k[8]
    j += 1
    print "\n"              
    charging_watt = float(0)     
    print "                                                               -------------------------------------                                                            \n"
      
    while ( h < (len(df_power)/96) ) : 
        print """\n. . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .\n"""
#         print (k*24),"to",(k+1)*24
        sum_p =  df_power[(h*96):((h+1)*96)].sum()
        sum_power.append(sum_p)
        
        sum_pv = sum(pv_consumption[(h*96):((h+1)*96)])
        sum_pvconsumption.append(sum_pv/1000)
        
        sum_batt = sum(batt_consumption[(h*96):((h+1)*96)])
        sum_battconsumption.append(sum_batt/1000)
        
        sum_grid = sum(grid_consumption[(h*96):((h+1)*96)])
        sum_gridconsumption.append(sum_grid/1000)
        
        df_power2 = pd.DataFrame(sum_power)  
        df_power3 = pd.DataFrame(sum_pvconsumption)  
        df_power4 = pd.DataFrame(sum_battconsumption)  
        df_power5 = pd.DataFrame(sum_gridconsumption)           
        result = pd.concat([df_power2, df_power3, df_power4, df_power5], axis=1)
        result.columns = ['power consumption','From PV','From BATTERY','From PEA']
        print result
        print "Power consuming between" ,time_a[h*96], "to" ,time_b[(h+1)*96-1], "equal to", result.iloc[h]['power consumption']," kW. -->> equal to",bill(float(result.iloc[h]['From PEA']),Ft),"bath"
        print """///////////////////////////////////////////////////////////////////////////////////////////////////////////////\n"""
        h +=1 
         
print "-------------YOUR PROGRAM IS DONE-----------------"
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
# Out:
# table thesis.main are Empty!!!
#
# data at : 0
# ______________________________________________________________________________________________
# Consuming watt = 305.692
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 305.692
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 2900.0 ||| LEFTED LEVELBATT = 2594.308
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 00:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 1
# ______________________________________________________________________________________________
# Consuming watt = 293.388
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 293.388
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 2594.308 ||| LEFTED LEVELBATT = 2300.92
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 00:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2
# ______________________________________________________________________________________________
# Consuming watt = 189.646
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 189.646
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 2300.92 ||| LEFTED LEVELBATT = 2111.274
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 00:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 3
# ______________________________________________________________________________________________
# Consuming watt = 297.196
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 297.196
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 2111.274 ||| LEFTED LEVELBATT = 1814.078
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 00:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 4
# ______________________________________________________________________________________________
# Consuming watt = 287.479
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 287.479
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1814.078 ||| LEFTED LEVELBATT = 1526.599
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 01:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 5
# ______________________________________________________________________________________________
# Consuming watt = 177.025
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 177.025
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1526.599 ||| LEFTED LEVELBATT = 1349.574
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 01:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 6
# ______________________________________________________________________________________________
# Consuming watt = 295.842
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 295.842
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1349.574 ||| LEFTED LEVELBATT = 1053.732
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 01:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 7
# ______________________________________________________________________________________________
# Consuming watt = 178.242
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 178.242
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1053.732 ||| LEFTED LEVELBATT = 875.49
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 01:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 8
# ______________________________________________________________________________________________
# Consuming watt = 289.721
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 289.721
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 875.49 ||| LEFTED LEVELBATT = 585.769
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 40.9 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 02:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 9
# ______________________________________________________________________________________________
# Consuming watt = 174.479
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 5.769
# GRID_CONSUMPTION = 168.71
# PREVIOUS LEVELBATT = 585.769 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 168.71 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 41.47 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 02:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 10
# ______________________________________________________________________________________________
# Consuming watt = 266.817
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 266.817
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 266.817 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 42.39 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 02:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 11
# ______________________________________________________________________________________________
# Consuming watt = 191.012
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 191.012
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 191.012 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 43.04 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 02:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 12
# ______________________________________________________________________________________________
# Consuming watt = 179.446
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 179.446
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 179.446 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 43.66 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 03:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 13
# ______________________________________________________________________________________________
# Consuming watt = 197.458
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 197.458
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 197.458 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 44.33 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 03:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 14
# ______________________________________________________________________________________________
# Consuming watt = 231.029
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 231.029
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 231.029 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 45.12 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 03:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 15
# ______________________________________________________________________________________________
# Consuming watt = 144.758
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 144.758
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 144.758 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 45.62 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 03:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 16
# ______________________________________________________________________________________________
# Consuming watt = 139.587
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 139.587
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 139.587 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 46.1 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 04:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 17
# ______________________________________________________________________________________________
# Consuming watt = 172.721
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 172.721
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 172.721 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 46.69 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 04:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 18
# ______________________________________________________________________________________________
# Consuming watt = 175.083
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 175.083
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 175.083 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.29 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 04:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 19
# ______________________________________________________________________________________________
# Consuming watt = 170.858
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 170.858
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 170.858 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.87 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 04:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 20
# ______________________________________________________________________________________________
# Consuming watt = 171.512
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 171.512
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 171.512 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.46 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 05:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 21
# ______________________________________________________________________________________________
# Consuming watt = 154.646
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 154.646
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 154.646 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.99 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 05:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 22
# ______________________________________________________________________________________________
# Consuming watt = 140.775
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 140.775
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 140.775 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 49.47 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 05:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 23
# ______________________________________________________________________________________________
# Consuming watt = 139.8
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 139.8
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 139.8 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 49.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 05:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 24
# ______________________________________________________________________________________________
# Consuming watt = 86.9625
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 86.9625
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 86.9625 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.25 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 06:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 25
# ______________________________________________________________________________________________
# Consuming watt = 45.6844
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 45.6844
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 45.6844 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.4 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 06:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'fan'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 26
# ______________________________________________________________________________________________
# Consuming watt = 36.5574
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 36.5574
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 36.5574 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.53 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 06:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'fan'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 27
# ______________________________________________________________________________________________
# Consuming watt = 31.0
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.0
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 31.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.64 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 06:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 28
# ______________________________________________________________________________________________
# Consuming watt = 31.7049
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 31.7049
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 31.7049 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.74 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 07:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 29
# ______________________________________________________________________________________________
# Consuming watt = 27.4631
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 27.4631
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 27.4631 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.84 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 07:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 30
# ______________________________________________________________________________________________
# Consuming watt = 26.7213
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 26.7213
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 26.7213 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.93 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 07:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 31
# ______________________________________________________________________________________________
# Consuming watt = 30.2582
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 30.2582
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 30.2582 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.03 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 07:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 32
# ______________________________________________________________________________________________
# Consuming watt = 33.7131
# PV_CONSUMPTION = 26.498
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 7.2151
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 26.498 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 7.2151 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.06 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 08:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 33
# ______________________________________________________________________________________________
# Consuming watt = 34.0369
# PV_CONSUMPTION = 27.5942
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 6.4427
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 27.5942 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 6.4427 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.08 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 08:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 34
# ______________________________________________________________________________________________
# Consuming watt = 146.316
# PV_CONSUMPTION = 29.5848
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 116.7312
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 29.5848 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 116.7312 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.48 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 08:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 35
# ______________________________________________________________________________________________
# Consuming watt = 58.1803
# PV_CONSUMPTION = 33.02
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 25.1603
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 33.02 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 25.1603 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.57 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 08:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 36
# ______________________________________________________________________________________________
# Consuming watt = 46.6885
# PV_CONSUMPTION = 36.2934
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 10.3951
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 36.2934 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 10.3951 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.6 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 09:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'electrical_thermo'] = 3 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 37
# ______________________________________________________________________________________________
# Consuming watt = 122.525
# PV_CONSUMPTION = 47.4942
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 75.0308
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 47.4942 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 75.0308 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 09:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'water_heater', 'light_system'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 38
# ______________________________________________________________________________________________
# Consuming watt = 709.459
# PV_CONSUMPTION = 53.3138
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 656.1452
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 53.3138 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 656.1452 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.11 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 09:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'water_heater', 'light_system'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 39
# ______________________________________________________________________________________________
# Consuming watt = 207.754
# PV_CONSUMPTION = 60.0084
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 147.7456
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 60.0084 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 147.7456 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.61 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 09:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'water_heater', 'light_system'] = 4 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 40
# ______________________________________________________________________________________________
# Consuming watt = 27.2951
# PV_CONSUMPTION = 27.2951
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 613.591264
# PV GENERATION = 62.286 ||| BATT_CHARGING = 33.591264
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.61 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 10:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 41
# ______________________________________________________________________________________________
# Consuming watt = 26.5738
# PV_CONSUMPTION = 26.5738
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 613.591264 ||| LEFTED LEVELBATT = 651.157024
# PV GENERATION = 65.7048 ||| BATT_CHARGING = 37.56576
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.61 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 10:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 42
# ______________________________________________________________________________________________
# Consuming watt = 31.5082
# PV_CONSUMPTION = 31.5082
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 651.157024 ||| LEFTED LEVELBATT = 712.390048
# PV GENERATION = 95.2926 ||| BATT_CHARGING = 61.233024
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.61 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 10:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 43
# ______________________________________________________________________________________________
# Consuming watt = 33.9631
# PV_CONSUMPTION = 33.9631
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 712.390048 ||| LEFTED LEVELBATT = 770.735296
# PV GENERATION = 94.7394 ||| BATT_CHARGING = 58.345248
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.61 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-01 10:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 44
# ______________________________________________________________________________________________
# Consuming watt = 33.8934
# PV_CONSUMPTION = 33.8934
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 770.735296 ||| LEFTED LEVELBATT = 817.556608
# PV GENERATION = 82.6656 ||| BATT_CHARGING = 46.821312
# ______________________________________________________________________________________________
#
# ...
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 96.183186 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1367.75 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 21:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2966
# ______________________________________________________________________________________________
# Consuming watt = 380.906
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 380.906
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 380.906 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1369.45 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 21:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2967
# ______________________________________________________________________________________________
# Consuming watt = 531.09
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 531.09
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 531.09 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1371.82 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 21:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2968
# ______________________________________________________________________________________________
# Consuming watt = 525.742
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 525.742
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 525.742 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1374.17 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 22:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2969
# ______________________________________________________________________________________________
# Consuming watt = 459.041
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 459.041
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 459.041 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1376.22 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 22:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'hair_dryer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 9 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2970
# ______________________________________________________________________________________________
# Consuming watt = 359.25
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 359.25
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 359.25 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1377.83 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 22:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2971
# ______________________________________________________________________________________________
# Consuming watt = 353.459
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 353.459
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 353.459 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1379.4 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 22:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2972
# ______________________________________________________________________________________________
# Consuming watt = 351.324
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 351.324
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 351.324 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1380.97 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 23:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'fan', 'tv', 'light_system'] = 8 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2973
# ______________________________________________________________________________________________
# Consuming watt = 346.877
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 346.877
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 346.877 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1382.52 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 23:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'fan', 'tv'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2974
# ______________________________________________________________________________________________
# Consuming watt = 280.344
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 280.344
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 280.344 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1383.77 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 23:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'fan', 'tv'] = 6 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
# data at : 2975
# ______________________________________________________________________________________________
# Consuming watt = 335.553
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 335.553
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 335.553 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 1385.27 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month1 WHERE  Timestamp = '2016-10-31 23:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger', 'fan', 'tv', 'light_system'] = 7 items
# ______________________________________________________________________________________________
#
#
#
#                                                                -------------------------------------
#
#
# . . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .
#
#     power consumption   From PV  From BATTERY   From PEA
# 0           14.516333  1.525699      3.249359   9.741275
# 1           10.887152  1.164984      0.669826   9.052343
# 2           12.090409  0.901186      0.331242  10.857981
# 3           11.124229  1.123566      1.273725   8.726937
# 4           11.863411  0.893392      0.260914  10.709104
# 5           12.203393  0.385872      0.000000  11.817521
# 6           14.584984  1.166771      1.075315  12.342898
# 7           11.277419  0.527986      0.025488  10.723945
# 8           14.887057  0.232621      0.000000  14.654436
# 9           11.784659  1.033200      1.400360   9.351099
# 10           8.804270  0.791743      0.255216   7.757311
# 11          15.524005  0.655609      0.461252  14.407144
# 12          12.033099  0.865771      0.718202  10.449126
# 13          12.547989  1.238860      0.729100  10.580029
# 14          13.481885  1.442191      0.968085  11.071608
# 15          12.055303  0.096105      0.000000  11.959198
# 16          12.165074  0.760228      0.402306  11.002540
# 17          12.083627  0.502714      0.222088  11.358824
# 18           9.460993  0.663586      0.102578   8.694829
# 19          12.909845  0.534953      0.252969  12.121923
# 20          15.305025  0.880163      0.322707  14.102155
# 21          10.696787  1.225154      1.098202   8.373432
# 22          11.226060  1.072470      1.118777   9.034813
# 23          13.657558  1.107941      1.282494  11.267123
# 24          12.333777  0.903450      0.579509  10.850819
# 25          14.277380  0.514208      0.333306  13.429866
# 26          11.909427  0.762784      0.349093  10.797550
# 27          12.434144  0.782240      0.731175  10.920729
# 28          10.595868  0.795583      0.489523   9.310762
# 29          14.107881  0.968061      0.446309  12.693511
# 30          10.282039  1.022107      1.411010   7.848923
# Power consuming between 2016-10-31 00:00:00 to 2016-10-31 23:59:59 equal to 10.2820391  kW. -->> equal to 67.77 bath
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# data at : 2976
# ______________________________________________________________________________________________
# KeyErrorTraceback (most recent call last)
# <ipython-input-7-696ea5562b82> in <module>()
#      52 #     print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
#      53 #     print "______________________________________________________________________________________________\n"
# ---> 54     if (df.PV[j] != 0):
#      55         if (levelbatt[j] == maxbatt):
#      56             batt_t = levelbatt[j] - minbatt
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    2167         try:
#    2168             return self._engine.get_value(s, k,
# -> 2169                                           tz=getattr(series.dtype, 'tz', None))
#    2170         except KeyError as e1:
#    2171             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3567)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3250)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8555)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8499)()
#
# KeyError: 2976

# %%
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
print "control_air-cont (times) ="      , count_air
print "control_fan (times) ="           , count_fan
print "control_tv (times) ="            , count_tv
print "control_computer (times) ="      , count_com
print "control_iphone_charger (times) =", count_iphon
print "control_elec_thermo (times) ="   , count_elec
print "control_hair_dryer (times) ="    , count_hair
print "control_water_heater (times) ="  , count_water
print sum_overpv/1000
