# %% [markdown]
# ### main of month 2 : NOVEMBER (30 days) || 35 PERCEnt ||

# %% [markdown]
# ### EVERY TIME
# #### RESET DATABASE &  RESTART KERNAL & CLAER OUTPUT

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline 

from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
# ____________________________________________________________________________________________________   

'''
##  PRIORITY TABLE
'''
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
      
        return ''.join(html)
 # ____________________________________________________________________________________________________   
    
"""
## CONVERSING  UNIT (kW) >>  BILL (bath)
"""
def bill(allpow,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge
 
    ## Fundamental parameter      
    if allpow <= 0:
        bath = 0
    elif 0 <= allpow <= 150:
        bath = allpow*t1
    elif  151 <= allpow <= 400:
        power = allpow-150
        bath_1 = 150*t1
        bath_2 = power*t2
        bath = bath_1+bath_2
    else:
        power = allpow-150
        bath_1 = 150*t1
        power = power-250
        bath_2 = 250*t2
        bath_3 = power*t3
        bath = bath_1+bath_2+bath_3   
    service_price = 38.22  #permonth (fixed)   
    ## FT -33.2 satang/unit
    FT_price = allpow*Ft
    ## VAT 7%
    VAT_price = ((service_price+bath)+FT_price)*0.07
    bill = bath+service_price+FT_price+VAT_price
    return round(bill,2)
 # ____________________________________________________________________________________________________   

"""
## CONVERSING  BILL (bath) >>  UNIT (kW) >> 
"""
def inbill(bath,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge  
    u = symbols('u')
    test_1 = solve(Eq((u*t1)+ser+(u*Ft)+(0.07*((u*t1)+ser))+(0.07*(u*Ft)),bath))
    test_2 = solve(Eq((150*t1)+((u-150)*t2)+ser+(u*Ft)+(0.07*((150*t1)+((u-150)*t2)+ser))+(0.07*(u*Ft)),bath))
    test_3 = solve(Eq((150*t1)+(250*t2)+((u-400)*t3)+ser+(u*Ft)+(0.07*((150*t1)+(250*t2)+((u-400)*t3)+ser))+(0.07*(u*Ft)),bath))
    if 1 <=  test_1[0] <= 150:
        unit = test_1[0]
    elif 151 <=  test_2[0] <=  400:
        unit = test_2[0]
    else:
        unit = test_3[0]
    return (round(unit))
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The ENDING POSITION OF EACH APPLIANCES
"""
############################################################## d

def end_air(j): 
    check = 1  
    m_air = j+1   
    while (check == 1):
        while df1.aircont[ m_air] > 0 and m_air < (96*30)-1:
            m_air += 1
        check = 0
    return  m_air

def end_com(j): 
    check = 1  
    m_com = j+1   
    while (check == 1):
        while df1.computer[m_com] > 0 and m_com < (96*30)-1:
            m_com += 1  
        check = 0
    return  m_com

def end_elec(j): 
    check = 1  
    m_elec = j+1   
    while (check == 1):
        while df1.elec_thermo[m_elec] > 0 and m_elec < (96*30)-1:
            m_elec += 1  
        check = 0
    return  m_elec

def end_hair(j): 
    check = 1  
    m_hair = j+1   
    while (check == 1):
        while df1.hair_dryer[m_hair] > 0 and m_hair < (96*30)-1:
            m_hair += 1  
        check = 0
    return  m_hair

def end_iphon(j): 
    check = 1  
    m_iphon = j+1   
    while (check == 1):
        while df1.iphonecharger[ m_iphon] > 0 and m_iphon < (96*30)-1:
            m_iphon += 1  
        check = 0
    return  m_iphon

def end_fan(j): 
    check = 1  
    m_fan = j+1   
    while (check == 1):
        while df1.fan[m_fan] > 0 and m_fan < (96*30)-1:
            m_fan += 1  
        check = 0
    return  m_fan

def end_tv(j): 
    check = 1  
    m_tv = j+1   
    while (check == 1):
        while df1.tv[m_tv] > 0 and m_tv < (96*30)-1 :
            m_tv += 1  
        check = 0
    return  m_tv

def end_water(j): 
    check = 1  
    m_water = j+1   
    while (check == 1):
        while df1.water_heater[m_water] > 0 and m_water < (96*30)-1:
            m_water += 1  
        check = 0
    return  m_water
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The STATE OF APPLIANCES 
"""    
def state(j,m_air,m_com, m_elec,m_hair,m_iphon, m_fan ,m_tv, m_water) :
    if j <= m_air:
        ans1 = 18   
    else:
        ans1 = 0
    if j <= m_com:
        ans2 = df1.computer[j]
    else:
        ans2 = 0
    if j <= m_elec:
        ans3 = df1.elec_thermo[j]
    else:
        ans3 = 0
    if j <= m_hair:
        ans4 = df1.hair_dryer[j]
    else:
        ans4 = 0
    if j <= m_iphon:
        ans5 = df1.iphonecharger[j]
    else:
        ans5 = 0
    if j <= m_fan:
        ans6 = df1.fan[j]
    else:
        ans6 = 0
    if j <= m_tv:
        ans7 = df1.tv[j]
    else:
        ans7 = 0
    if j <= m_water:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0

    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8
#     print "substact k watt out from watt = ",k,"watt    ||||||" ,ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8
    return (ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8,k) 
 # ____________________________________________________________________________________________________   

"""
## PREDICTION 
"""        
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
 # ____________________________________________________________________________________________________   

"""
## FITTING PARAMETERS FOR PREDICTION
""" 
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []    
    ##############################################################
    ### ??????????????????????????????????????????????????????????
    query_last = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query_last
    df1 = pd.read_sql(query_last, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data,96*7,alpha,beta,gamma,pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print "the minimum MSE of prediction =",MSE_min,"by alpha =",alpha,"beta =",beta,"gamma =",gamma
    return (alpha,beta,gamma)
 # ____________________________________________________________________________________________________   

"""
## CHECKING THE STATUS OF APPLIANCES ON THAT TIME
""" 
def appliances(j):
    ############################################################## (day + table_database)
    ### ??????????????????????????????????????????????????????????
    time_b = pd.date_range('2016-11-01 00:14:59', periods=96*d, freq='15T')
    conn = MySQLdb.connect("localhost","conn","hems")
    c = conn.cursor()
    query1 = "SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '%s'; "% (time_b[j])
    print "Check status of appliances from"
    print query1
    df1 = pd.read_sql(query1, conn) 
    
    for row in df1.iterrows():
        index, data = row
        state = data.tolist()
    i = 1
    status = []
    while(i < len(state)-1):
        dict = { 1:'refrigerator',2:'wireless_router',3:'aircont',4:'computer',5:'electrical_thermo',6:'hair_dryer',7:'microwave',8:'iphone_charger',9:'fan',10:'tv'
                ,11:'washing_machine',12:'iron',13:'rice_cooker',14:'water_heater',15:'light_system'}
        if state[i] != 0:
            a = dict[i]
            status.append(a)
        i +=1  
    print "NOW !! you are turning ON" ,status ,"=",len(status),"items"
    print "______________________________________________________________________________________________\n"
    return(state)
 # ____________________________________________________________________________________________________

# %%
# Set paremeters
j = 0
d = 32   ################################
pred_no = 1
z  = 0 
trinker = [0,0,0,0,0,0,0,0]
batt = float(2.900*1000)     ## SIZE OF BATTERY  2.9 kW 
k = 0
all_power = []
sum_power = []
sum_p = []
sum_pv = []
sum_pvconsumption = []
sum_batt = []
sum_battconsumption = []
sum_grid= []
sum_gridconsumption = []
h = 0

ans_air = 0 
ans_com = 0 
ans_elec = 0 
ans_hair = 0 
ans_iphon = 0 
ans_fan = 0
ans_tv = 0
ans_water = 0
m_air = 0
m_com = 0
m_elec = 0
m_hair = 0
m_iphon = 0
m_fan = 0
m_tv = 0   
m_water = 0
minbatt = batt * 0.2        ## PERIOD OF  BATTERY  USING  2.9*0.2 = 580 - 2900
maxbatt = batt
effi = float(0.96)            ##  EFFICIENTCY OF CHARGING  BATTERY  = 96%
levelbatt = []
levelbatt.append(float(580))  ####################################################
pv_consumption = []
batt_consumption = []
grid_consumption = []
overpv = float(0)
sum_overpv = float(0)
charging_watt = float(0)
count_active = 0 

count_air = 0
count_fan = 0
count_tv = 0
count_com = 0
count_iphon = 0
count_elec = 0
count_hair = 0
count_water = 0
 
# Connect MYSQL
conn= MySQLdb.connect("localhost","conn","hems","power")
c = conn.cursor()

# Read the data of lastest month 
#################################################### (DAY)
query0 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices_month1 WHERE Timestamp >= '2016-10-01 00:14:59' AND  Timestamp <= '2016-10-31 23:59:59';"
df = pd.read_sql(query0, conn)   
print "\n"
print "Total unit consumption in the last month equal to",df.total_watt.sum()/1000,"kW"
last_bill = bill(df.total_watt.sum()/1000,-0.048)    
print "The lastest elctrical bill is about",last_bill,"bath with Ft = -0.048"
print "\n______________________________________________________________________________________________\n"
   
x = raw_input('What is about Ft in the next month?',)
Ft = float(x)
    
y = raw_input('How about expected price in electrical bill do you want?')
target_price = float(y)

print "\n______________________________________________________________________________________________"    
print "\nThe expected price in the next electrical bill is about",target_price,"bath with Ft =", Ft
discount = (last_bill-target_price)/last_bill *100
print "To compare with the lastest bill is equal to",round(discount,2),"% cut-off"
target_unit = inbill(target_price,Ft)
print "Total available unit consumption in the next month equal to",target_unit,"kW or unit"
print "______________________________________________________________________________________________\n"


# Show the priority of 15 appliances
name = ['refrigerator','wireless_router','aircont','computer','electrical_thermo','hair_dryer','microwave','iphone_charger','fan','tv','washing_machine','iron','rice_cooker','water_heater','light_system']
types = ['Type1 : always turn on [Dont control]','Type1 : always turn on','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday'
        ,'Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type3 : turn on manytime(1-3) in everyday','Type3 : turn on manytime(1-3) in everyday','Type4 : turn on oncetime in someday'
        ,'Type4 : turn on oncetime in someday','Type4 : turn on oncetime in someday','Type5 : turn on manytime(1-3) in someday','Type6 : monitor power consuming [Dont control]']
prior = ['x','x','1','4','6','7','9','5','2','3','12','11','10','9','x']
table = ListTable()
table.append(['the 15 appliances','Type of appliances','the priority'])
for i in xrange(15):
    x = name[i]
    y = types[i]
    z = prior[i]
    table.append([x, y ,z])
    
print "\n"

table
# Out:
# Total unit consumption in the last month equal to 383.111085 kW
# The lastest elctrical bill is about 1595.63 bath with Ft = -0.048
#
# ______________________________________________________________________________________________
# ______________________________________________________________________________________________
#
# The expected price in the next electrical bill is about 1050.0 bath with Ft = -0.048
# To compare with the lastest bill is equal to 34.2 % cut-off
# Total available unit consumption in the next month equal to 261.0 kW or unit
# ______________________________________________________________________________________________
# [['the 15 appliances', 'Type of appliances', 'the priority'],
#  ['refrigerator', 'Type1 : always turn on [Dont control]', 'x'],
#  ['wireless_router', 'Type1 : always turn on', 'x'],
#  ['aircont', 'Type2 : turn on oncetime&everyday', '1'],
#  ['computer', 'Type2 : turn on oncetime&everyday', '4'],
#  ['electrical_thermo', 'Type2 : turn on oncetime&everyday', '6'],
#  ['hair_dryer', 'Type2 : turn on oncetime&everyday', '7'],
#  ['microwave', 'Type2 : turn on oncetime&everyday', '9'],
#  ['iphone_charger', 'Type2 : turn on oncetime&everyday', '5'],
#  ['fan', 'Type3 : turn on manytime(1-3) in everyday', '2'],
#  ['tv', 'Type3 : turn on manytime(1-3) in everyday', '3'],
#  ['washing_machine', 'Type4 : turn on oncetime in someday', '12'],
#  ['iron', 'Type4 : turn on oncetime in someday', '11'],
#  ['rice_cooker', 'Type4 : turn on oncetime in someday', '10'],
#  ['water_heater', 'Type5 : turn on manytime(1-3) in someday', '9'],
#  ['light_system', 'Type6 : monitor power consuming [Dont control]', 'x']]

# %%
d = 32
#################################################### (DAY)
time_a_last = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-10-31 23:44:59', periods=96*d, freq='15T')
#################################################### (DAY)
time_a = pd.date_range('2016-11-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-11-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

query_empty = """truncate table thesis.main""" 
c.execute(query_empty)
print "table thesis.main are Empty!!! \n"

query_last = "SELECT * FROM thesis.measure_15devices WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a_last[j],time_b_last[j])
df_last  = pd.read_sql(query_last, conn)

### DATABASE OPENING DEVICE *****
#################################################### (DATABASE)
query1 = "SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)

### DATABASE PV *****
#################################################### (DAY)
query = "SELECT Timestamp,PV FROM thesis.PV WHERE Timestamp>='%s'AND Timestamp<='%s'; "%('2016-11-01 00:00:00','2016-11-30 23:59:59')
df = pd.read_sql(query, conn)
df['PV'] = ((df.PV/10)*2)

while ( j <= (96*d) -1): # 1 month on OCTOBER

    print "data at :" , j
#     print j,
    print "______________________________________________________________________________________________\n",
    query_last = "\nSELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s'; "%(time_a_last[j],time_b_last[j])
#     print query_last
    df_last = pd.read_sql(query_last, conn)
    conn.commit()
    data_y = df_last['total_watt'].values.tolist()   
    ans_fiting = fittingparameter(data_y,j)
    
    query_last_new = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
    query_last_new_1 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
    print "______________________________________________________________________________________________"
    print "\n",query_last_new  
    print query_last_new_1
    print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
    df_last_new = pd.read_sql(query_last_new, conn)
    conn.commit()
    data_y = df_last_new['total_watt'].values.tolist()     
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]   
    pred_watt = abs(pred_data[0])
    target = pred_watt*(1-(discount/100))
    print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
    print "______________________________________________________________________________________________\n"

    if (df.PV[j] != 0):
        if (levelbatt[j] == maxbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]))
                sub = target - float(0)
                overpv = df.PV[j] - watt
                sum_overpv += overpv
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
                    sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
                    sub = target - lefted_batt     
                                           
        else:
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                charging_watt = df.PV[j] - watt
                missing_watt = maxbatt - levelbatt[j]
                if (charging_watt > missing_watt):
                    charging_watt = missing_watt *effi
                else:
                    charging_watt = charging_watt * effi 
                levelbatt.append(float(levelbatt[j]+(charging_watt)))
                sub = target - float(0)
                overpv = df.PV[j] - watt - charging_watt
                sum_overpv += overpv   
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
                    sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
                    sub = target - lefted_batt                          
    else :
        if (levelbatt[j] > minbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k 
            if (batt_t > watt):
                pv_consumption.append(float(0))
                batt_consumption.append(float(watt))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]-watt))
                sub = target - float(0)
            else:
                lefted_batt = watt - batt_t
                pv_consumption.append(float(0))
                batt_consumption.append(float(batt_t))
                grid_consumption.append(float(lefted_batt))
                levelbatt.append(float(levelbatt[j]-batt_t))
                sub = target - float(lefted_batt)                
        else:
            watt = df1.total_watt[j] - k 
            pv_consumption.append(float(0))
            batt_consumption.append(float(0))
            grid_consumption.append(float(watt))
            levelbatt.append(float(levelbatt[j]))
            sub = target -  watt
            
    print "Consuming watt =",watt       
    print "PV_CONSUMPTION =",pv_consumption[j]
    print "BATT_CONSUMPTION =",batt_consumption[j]
    print "GRID_CONSUMPTION =",grid_consumption[j]
    print "PREVIOUS LEVELBATT =",levelbatt[j],"||| LEFTED LEVELBATT =",levelbatt[j+1]   
    print "PV GENERATION =",df.PV[j],"||| BATT_CHARGING =",charging_watt
    print "______________________________________________________________________________________________\n"
    
    
    print "||| 15 Minutes Lefted You Consumed power from ""PEA"" about",grid_consumption[j],"watt"   
    print "||| NOW YOUR ELECTRICAL BILL IS ABOUT",bill((sum(grid_consumption))/1000,Ft),"bath"   
    print "______________________________________________________________________________________________\n" 
   
       
    c.execute("INSERT INTO thesis.main (Timestamp, old_watt, predicted_watt, target_watt,PV_genarator , levelbatt ,pv_consumption , batt_consumption,grid_consumption,sum_load_watt,watt) VALUES ( %s,  %s,%s, %s, %s, %s, %s, %s, %s, %s, %s)",
              (time_b[j],df1.total_watt[j],pred_watt,target,df.PV[j],levelbatt[j],pv_consumption[j],batt_consumption[j],grid_consumption[j],pv_consumption[j]+batt_consumption[j]+grid_consumption[j],watt))
    conn.commit()  
  
    check_state = appliances(j) 
   
    c.execute("INSERT INTO thesis.measure_15devices (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt) VALUES ( %s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s)",
              (time_b[j],check_state[1],check_state[2],check_state[3]-ans_air,check_state[4]-ans_com,check_state[5]-ans_elec,check_state[6]-ans_hair,check_state[7],check_state[8]-ans_iphon,check_state[9]-ans_fan,check_state[10]--ans_tv,check_state[11],check_state[12],check_state[13],check_state[14]-ans_water,check_state[15],watt))               
    conn.commit()
    
    all_power.append(watt/1000)
    df_power = pd.DataFrame(all_power)

    ###   [Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt]
    del check_state[13]   # del  rice_cooker
    del check_state[12]   # del iron
    del check_state[11]   # del washing_machine
    del check_state[7]    # del microwave
    del check_state[2]    # del wireless_router
    del check_state[1]    # del refrigerator
    del check_state[0]    # del Timestamp
    del check_state[-1]   # del  total_watt
    del check_state[-1]   # del light_system
    ###   [ aircont, computer, elec_thermo, hair_dryer, iphonecharger,fan,tv, water_heater]
           
    if j == 0:
        sum_sub = sub       
    else :
        sum_sub = sum_sub + sub      
    
    if sum_sub < 0: ##turn OFF devices 
        print "\n_____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________ "
        print "\n"
        print "m_air =",check_state[0] , "m_fan=",check_state[5] , "m_tv =",check_state[6] , "m_com =",check_state[1] , "m_iphon =",check_state[4] , "m_elec=",check_state[2] , "m_hair=",check_state[3] , "m_water =",check_state[7]        
                
        if  check_state[0] > 0 and trinker[0] == 0:  #air
            m_air = end_air(j)-1
            count_air += 1
            
        elif  check_state[5] > 0 and trinker[5] == 0:        
            m_fan = end_fan(j)-1
            count_fan += 1
            
        elif  check_state[6] > 0 and trinker[6] == 0:        
            m_tv = end_tv(j)-1
            count_tv += 1  
            
        elif  check_state[1] > 0 and trinker[1] == 0:
            m_com = end_com(j)-1          
            count_com += 1 
            
        elif  check_state[4] > 0 and trinker[4] == 0:        
            m_iphon = end_iphon(j)-1
            count_iphon += 1
            
        elif  check_state[2] > 0 and trinker[2] == 0:
            m_elec = end_elec(j)-1
            count_elec += 1 
            
        elif  check_state[3] > 0 and trinker[3] == 0:        
            m_hair = end_hair(j)-1                    
            count_hair += 1 
            
        elif check_state[7] > 0 and trinker[7] == 0:        
            m_water = end_water(j)-1
            count_water += 1 
#         else:
#             print "No appliances"
            
        if j <= m_air:
            trinker[0] = 1
        else :
            trinker[0] = 0
            
        if j <= m_com:
             trinker[1] = 1
        else :
            trinker[1] = 0 
            
        if j <= m_elec:
             trinker[2] = 1 
        else :
            trinker[2] = 0  
            
        if j <= m_hair:
             trinker[3] = 1
        else :
            trinker[3] = 0  
            
        if j <= m_iphon:
             trinker[4] = 1 
        else :
            trinker[4] = 0  
            
        if j <= m_fan:
             trinker[5] = 1 
        else :            
            trinker[5] = 0  
            
        if j <= m_tv:
             trinker[6] = 1
        else :
            trinker[6] = 0
            
        if j <= m_water:
             trinker[7] = 1 
        else :
            trinker[7] = 0                
#         print "             ",   m_air   , "           ",   m_fan  , "          ",    m_tv   , "             ",  m_com  , "               ", m_iphon , "            ", m_elec  , "            ",m_hair     , "               ",m_water                 
#         print "             ",trinker[0] , "           ",trinker[5] , "         ",trinker[6] , "             ",trinker[7] , "               ",trinker[4] , "           ",trinker[2] , "            ",trinker[3] , "               ",trinker[7]                 
      
        j += 1  
        k = state(j,m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)
        ans_air = k[0] 
        ans_com = k[1] 
        ans_elec = k[2] 
        ans_hair = k[3] 
        ans_iphon = k[4] 
        ans_fan = k[5]
        ans_tv = k[6] 
        ans_water = k[7] 
        k = k[8]          
    else: 
        print "\n______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________ "
        j += 1
        k = state(j, m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)  
        ans_air = k[0] 
        ans_com = k[1] 
        ans_elec = k[2] 
        ans_hair = k[3] 
        ans_iphon = k[4] 
        ans_fan = k[5]
        ans_tv = k[6] 
        ans_water = k[7] 
        k = k[8]
    print "\n"              
    charging_watt = float(0)     
    print "                             -------------------------------------                                                            \n"
      
    while ( h < (len(df_power)/96) ) : 
        print """\n. . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .\n"""
#         print (k*24),"to",(k+1)*24
        sum_p =  df_power[(h*96):((h+1)*96)].sum()
        sum_power.append(sum_p)
        
        sum_pv = sum(pv_consumption[(h*96):((h+1)*96)])
        sum_pvconsumption.append(sum_pv/1000)
        
        sum_batt = sum(batt_consumption[(h*96):((h+1)*96)])
        sum_battconsumption.append(sum_batt/1000)
        
        sum_grid = sum(grid_consumption[(h*96):((h+1)*96)])
        sum_gridconsumption.append(sum_grid/1000)
        
        df_power2 = pd.DataFrame(sum_power)  
        df_power3 = pd.DataFrame(sum_pvconsumption)  
        df_power4 = pd.DataFrame(sum_battconsumption)  
        df_power5 = pd.DataFrame(sum_gridconsumption)           
        result = pd.concat([df_power2, df_power3, df_power4, df_power5], axis=1)
        result.columns = ['power consumption','From PV','From BATTERY','From PEA']
        print result
        print "Power consuming between" ,time_a[h*96], "to" ,time_b[(h+1)*96-1], "equal to", result.iloc[h]['power consumption']," kW. -->> equal to",bill(float(result.iloc[h]['From PEA']),Ft),"bath"
        print """///////////////////////////////////////////////////////////////////////////////////////////////////////////////\n"""
        h +=1 
         
print "-------------YOUR PROGRAM IS DONE-----------------"
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
# Out:
# the minimum MSE of prediction = 4.21446848609e-05 by alpha = 0.4 beta = 0.5 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 00:14:59'AND Timestamp<='2016-10-31 23:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:14:59' ;
# BY USE alpha = 0.4 beta = 0.5 gamma = 0.9
# predicted watt is  283.585887462 watt ||||| targeted watt at t is  186.612925199 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 313.058
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 313.058
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 313.058 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 41.97 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 265.9 m_fan= 0.0 m_tv = 16.1827 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 1
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:14:59' ;
# the minimum MSE of prediction = 0.329357772534 by alpha = 0.4 beta = 0.4 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 00:29:59'AND Timestamp<='2016-11-01 00:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:29:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 1.0
# predicted watt is  332.71007012 watt ||||| targeted watt at t is  218.938960552 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 295.642
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 295.642
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 295.642 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 42.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 263.3 m_fan= 0.0 m_tv = 16.4757 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 2
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:29:59' ;
# the minimum MSE of prediction = 4.34175519889e-05 by alpha = 0.3 beta = 0.8 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 00:44:59'AND Timestamp<='2016-11-01 00:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:44:59' ;
# BY USE alpha = 0.3 beta = 0.8 gamma = 0.2
# predicted watt is  250.329398582 watt ||||| targeted watt at t is  164.728582761 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 293.716
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 293.716
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 293.716 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 43.99 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 261.2 m_fan= 0.0 m_tv = 16.5452 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 3
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:44:59' ;
# the minimum MSE of prediction = 0.00272567580355 by alpha = 0.6 beta = 0.6 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 00:59:59'AND Timestamp<='2016-11-01 00:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:59:59' ;
# BY USE alpha = 0.6 beta = 0.6 gamma = 0.5
# predicted watt is  288.778650635 watt ||||| targeted watt at t is  190.030008941 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 270.4128
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 270.4128
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 270.4128 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 44.91 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 00:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 258.8 m_fan= 0.0 m_tv = 16.4982 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 4
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 00:59:59' ;
# the minimum MSE of prediction = 0.000153457988047 by alpha = 0.7 beta = 0.3 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 01:14:59'AND Timestamp<='2016-11-01 00:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:14:59' ;
# BY USE alpha = 0.7 beta = 0.3 gamma = 1.0
# predicted watt is  345.327858045 watt ||||| targeted watt at t is  227.242061723 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 174.6298
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 174.6298
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 174.6298 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 45.51 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 160.021 m_fan= 0.0 m_tv = 16.5242 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 5
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:14:59' ;
# the minimum MSE of prediction = 32.6670470124 by alpha = 0.3 beta = 0.9 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 01:29:59'AND Timestamp<='2016-11-01 01:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:29:59' ;
# BY USE alpha = 0.3 beta = 0.9 gamma = 0.8
# predicted watt is  65.4263300151 watt ||||| targeted watt at t is  43.0536192701 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 278.7209
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 278.7209
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 278.7209 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 46.46 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 265.3 m_fan= 0.0 m_tv = 16.4631 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 6
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:29:59' ;
# the minimum MSE of prediction = 0.205161003877 by alpha = 0.1 beta = 0.4 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 01:44:59'AND Timestamp<='2016-11-01 01:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:44:59' ;
# BY USE alpha = 0.1 beta = 0.4 gamma = 0.2
# predicted watt is  290.332542921 watt ||||| targeted watt at t is  191.052543552 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 211.6999
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 211.6999
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 211.6999 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.19 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 201.558 m_fan= 0.0 m_tv = 16.4631 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 7
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:44:59' ;
# the minimum MSE of prediction = 0.002138873193 by alpha = 0.2 beta = 0.0 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 01:59:59'AND Timestamp<='2016-11-01 01:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:59:59' ;
# BY USE alpha = 0.2 beta = 0.0 gamma = 0.3
# predicted watt is  215.412200188 watt ||||| targeted watt at t is  141.751414925 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 218.8001
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 218.8001
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 218.8001 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.94 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 01:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'tv'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 204.317 m_fan= 0.0 m_tv = 16.4559 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 8
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 01:59:59' ;
# the minimum MSE of prediction = 3.54641548417e-05 by alpha = 0.6 beta = 0.1 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 02:14:59'AND Timestamp<='2016-11-01 01:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:14:59' ;
# BY USE alpha = 0.6 beta = 0.1 gamma = 0.7
# predicted watt is  181.790603646 watt ||||| targeted watt at t is  119.62681438 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 275.233
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 275.233
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 275.233 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.88 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 263.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 9
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:14:59' ;
# the minimum MSE of prediction = 1.35548057161 by alpha = 0.2 beta = 0.3 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 02:29:59'AND Timestamp<='2016-11-01 02:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:29:59' ;
# BY USE alpha = 0.2 beta = 0.3 gamma = 0.8
# predicted watt is  260.809288808 watt ||||| targeted watt at t is  171.624846142 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 156.767
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 156.767
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 156.767 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 49.42 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 147.621 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 10
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:29:59' ;
# the minimum MSE of prediction = 0.205399553254 by alpha = 0.1 beta = 0.0 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 02:44:59'AND Timestamp<='2016-11-01 02:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:44:59' ;
# BY USE alpha = 0.1 beta = 0.0 gamma = 0.6
# predicted watt is  203.208203415 watt ||||| targeted watt at t is  133.720607902 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 247.188
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 247.188
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 247.188 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.26 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 238.629 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 11
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:44:59' ;
# the minimum MSE of prediction = 0.000365793127962 by alpha = 0.5 beta = 0.6 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 02:59:59'AND Timestamp<='2016-11-01 02:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:59:59' ;
# BY USE alpha = 0.5 beta = 0.6 gamma = 0.7
# predicted watt is  204.66956186 watt ||||| targeted watt at t is  134.682250868 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 187.529
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 187.529
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 187.529 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.91 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 02:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 173.258 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 12
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 02:59:59' ;
# the minimum MSE of prediction = 0.000448885603524 by alpha = 0.2 beta = 0.0 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 03:14:59'AND Timestamp<='2016-11-01 02:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:14:59' ;
# BY USE alpha = 0.2 beta = 0.0 gamma = 0.3
# predicted watt is  177.216210527 watt ||||| targeted watt at t is  116.616647376 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 192.837
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 192.837
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 192.837 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.57 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 176.808 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 13
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:14:59' ;
# the minimum MSE of prediction = 9.67230814942e-05 by alpha = 0.1 beta = 0.7 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 03:29:59'AND Timestamp<='2016-11-01 03:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:29:59' ;
# BY USE alpha = 0.1 beta = 0.7 gamma = 0.3
# predicted watt is  186.453717425 watt ||||| targeted watt at t is  122.695363772 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 216.646
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 216.646
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 216.646 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 52.31 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 200.854 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 14
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:29:59' ;
# the minimum MSE of prediction = 0.000187744377816 by alpha = 0.3 beta = 0.2 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 03:44:59'AND Timestamp<='2016-11-01 03:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:44:59' ;
# BY USE alpha = 0.3 beta = 0.2 gamma = 0.5
# predicted watt is  164.954607848 watt ||||| targeted watt at t is  108.547932942 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 169.583
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 169.583
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 169.583 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 52.89 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 158.525 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 15
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:44:59' ;
# the minimum MSE of prediction = 8.35126616594e-06 by alpha = 0.5 beta = 0.8 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 03:59:59'AND Timestamp<='2016-11-01 03:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:59:59' ;
# BY USE alpha = 0.5 beta = 0.8 gamma = 0.3
# predicted watt is  155.516245025 watt ||||| targeted watt at t is  102.337043849 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 127.117
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 127.117
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 127.117 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 53.32 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 03:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 111.775 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 16
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 03:59:59' ;
# the minimum MSE of prediction = 0.558494655625 by alpha = 1.0 beta = 1.0 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 04:14:59'AND Timestamp<='2016-11-01 03:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:14:59' ;
# BY USE alpha = 1.0 beta = 1.0 gamma = 0.6
# predicted watt is  115.270725 watt ||||| targeted watt at t is  75.8535883946 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 222.742
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 222.742
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 222.742 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.09 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 210.279 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 17
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:14:59' ;
# the minimum MSE of prediction = 0.0214919245254 by alpha = 0.2 beta = 0.6 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 04:29:59'AND Timestamp<='2016-11-01 04:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:29:59' ;
# BY USE alpha = 0.2 beta = 0.6 gamma = 0.5
# predicted watt is  237.153689086 watt ||||| targeted watt at t is  156.058342812 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 169.529
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 169.529
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 169.529 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.67 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 158.942 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 18
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:29:59' ;
# the minimum MSE of prediction = 0.00135914141307 by alpha = 0.4 beta = 0.3 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 04:44:59'AND Timestamp<='2016-11-01 04:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:44:59' ;
# BY USE alpha = 0.4 beta = 0.3 gamma = 1.0
# predicted watt is  163.18346364 watt ||||| targeted watt at t is  107.382436293 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 120.579
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 120.579
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 120.579 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 55.08 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 105.733 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 19
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:44:59' ;
# the minimum MSE of prediction = 0.0170452183874 by alpha = 0.1 beta = 0.0 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 04:59:59'AND Timestamp<='2016-11-01 04:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:59:59' ;
# BY USE alpha = 0.1 beta = 0.0 gamma = 0.9
# predicted watt is  103.37625344 watt ||||| targeted watt at t is  68.0264635986 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 119.033
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 119.033
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 119.033 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 55.49 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 04:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 107.821 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 20
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 04:59:59' ;
# the minimum MSE of prediction = 0.000662252920785 by alpha = 0.9 beta = 0.0 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 05:14:59'AND Timestamp<='2016-11-01 04:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:14:59' ;
# BY USE alpha = 0.9 beta = 0.0 gamma = 0.0
# predicted watt is  114.23643401 watt ||||| targeted watt at t is  75.1729760097 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 137.113
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 137.113
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 137.113 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 55.96 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 128.117 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 21
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:14:59' ;
# the minimum MSE of prediction = 0.000252407599973 by alpha = 0.2 beta = 0.2 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 05:29:59'AND Timestamp<='2016-11-01 05:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:29:59' ;
# BY USE alpha = 0.2 beta = 0.2 gamma = 0.3
# predicted watt is  109.647165245 watt ||||| targeted watt at t is  72.1530201283 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 152.788
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 152.788
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 152.788 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 56.48 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 143.992 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 22
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:29:59' ;
# the minimum MSE of prediction = 2.12726439137 by alpha = 0.1 beta = 0.3 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 05:44:59'AND Timestamp<='2016-11-01 05:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:44:59' ;
# BY USE alpha = 0.1 beta = 0.3 gamma = 0.4
# predicted watt is  143.025576121 watt ||||| targeted watt at t is  94.1175930056 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 157.712
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 157.712
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 157.712 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 57.02 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 142.579 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 23
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:44:59' ;
# the minimum MSE of prediction = 0.0114096332723 by alpha = 0.9 beta = 0.3 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 05:59:59'AND Timestamp<='2016-11-01 05:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:59:59' ;
# BY USE alpha = 0.9 beta = 0.3 gamma = 0.0
# predicted watt is  147.439372117 watt ||||| targeted watt at t is  97.0220795064 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 154.117
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 154.117
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 154.117 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 57.55 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 05:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 137.817 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 24
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 05:59:59' ;
# the minimum MSE of prediction = 0.000141857690936 by alpha = 0.9 beta = 0.5 gamma = 0.0
# ______________________________________________________________________________________________
#
# ...
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 10:29:59' ;
# the minimum MSE of prediction = 0.0400664615778 by alpha = 0.1 beta = 0.8 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 10:44:59'AND Timestamp<='2016-11-01 10:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 10:44:59' ;
# BY USE alpha = 0.1 beta = 0.8 gamma = 0.0
# predicted watt is  36.3266716171 watt ||||| targeted watt at t is  23.9046678728 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 26.8958
# PV_CONSUMPTION = 26.8958
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 863.992 ||| LEFTED LEVELBATT = 939.740032
# PV GENERATION = 105.8 ||| BATT_CHARGING = 75.748032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 10:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 43
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 10:44:59' ;
# the minimum MSE of prediction = 0.000831024412796 by alpha = 0.8 beta = 0.7 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 10:59:59'AND Timestamp<='2016-11-01 10:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 10:59:59' ;
# BY USE alpha = 0.8 beta = 0.7 gamma = 0.2
# predicted watt is  46.6263998837 watt ||||| targeted watt at t is  30.6823761636 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 29.0083
# PV_CONSUMPTION = 29.0083
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 939.740032 ||| LEFTED LEVELBATT = 1007.988064
# PV GENERATION = 100.1 ||| BATT_CHARGING = 68.248032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 10:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 44
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 10:59:59' ;
# the minimum MSE of prediction = 5.47302681035e-05 by alpha = 0.8 beta = 0.3 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 11:14:59'AND Timestamp<='2016-11-01 10:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:14:59' ;
# BY USE alpha = 0.8 beta = 0.3 gamma = 0.5
# predicted watt is  30.8505445937 watt ||||| targeted watt at t is  20.3011173163 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 33.7167
# PV_CONSUMPTION = 33.7167
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1007.988064 ||| LEFTED LEVELBATT = 1058.468032
# PV GENERATION = 86.3 ||| BATT_CHARGING = 50.479968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 11:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 45
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:14:59' ;
# the minimum MSE of prediction = 0.00508311400115 by alpha = 0.9 beta = 0.5 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 11:29:59'AND Timestamp<='2016-11-01 11:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:29:59' ;
# BY USE alpha = 0.9 beta = 0.5 gamma = 0.9
# predicted watt is  40.3773521905 watt ||||| targeted watt at t is  26.5702072536 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 34.0792
# PV_CONSUMPTION = 34.0792
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1058.468032 ||| LEFTED LEVELBATT = 1100.92
# PV GENERATION = 78.3 ||| BATT_CHARGING = 42.451968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 11:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 46
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:29:59' ;
# the minimum MSE of prediction = 0.000202473363463 by alpha = 0.6 beta = 0.3 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 11:44:59'AND Timestamp<='2016-11-01 11:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:44:59' ;
# BY USE alpha = 0.6 beta = 0.3 gamma = 0.6
# predicted watt is  35.2881574406 watt ||||| targeted watt at t is  23.2212764317 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 31.1042
# PV_CONSUMPTION = 31.1042
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1100.92 ||| LEFTED LEVELBATT = 1111.571968
# PV GENERATION = 42.2 ||| BATT_CHARGING = 10.651968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 11:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 47
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:44:59' ;
# the minimum MSE of prediction = 5.1849812918e-05 by alpha = 0.4 beta = 0.2 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 11:59:59'AND Timestamp<='2016-11-01 11:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:59:59' ;
# BY USE alpha = 0.4 beta = 0.2 gamma = 0.1
# predicted watt is  32.2340582476 watt ||||| targeted watt at t is  21.2115347292 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 31.2833
# PV_CONSUMPTION = 31.2833
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1111.571968 ||| LEFTED LEVELBATT = 1166.116
# PV GENERATION = 88.1 ||| BATT_CHARGING = 54.544032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 11:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 48
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 11:59:59' ;
# the minimum MSE of prediction = 3.05490451264e-05 by alpha = 0.7 beta = 0.1 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 12:14:59'AND Timestamp<='2016-11-01 11:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 12:14:59' ;
# BY USE alpha = 0.7 beta = 0.1 gamma = 0.4
# predicted watt is  29.8576240304 watt ||||| targeted watt at t is  19.6477286288 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 32.5708
# PV_CONSUMPTION = 32.5708
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1166.116 ||| LEFTED LEVELBATT = 1186.016032
# PV GENERATION = 53.3 ||| BATT_CHARGING = 19.900032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 12:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 49
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 12:14:59' ;
# the minimum MSE of prediction = 0.000730112037779 by alpha = 0.6 beta = 0.5 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp>='2016-10-01 12:29:59'AND Timestamp<='2016-11-01 12:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 12:29:59' ;
# BY USE alpha = 0.6 beta = 0.5 gamma = 0.5
# predicted watt is  35.6125274293 watt ||||| targeted watt at t is  23.4347272242 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 28.45
# PV_CONSUMPTION = 28.45
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1186.016032 ||| LEFTED LEVELBATT = 1219.088032
# PV GENERATION = 62.9 ||| BATT_CHARGING = 33.072
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.86 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month2 WHERE  Timestamp = '2016-11-01 12:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 50
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure_15devices WHERE Timestamp = '2016-11-01 12:29:59' ;

# %%
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
print "control_air-cont (times) ="      , count_air
print "control_fan (times) ="           , count_fan
print "control_tv (times) ="            , count_tv
print "control_computer (times) ="      , count_com
print "control_iphone_charger (times) =", count_iphon
print "control_elec_thermo (times) ="   , count_elec
print "control_hair_dryer (times) ="    , count_hair
print "control_water_heater (times) ="  , count_water
print sum_overpv/1000
