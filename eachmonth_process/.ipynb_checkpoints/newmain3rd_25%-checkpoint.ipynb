# %% [markdown]
# ### main of month 3 : DECEMBER (31 days) ||| 25 percent ||

# %% [markdown]
# ### EVERY TIME
# #### RESET DATABASE &  RESTART KERNAL & CLAER OUTPUT

# %%
import pandas as pd
import MySQLdb
import numpy as np
import time
import datetime 
import random
import matplotlib.pyplot as plt
# %matplotlib inline 

from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr
# ____________________________________________________________________________________________________   

'''
##  PRIORITY TABLE
'''
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
      
        return ''.join(html)
 # ____________________________________________________________________________________________________   
    
"""
## CONVERSING  UNIT (kW) >>  BILL (bath)
"""
def bill(allpow,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge
 
    ## Fundamental parameter      
    if allpow <= 0:
        bath = 0
    elif 0 <= allpow <= 150:
        bath = allpow*t1
    elif  151 <= allpow <= 400:
        power = allpow-150
        bath_1 = 150*t1
        bath_2 = power*t2
        bath = bath_1+bath_2
    else:
        power = allpow-150
        bath_1 = 150*t1
        power = power-250
        bath_2 = 250*t2
        bath_3 = power*t3
        bath = bath_1+bath_2+bath_3   
    service_price = 38.22  #permonth (fixed)   
    ## FT -33.2 satang/unit
    FT_price = allpow*Ft
    ## VAT 7%
    VAT_price = ((service_price+bath)+FT_price)*0.07
    bill = bath+service_price+FT_price+VAT_price
    return round(bill,2)
 # ____________________________________________________________________________________________________   

"""
## CONVERSING  BILL (bath) >>  UNIT (kW) >> 
"""
def inbill(bath,Ft):
    
    t1 = 3.2484      # rate_1
    t2 = 4.2218      # rate_2
    t3 = 4.4217      # rate_3
    ser = 38.22      # service_charge  
    u = symbols('u')
    test_1 = solve(Eq((u*t1)+ser+(u*Ft)+(0.07*((u*t1)+ser))+(0.07*(u*Ft)),bath))
    test_2 = solve(Eq((150*t1)+((u-150)*t2)+ser+(u*Ft)+(0.07*((150*t1)+((u-150)*t2)+ser))+(0.07*(u*Ft)),bath))
    test_3 = solve(Eq((150*t1)+(250*t2)+((u-400)*t3)+ser+(u*Ft)+(0.07*((150*t1)+(250*t2)+((u-400)*t3)+ser))+(0.07*(u*Ft)),bath))
    if 1 <=  test_1[0] <= 150:
        unit = test_1[0]
    elif 151 <=  test_2[0] <=  400:
        unit = test_2[0]
    else:
        unit = test_3[0]
    return (round(unit))
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The ENDING POSITION OF EACH APPLIANCES
"""
############################################################ d
def end_air(j): 
    check = 1  
    m_air = j+1   
    while (check == 1):
        while df1.aircont[ m_air] > 0 and m_air < (96*31)-1:
            m_air += 1
        check = 0
    return  m_air

def end_com(j): 
    check = 1  
    m_com = j+1   
    while (check == 1):
        while df1.computer[m_com] > 0 and m_com < (96*31)-1:
            m_com += 1  
        check = 0
    return  m_com

def end_elec(j): 
    check = 1  
    m_elec = j+1   
    while (check == 1):
        while df1.elec_thermo[m_elec] > 0 and m_elec < (96*31)-1:
            m_elec += 1  
        check = 0
    return  m_elec

def end_hair(j): 
    check = 1  
    m_hair = j+1   
    while (check == 1):
        while df1.hair_dryer[m_hair] > 0 and m_hair < (96*31)-1:
            m_hair += 1  
        check = 0
    return  m_hair

def end_iphon(j): 
    check = 1  
    m_iphon = j+1   
    while (check == 1):
        while df1.iphonecharger[ m_iphon] > 0 and m_iphon < (96*31)-1:
            m_iphon += 1  
        check = 0
    return  m_iphon

def end_fan(j): 
    check = 1  
    m_fan = j+1   
    while (check == 1):
        while df1.fan[m_fan] > 0 and m_fan < (96*31)-1:
            m_fan += 1  
        check = 0
    return  m_fan

def end_tv(j): 
    check = 1  
    m_tv = j+1   
    while (check == 1):
        while df1.tv[m_tv] > 0 and m_tv < (96*31)-1 :
            m_tv += 1  
        check = 0
    return  m_tv

def end_water(j): 
    check = 1  
    m_water = j+1   
    while (check == 1):
        while df1.water_heater[m_water] > 0 and m_water < (96*31)-1:
            m_water += 1  
        check = 0
    return  m_water
 # ____________________________________________________________________________________________________   

"""
## CHECKING  The STATE OF APPLIANCES 
"""    
def state(j,m_air,m_com, m_elec,m_hair,m_iphon, m_fan ,m_tv, m_water) :
    if j <= m_air:
        ans1 = 18    
    else:
        ans1 = 0
    if j <= m_com:
        ans2 = df1.computer[j]
    else:
        ans2 = 0
    if j <= m_elec:
        ans3 = df1.elec_thermo[j]
    else:
        ans3 = 0
    if j <= m_hair:
        ans4 = df1.hair_dryer[j]
    else:
        ans4 = 0
    if j <= m_iphon:
        ans5 = df1.iphonecharger[j]
    else:
        ans5 = 0
    if j <= m_fan:
        ans6 = df1.fan[j]
    else:
        ans6 = 0
    if j <= m_tv:
        ans7 = df1.tv[j]
    else:
        ans7 = 0
    if j <= m_water:
        ans8 = df1.water_heater[j]
    else:
        ans8 = 0

    k = ans1+ans2+ans3+ans4+ans5+ans6+ans7+ans8
#     print "substact k watt out from watt = ",k,"watt    ||||||" ,ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8
    return (ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8,k) 
 # ____________________________________________________________________________________________________   

"""
## PREDICTION 
"""        
def initial_trend(series, slen):
    sum = 0.0
    for i in range(slen):
        sum += float(series[i+slen] - series[i]) / slen
    return sum / slen

def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals
 # ____________________________________________________________________________________________________   

"""
## FITTING PARAMETERS FOR PREDICTION
""" 
from sklearn.metrics import mean_squared_error
def fittingparameter(data_y,j):
    count_alpha = 0
    count_beta = 0
    count_gamma = 0
    alpha = float(0)
    beta = float(0)
    gamma = float(0)
    index_alpha =[]
    index_beta =[]
    index_gamma = []
    act = j
    data = data_y
    pred_no = 1
    ramda = 0.1
    MSE_holtload = []    
    ##############################################################
    ### ?????????????????????????????????????????????????????????? DATABASE
    query_last = "SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '%s' ;"% (time_b_last[act+1])
    print query_last
    df1 = pd.read_sql(query_last, conn)
    while (alpha <= float(1)):
        count_alpha += 1
        beta = float(0)
        while (beta <=float(1)):
            count_beta += 1 
            gamma = float(0)
            while (gamma <= float(1)):
                count_gamma += 1
                pred_h = triple_exponential_smoothing(data,96*7,alpha,beta,gamma,pred_no)
                pred_data = pred_h[len(pred_h)-(pred_no):]                                               
                MSE = mean_squared_error (df1.total_watt, pred_data)   
#                 print MSE              
                MSE_holtload.append(MSE)
                index_alpha.append(alpha)
                index_beta.append(beta)
                index_gamma.append(gamma)     
#                 print index_alpha,index_beta,index_gamma
                gamma += ramda
            beta += ramda
        alpha += ramda  
#     print  count_gamma,count_beta,count_alpha    
    index_MSE = MSE_holtload.index(min(MSE_holtload))
    MSE_min = MSE_holtload[index_MSE]
    alpha = index_alpha[index_MSE]
    beta = index_beta[index_MSE]
    gamma= index_gamma[index_MSE]
    print "the minimum MSE of prediction =",MSE_min,"by alpha =",alpha,"beta =",beta,"gamma =",gamma
    return (alpha,beta,gamma)
 # ____________________________________________________________________________________________________   

"""
## CHECKING THE STATUS OF APPLIANCES ON THAT TIME
""" 
def appliances(j):
    ############################################################## (day + table_database)
    ### ??????????????????????????????????????????????????????????
    time_b = pd.date_range('2016-12-01 00:14:59', periods=96*d, freq='15T')
    conn = MySQLdb.connect("localhost","conn","hems")
    c = conn.cursor()
    query1 = "SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '%s'; "% (time_b[j])
    print "Check status of appliances from"
    print query1
    df1 = pd.read_sql(query1, conn) 
    
    for row in df1.iterrows():
        index, data = row
        state = data.tolist()
    i = 1
    status = []
    while(i < len(state)-1):
        dict = { 1:'refrigerator',2:'wireless_router',3:'aircont',4:'computer',5:'electrical_thermo',6:'hair_dryer',7:'microwave',8:'iphone_charger',9:'fan',10:'tv'
                ,11:'washing_machine',12:'iron',13:'rice_cooker',14:'water_heater',15:'light_system'}
        if state[i] != 0:
            a = dict[i]
            status.append(a)
        i +=1  
    print "NOW !! you are turning ON" ,status ,"=",len(status),"items"
    print "______________________________________________________________________________________________\n"
    return(state)
 # ____________________________________________________________________________________________________

# %%
# Set paremeters
j = 0
d = 32   ################################
pred_no = 1
z  = 0 
trinker = [0,0,0,0,0,0,0,0]
batt = float(2.900*1000)     ## SIZE OF BATTERY  2.9 kW 
k = 0
all_power = []
sum_power = []
sum_p = []
sum_pv = []
sum_pvconsumption = []
sum_batt = []
sum_battconsumption = []
sum_grid= []
sum_gridconsumption = []
h = 0

ans_air = 0 
ans_com = 0 
ans_elec = 0 
ans_hair = 0 
ans_iphon = 0 
ans_fan = 0
ans_tv = 0
ans_water = 0
m_air = 0
m_com = 0
m_elec = 0
m_hair = 0
m_iphon = 0
m_fan = 0
m_tv = 0   
m_water = 0
minbatt = batt * 0.2        ## PERIOD OF  BATTERY  USING  2.9*0.2 = 580 - 2900
maxbatt = batt
effi = float(0.96)            ##  EFFICIENTCY OF CHARGING  BATTERY  = 96%
levelbatt = []
levelbatt.append(float(580))  ####################################################
pv_consumption = []
batt_consumption = []
grid_consumption = []
overpv = float(0)
sum_overpv = float(0)
charging_watt = float(0)
count_active = 0 

count_air = 0
count_fan = 0
count_tv = 0
count_com = 0
count_iphon = 0
count_elec = 0
count_hair = 0
count_water = 0
 
# Connect MYSQL
conn= MySQLdb.connect("localhost","conn","hems","power")
c = conn.cursor()

# Read the data of lastest month 
####################################################(database(-1 month) + DAY)
query0 = "SELECT Timestamp,total_watt FROM thesis.measure_15devices_month2 WHERE Timestamp >= '2016-11-01 00:14:59' AND  Timestamp <= '2016-11-30 23:59:59';"
df = pd.read_sql(query0, conn)   
print "\n"
print "Total unit consumption in the last month equal to",df.total_watt.sum()/1000,"kW"
last_bill = bill(df.total_watt.sum()/1000,-0.048)    
print "The lastest elctrical bill is about",last_bill,"bath with Ft = -0.048"
print "\n______________________________________________________________________________________________\n"
   
x = raw_input('What is about Ft in the next month?',)
Ft = float(x)
    
y = raw_input('How about expected price in electrical bill do you want?')
target_price = float(y)

print "\n______________________________________________________________________________________________"    
print "\nThe expected price in the next electrical bill is about",target_price,"bath with Ft =", Ft
discount = (last_bill-target_price)/last_bill *100
print "To compare with the lastest bill is equal to",round(discount,2),"% cut-off"
target_unit = inbill(target_price,Ft)
print "Total available unit consumption in the next month equal to",target_unit,"kW or unit"
print "______________________________________________________________________________________________\n"


# Show the priority of 15 appliances
name = ['refrigerator','wireless_router','aircont','computer','electrical_thermo','hair_dryer','microwave','iphone_charger','fan','tv','washing_machine','iron','rice_cooker','water_heater','light_system']
types = ['Type1 : always turn on [Dont control]','Type1 : always turn on','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday'
        ,'Type2 : turn on oncetime&everyday','Type2 : turn on oncetime&everyday','Type3 : turn on manytime(1-3) in everyday','Type3 : turn on manytime(1-3) in everyday','Type4 : turn on oncetime in someday'
        ,'Type4 : turn on oncetime in someday','Type4 : turn on oncetime in someday','Type5 : turn on manytime(1-3) in someday','Type6 : monitor power consuming [Dont control]']
prior = ['x','x','1','4','6','7','9','5','2','3','12','11','10','9','x']
table = ListTable()
table.append(['the 15 appliances','Type of appliances','the priority'])
for i in xrange(15):
    x = name[i]
    y = types[i]
    z = prior[i]
    table.append([x, y ,z])
    
print "\n"

table
# Out:
# Total unit consumption in the last month equal to 386.4451217 kW
# The lastest elctrical bill is about 1610.52 bath with Ft = -0.048
#
# ______________________________________________________________________________________________
# ______________________________________________________________________________________________
#
# The expected price in the next electrical bill is about 1200.0 bath with Ft = -0.048
# To compare with the lastest bill is equal to 25.49 % cut-off
# Total available unit consumption in the next month equal to 295.0 kW or unit
# ______________________________________________________________________________________________
# [['the 15 appliances', 'Type of appliances', 'the priority'],
#  ['refrigerator', 'Type1 : always turn on [Dont control]', 'x'],
#  ['wireless_router', 'Type1 : always turn on', 'x'],
#  ['aircont', 'Type2 : turn on oncetime&everyday', '1'],
#  ['computer', 'Type2 : turn on oncetime&everyday', '4'],
#  ['electrical_thermo', 'Type2 : turn on oncetime&everyday', '6'],
#  ['hair_dryer', 'Type2 : turn on oncetime&everyday', '7'],
#  ['microwave', 'Type2 : turn on oncetime&everyday', '9'],
#  ['iphone_charger', 'Type2 : turn on oncetime&everyday', '5'],
#  ['fan', 'Type3 : turn on manytime(1-3) in everyday', '2'],
#  ['tv', 'Type3 : turn on manytime(1-3) in everyday', '3'],
#  ['washing_machine', 'Type4 : turn on oncetime in someday', '12'],
#  ['iron', 'Type4 : turn on oncetime in someday', '11'],
#  ['rice_cooker', 'Type4 : turn on oncetime in someday', '10'],
#  ['water_heater', 'Type5 : turn on manytime(1-3) in someday', '9'],
#  ['light_system', 'Type6 : monitor power consuming [Dont control]', 'x']]

# %%
d = 32
####################################################( DAY)
time_a_last = pd.date_range('2016-11-01 00:14:59', periods=96*d, freq='15T')
time_b_last = pd.date_range('2016-11-30 23:44:59', periods=96*d, freq='15T')
####################################################( DAY)
time_a = pd.date_range('2016-12-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-12-01 00:14:59', periods=96*d, freq='15T')

conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

####################################################( DATA)
query_empty = """truncate table thesis.main3rd_25""" 
c.execute(query_empty)
print "table thesis.main3rd_25 are Empty!!! \n"

####################################################( DATA)
query_last = "SELECT * FROM thesis.measure3rd_15devices_25 WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a_last[j],time_b_last[j])
df_last  = pd.read_sql(query_last, conn)

### DATABASE OPENING DEVICE *****
####################################################( DATA)
query1 = "SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp >= '%s' AND Timestamp <= '%s'; "% (time_a[0],time_b[(96*d)-1])
df1 = pd.read_sql(query1, conn)

### DATABASE PV *****
####################################################( DAY)
query = "SELECT Timestamp,PV FROM thesis.PV WHERE Timestamp>='%s'AND Timestamp<='%s'; "%('2016-12-01 00:00:00','2016-12-31 23:59:59')
df = pd.read_sql(query, conn)
df['PV'] = ((df.PV/10)*2)

while ( j <= (96*d) -1): # 1 month on OCTOBER

    print "data at :" , j
#     print j,
    print "______________________________________________________________________________________________\n",
    query_last = "\nSELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='%s'AND Timestamp<='%s'; "%(time_a_last[j],time_b_last[j])
#     print query_last
    df_last = pd.read_sql(query_last, conn)
    conn.commit()
    data_y = df_last['total_watt'].values.tolist()   
    ans_fiting = fittingparameter(data_y,j)
    
    query_last_new = "SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='%s'AND Timestamp<='%s';"%(time_a_last[j],time_b_last[j+1])
    query_last_new_1 = "SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '%s' ;"% (time_b_last[j+2])
    print "______________________________________________________________________________________________"
    print "\n",query_last_new  
    print query_last_new_1
    print "BY USE alpha =",ans_fiting[0],"beta =",ans_fiting[1],"gamma =",ans_fiting[2]
    df_last_new = pd.read_sql(query_last_new, conn)
    conn.commit()
    data_y = df_last_new['total_watt'].values.tolist()     
    pred_h = triple_exponential_smoothing(data_y, 96*7, ans_fiting[0], ans_fiting[1], ans_fiting[2],1)
    pred_data = pred_h[len(pred_h)-(pred_no):]   
    pred_watt = abs(pred_data[0])
    target = pred_watt*(1-(discount/100))
    print "predicted watt is ",pred_watt ,"watt ||||| targeted watt at t is ",target,"watt"
    print "______________________________________________________________________________________________\n"

    if (df.PV[j] != 0):
        if (levelbatt[j] == maxbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]))
                sub = target - float(0)
                overpv = df.PV[j] - watt
                sum_overpv += overpv
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
                    sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
                    sub = target - lefted_batt     
                                           
        else:
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k
            if (df.PV[j] > watt):
                pv_consumption.append(float(watt))
                batt_consumption.append(float(0))
                grid_consumption.append(float(0))
                charging_watt = df.PV[j] - watt
                missing_watt = maxbatt - levelbatt[j]
                if (charging_watt > missing_watt):
                    charging_watt = missing_watt *effi
                else:
                    charging_watt = charging_watt * effi 
                levelbatt.append(float(levelbatt[j]+(charging_watt)))
                sub = target - float(0)
                overpv = df.PV[j] - watt - charging_watt
                sum_overpv += overpv   
            else:
                lefted_pv = watt-df.PV[j]
                pv_consumption.append(float(df.PV[j]))
                if (batt_t > lefted_pv):
                    batt_consumption.append(float(lefted_pv))
                    grid_consumption.append(float(0))
                    levelbatt.append(float(levelbatt[j]-lefted_pv))
                    sub = target - float(0)
                else:
                    lefted_batt = lefted_pv - batt_t
                    batt_consumption.append(float(batt_t))
                    grid_consumption.append(float(lefted_batt))
                    levelbatt.append(float(levelbatt[j]-batt_t))
                    sub = target - lefted_batt                          
    else :
        if (levelbatt[j] > minbatt):
            batt_t = levelbatt[j] - minbatt
            watt = df1.total_watt[j] - k 
            if (batt_t > watt):
                pv_consumption.append(float(0))
                batt_consumption.append(float(watt))
                grid_consumption.append(float(0))
                levelbatt.append(float(levelbatt[j]-watt))
                sub = target - float(0)
            else:
                lefted_batt = watt - batt_t
                pv_consumption.append(float(0))
                batt_consumption.append(float(batt_t))
                grid_consumption.append(float(lefted_batt))
                levelbatt.append(float(levelbatt[j]-batt_t))
                sub = target - float(lefted_batt)                
        else:
            watt = df1.total_watt[j] - k 
            pv_consumption.append(float(0))
            batt_consumption.append(float(0))
            grid_consumption.append(float(watt))
            levelbatt.append(float(levelbatt[j]))
            sub = target -  watt
            
    print "Consuming watt =",watt       
    print "PV_CONSUMPTION =",pv_consumption[j]
    print "BATT_CONSUMPTION =",batt_consumption[j]
    print "GRID_CONSUMPTION =",grid_consumption[j]
    print "PREVIOUS LEVELBATT =",levelbatt[j],"||| LEFTED LEVELBATT =",levelbatt[j+1]   
    print "PV GENERATION =",df.PV[j],"||| BATT_CHARGING =",charging_watt
    print "______________________________________________________________________________________________\n"
    
    
    print "||| 15 Minutes Lefted You Consumed power from ""PEA"" about",grid_consumption[j],"watt"   
    print "||| NOW YOUR ELECTRICAL BILL IS ABOUT",bill((sum(grid_consumption))/1000,Ft),"bath"   
    print "______________________________________________________________________________________________\n" 
   
       
    c.execute("INSERT INTO thesis.main3rd_25 (Timestamp, old_watt, predicted_watt, target_watt,PV_genarator , levelbatt ,pv_consumption , batt_consumption,grid_consumption,sum_load_watt,watt) VALUES ( %s,  %s,%s, %s, %s, %s, %s, %s, %s, %s, %s)",
              (time_b[j],df1.total_watt[j],pred_watt,target,df.PV[j],levelbatt[j],pv_consumption[j],batt_consumption[j],grid_consumption[j],pv_consumption[j]+batt_consumption[j]+grid_consumption[j],watt))
    conn.commit()  
  
    check_state = appliances(j) 
   
    c.execute("INSERT INTO thesis.measure3rd_15devices_25 (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt) VALUES ( %s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s)",
              (time_b[j],check_state[1],check_state[2],check_state[3]-ans_air,check_state[4]-ans_com,check_state[5]-ans_elec,check_state[6]-ans_hair,check_state[7],check_state[8]-ans_iphon,check_state[9]-ans_fan,check_state[10]--ans_tv,check_state[11],check_state[12],check_state[13],check_state[14]-ans_water,check_state[15],watt))               
    conn.commit()
    
    all_power.append(watt/1000)
    df_power = pd.DataFrame(all_power)

    ###   [Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger,fan,tv,washing_machine, iron, rice_cooker, water_heater,light_system, total_watt]
    del check_state[13]   # del  rice_cooker
    del check_state[12]   # del iron
    del check_state[11]   # del washing_machine
    del check_state[7]    # del microwave
    del check_state[2]    # del wireless_router
    del check_state[1]    # del refrigerator
    del check_state[0]    # del Timestamp
    del check_state[-1]   # del  total_watt
    del check_state[-1]   # del light_system
    ###   [ aircont, computer, elec_thermo, hair_dryer, iphonecharger,fan,tv, water_heater]
           
    if j == 0:
        sum_sub = sub       
    else :
        sum_sub = sum_sub + sub      
    
    if sum_sub < 0: ##turn OFF devices 
        print "\n_____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________ "
        print "\n"
        print "m_air =",check_state[0] , "m_fan=",check_state[5] , "m_tv =",check_state[6] , "m_com =",check_state[1] , "m_iphon =",check_state[4] , "m_elec=",check_state[2] , "m_hair=",check_state[3] , "m_water =",check_state[7]        
                
        if  check_state[0] > 0 and trinker[0] == 0:  #air
            m_air = end_air(j)-1
            count_air += 1
            
        elif  check_state[5] > 0 and trinker[5] == 0:        
            m_fan = end_fan(j)-1
            count_fan += 1
            
        elif  check_state[6] > 0 and trinker[6] == 0:        
            m_tv = end_tv(j)-1
            count_tv += 1  
            
        elif  check_state[1] > 0 and trinker[1] == 0:
            m_com = end_com(j)-1          
            count_com += 1 
            
        elif  check_state[4] > 0 and trinker[4] == 0:        
            m_iphon = end_iphon(j)-1
            count_iphon += 1
            
        elif  check_state[2] > 0 and trinker[2] == 0:
            m_elec = end_elec(j)-1
            count_elec += 1 
            
        elif  check_state[3] > 0 and trinker[3] == 0:        
            m_hair = end_hair(j)-1                    
            count_hair += 1 
            
        elif check_state[7] > 0 and trinker[7] == 0:        
            m_water = end_water(j)-1
            count_water += 1 
#         else:
#             print "No appliances"
            
        if j <= m_air:
            trinker[0] = 1
        else :
            trinker[0] = 0
            
        if j <= m_com:
             trinker[1] = 1
        else :
            trinker[1] = 0 
            
        if j <= m_elec:
             trinker[2] = 1 
        else :
            trinker[2] = 0  
            
        if j <= m_hair:
             trinker[3] = 1
        else :
            trinker[3] = 0  
            
        if j <= m_iphon:
             trinker[4] = 1 
        else :
            trinker[4] = 0  
            
        if j <= m_fan:
             trinker[5] = 1 
        else :            
            trinker[5] = 0  
            
        if j <= m_tv:
             trinker[6] = 1
        else :
            trinker[6] = 0
            
        if j <= m_water:
             trinker[7] = 1 
        else :
            trinker[7] = 0                
#         print "             ",   m_air   , "           ",   m_fan  , "          ",    m_tv   , "             ",  m_com  , "               ", m_iphon , "            ", m_elec  , "            ",m_hair     , "               ",m_water                 
#         print "             ",trinker[0] , "           ",trinker[5] , "         ",trinker[6] , "             ",trinker[7] , "               ",trinker[4] , "           ",trinker[2] , "            ",trinker[3] , "               ",trinker[7]                 
      
        j += 1  
        k = state(j,m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)
        ans_air = k[0] 
        ans_com = k[1] 
        ans_elec = k[2] 
        ans_hair = k[3] 
        ans_iphon = k[4] 
        ans_fan = k[5]
        ans_tv = k[6] 
        ans_water = k[7] 
        k = k[8]          
    else: 
        print "\n______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________ "
        j += 1
        k = state(j, m_air,m_com,m_elec ,m_hair,m_iphon, m_fan,m_tv,m_water)  
        ans_air = k[0] 
        ans_com = k[1] 
        ans_elec = k[2] 
        ans_hair = k[3] 
        ans_iphon = k[4] 
        ans_fan = k[5]
        ans_tv = k[6] 
        ans_water = k[7] 
        k = k[8]
    print "\n"              
    charging_watt = float(0)     
    print "                             -------------------------------------                                                            \n"
      
    while ( h < (len(df_power)/96) ) : 
        print """\n. . . . . . . . . . . . . . . . . . . .END DAY  . . . . . . . . . . . .. . . . . . . . . . . . . . .\n"""
#         print (k*24),"to",(k+1)*24
        sum_p =  df_power[(h*96):((h+1)*96)].sum()
        sum_power.append(sum_p)
        
        sum_pv = sum(pv_consumption[(h*96):((h+1)*96)])
        sum_pvconsumption.append(sum_pv/1000)
        
        sum_batt = sum(batt_consumption[(h*96):((h+1)*96)])
        sum_battconsumption.append(sum_batt/1000)
        
        sum_grid = sum(grid_consumption[(h*96):((h+1)*96)])
        sum_gridconsumption.append(sum_grid/1000)
        
        df_power2 = pd.DataFrame(sum_power)  
        df_power3 = pd.DataFrame(sum_pvconsumption)  
        df_power4 = pd.DataFrame(sum_battconsumption)  
        df_power5 = pd.DataFrame(sum_gridconsumption)           
        result = pd.concat([df_power2, df_power3, df_power4, df_power5], axis=1)
        result.columns = ['power consumption','From PV','From BATTERY','From PEA']
        print result
        print "Power consuming between" ,time_a[h*96], "to" ,time_b[(h+1)*96-1], "equal to", result.iloc[h]['power consumption']," kW. -->> equal to",bill(float(result.iloc[h]['From PEA']),Ft),"bath"
        print """///////////////////////////////////////////////////////////////////////////////////////////////////////////////\n"""
        h +=1 
         
print "-------------YOUR PROGRAM IS DONE-----------------"
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
# Out:
# table thesis.main3rd_25 are Empty!!!
#
# data at : 0
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-11-30 23:59:59' ;
# the minimum MSE of prediction = 0.00708693646772 by alpha = 0.4 beta = 0.9 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 00:14:59'AND Timestamp<='2016-11-30 23:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:14:59' ;
# BY USE alpha = 0.4 beta = 0.9 gamma = 0.7
# predicted watt is  786.195784124 watt ||||| targeted watt at t is  585.795234426 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 329.057
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 329.057
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 329.057 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 42.02 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 00:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'light_system'] = 6 items
# ______________________________________________________________________________________________
#
#
# ______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________
#
#
#                              -------------------------------------
#
# data at : 1
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:14:59' ;
# the minimum MSE of prediction = 28.8495263028 by alpha = 0.0 beta = 0.0 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 00:29:59'AND Timestamp<='2016-12-01 00:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:29:59' ;
# BY USE alpha = 0.0 beta = 0.0 gamma = 0.3
# predicted watt is  284.719493561 watt ||||| targeted watt at t is  212.144768319 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 332.281
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 332.281
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 332.281 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 43.16 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 00:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'light_system'] = 6 items
# ______________________________________________________________________________________________
#
#
# ______________________________ POWER CONSUMPTION IS UNDER LIMIT______________________________
#
#
#                              -------------------------------------
#
# data at : 2
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:29:59' ;
# the minimum MSE of prediction = 0.435588225154 by alpha = 0.7 beta = 0.4 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 00:44:59'AND Timestamp<='2016-12-01 00:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:44:59' ;
# BY USE alpha = 0.7 beta = 0.4 gamma = 0.6
# predicted watt is  234.804423527 watt ||||| targeted watt at t is  174.95300166 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 334.026
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 334.026
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 334.026 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 44.3 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 00:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'light_system'] = 6 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 268.14 m_fan= 0.0 m_tv = 0.0 m_com = 16.2458 m_iphon = 2.4152 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 3
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:44:59' ;
# the minimum MSE of prediction = 0.542277960737 by alpha = 0.6 beta = 0.3 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 00:59:59'AND Timestamp<='2016-12-01 00:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:59:59' ;
# BY USE alpha = 0.6 beta = 0.3 gamma = 0.8
# predicted watt is  260.613713292 watt ||||| targeted watt at t is  194.183528271 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 322.495
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 322.495
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 322.495 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 45.41 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 00:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'computer', 'iphone_charger', 'light_system'] = 6 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 271.39 m_fan= 0.0 m_tv = 0.0 m_com = 15.5248 m_iphon = 2.6845 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 4
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 00:59:59' ;
# the minimum MSE of prediction = 0.187333157252 by alpha = 0.9 beta = 0.9 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 01:14:59'AND Timestamp<='2016-12-01 00:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:14:59' ;
# BY USE alpha = 0.9 beta = 0.9 gamma = 1.0
# predicted watt is  263.298469004 watt ||||| targeted watt at t is  196.183942332 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 287.419
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 287.419
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 287.419 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 46.39 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 01:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont', 'iphone_charger'] = 4 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 273.12 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 2.6741 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 5
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:14:59' ;
# the minimum MSE of prediction = 0.014991362166 by alpha = 0.5 beta = 0.0 gamma = 0.5
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 01:29:59'AND Timestamp<='2016-12-01 01:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:29:59' ;
# BY USE alpha = 0.5 beta = 0.0 gamma = 0.5
# predicted watt is  368.967265858 watt ||||| targeted watt at t is  274.917864435 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 277.324
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 277.324
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 277.324 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 47.34 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 01:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 266.22 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 6
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:29:59' ;
# the minimum MSE of prediction = 0.021952808829 by alpha = 0.6 beta = 0.5 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 01:44:59'AND Timestamp<='2016-12-01 01:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:44:59' ;
# BY USE alpha = 0.6 beta = 0.5 gamma = 0.6
# predicted watt is  174.063904581 watt ||||| targeted watt at t is  129.69518261 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 289.622
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 289.622
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 289.622 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 48.33 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 01:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 274.58 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 7
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:44:59' ;
# the minimum MSE of prediction = 0.465869864478 by alpha = 0.4 beta = 0.0 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 01:59:59'AND Timestamp<='2016-12-01 01:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:59:59' ;
# BY USE alpha = 0.4 beta = 0.0 gamma = 1.0
# predicted watt is  281.386598141 watt ||||| targeted watt at t is  209.661424738 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 287.821
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 287.821
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 287.821 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 49.32 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 01:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 277.5 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 8
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 01:59:59' ;
# the minimum MSE of prediction = 0.0039417904484 by alpha = 0.6 beta = 0.0 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 02:14:59'AND Timestamp<='2016-12-01 01:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:14:59' ;
# BY USE alpha = 0.6 beta = 0.0 gamma = 0.8
# predicted watt is  277.082888037 watt ||||| targeted watt at t is  206.454726203 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 287.301
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 287.301
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 287.301 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 50.3 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 02:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 278.48 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 9
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:14:59' ;
# the minimum MSE of prediction = 0.00824792634379 by alpha = 0.7 beta = 0.7 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 02:29:59'AND Timestamp<='2016-12-01 02:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:29:59' ;
# BY USE alpha = 0.7 beta = 0.7 gamma = 0.6
# predicted watt is  305.182529602 watt ||||| targeted watt at t is  227.391796142 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 277.002
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 277.002
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 277.002 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 51.25 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 02:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 267.41 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 10
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:29:59' ;
# the minimum MSE of prediction = 0.00205191007095 by alpha = 0.6 beta = 0.0 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 02:44:59'AND Timestamp<='2016-12-01 02:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:44:59' ;
# BY USE alpha = 0.6 beta = 0.0 gamma = 0.8
# predicted watt is  266.738630551 watt ||||| targeted watt at t is  198.747210007 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 281.057
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 281.057
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 281.057 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 52.21 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 02:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 265.42 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 11
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:44:59' ;
# the minimum MSE of prediction = 4.2945425408e-05 by alpha = 0.4 beta = 0.1 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 02:59:59'AND Timestamp<='2016-12-01 02:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:59:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.9
# predicted watt is  200.560457815 watt ||||| targeted watt at t is  149.437789893 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 290.478
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 290.478
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 290.478 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 53.21 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 02:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 274.29 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 12
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 02:59:59' ;
# the minimum MSE of prediction = 0.00161579219531 by alpha = 0.9 beta = 0.0 gamma = 0.7
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 03:14:59'AND Timestamp<='2016-12-01 02:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:14:59' ;
# BY USE alpha = 0.9 beta = 0.0 gamma = 0.7
# predicted watt is  299.403630825 watt ||||| targeted watt at t is  223.085933109 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 288.622
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 288.622
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 288.622 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 54.2 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 03:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 274.36 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 13
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:14:59' ;
# the minimum MSE of prediction = 0.00214263848323 by alpha = 0.6 beta = 0.2 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 03:29:59'AND Timestamp<='2016-12-01 03:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:29:59' ;
# BY USE alpha = 0.6 beta = 0.2 gamma = 0.0
# predicted watt is  259.438043795 watt ||||| targeted watt at t is  193.307535798 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 290.823
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 290.823
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 290.823 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 55.19 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 03:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 278.54 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 14
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:29:59' ;
# the minimum MSE of prediction = 0.000413404683782 by alpha = 0.5 beta = 0.8 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 03:44:59'AND Timestamp<='2016-12-01 03:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:44:59' ;
# BY USE alpha = 0.5 beta = 0.8 gamma = 1.0
# predicted watt is  191.67373339 watt ||||| targeted watt at t is  142.816282982 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 280.589
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 280.589
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 280.589 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 56.15 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 03:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 265.31 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 15
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:44:59' ;
# the minimum MSE of prediction = 0.000546737980107 by alpha = 0.8 beta = 0.6 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 03:59:59'AND Timestamp<='2016-12-01 03:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:59:59' ;
# BY USE alpha = 0.8 beta = 0.6 gamma = 0.1
# predicted watt is  301.767423891 watt ||||| targeted watt at t is  224.847197594 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 275.378
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 275.378
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 275.378 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 57.1 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 03:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 264.59 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 16
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 03:59:59' ;
# the minimum MSE of prediction = 0.000387085711826 by alpha = 0.5 beta = 0.0 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 04:14:59'AND Timestamp<='2016-12-01 03:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:14:59' ;
# BY USE alpha = 0.5 beta = 0.0 gamma = 0.2
# predicted watt is  285.893872025 watt ||||| targeted watt at t is  213.019798842 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 286.214
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 286.214
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 286.214 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 58.08 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 04:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 274.16 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 17
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:14:59' ;
# the minimum MSE of prediction = 3.2443177336e-05 by alpha = 0.8 beta = 0.0 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 04:29:59'AND Timestamp<='2016-12-01 04:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:29:59' ;
# BY USE alpha = 0.8 beta = 0.0 gamma = 0.2
# predicted watt is  248.502195499 watt ||||| targeted watt at t is  185.159224722 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 273.605
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 273.605
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 273.605 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 59.01 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 04:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 259.18 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 18
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:29:59' ;
# the minimum MSE of prediction = 5.15637986829e-06 by alpha = 0.4 beta = 0.4 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 04:44:59'AND Timestamp<='2016-12-01 04:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:44:59' ;
# BY USE alpha = 0.4 beta = 0.4 gamma = 0.1
# predicted watt is  267.37391174 watt ||||| targeted watt at t is  199.220558632 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 281.6
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 281.6
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 281.6 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 59.98 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 04:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 271.85 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 19
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:44:59' ;
# the minimum MSE of prediction = 0.000252756157979 by alpha = 0.3 beta = 0.5 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 04:59:59'AND Timestamp<='2016-12-01 04:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:59:59' ;
# BY USE alpha = 0.3 beta = 0.5 gamma = 0.2
# predicted watt is  258.75923508 watt ||||| targeted watt at t is  192.801754773 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 280.467
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 280.467
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 280.467 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 60.94 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 04:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 271.63 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 20
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 04:59:59' ;
# the minimum MSE of prediction = 9.51677264274e-06 by alpha = 0.8 beta = 0.9 gamma = 0.6
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 05:14:59'AND Timestamp<='2016-12-01 04:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:14:59' ;
# BY USE alpha = 0.8 beta = 0.9 gamma = 0.6
# predicted watt is  310.525368297 watt ||||| targeted watt at t is  231.372750389 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 287.285
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 287.285
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 287.285 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 61.92 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 05:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 276.31 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 21
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:14:59' ;
# the minimum MSE of prediction = 8.75248304365e-07 by alpha = 0.8 beta = 0.1 gamma = 0.4
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 05:29:59'AND Timestamp<='2016-12-01 05:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:29:59' ;
# BY USE alpha = 0.8 beta = 0.1 gamma = 0.4
# predicted watt is  292.906702861 watt ||||| targeted watt at t is  218.245065838 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 271.99
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 271.99
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 271.99 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 62.85 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 05:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 256.29 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 22
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:29:59' ;
# the minimum MSE of prediction = 0.0107597685641 by alpha = 0.4 beta = 0.1 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 05:44:59'AND Timestamp<='2016-12-01 05:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:44:59' ;
# BY USE alpha = 0.4 beta = 0.1 gamma = 0.9
# predicted watt is  271.303563859 watt ||||| targeted watt at t is  202.148546203 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 273.216
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 273.216
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 273.216 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 63.79 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 05:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 257.12 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 23
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:44:59' ;
# the minimum MSE of prediction = 0.00313637006553 by alpha = 0.9 beta = 0.1 gamma = 0.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-01 05:59:59'AND Timestamp<='2016-12-01 05:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-01 05:59:59' ;
# BY USE alpha = 0.9 beta = 0.1 gamma = 0.0
# predicted watt is  273.486801381 watt ||||| targeted watt at t is  203.775278579 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 289.642
# PV_CONSUMPTION = 0.0
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 289.642
# PREVIOUS LEVELBATT = 580.0 ||| LEFTED LEVELBATT = 580.0
# PV GENERATION = 0.0 ||| BATT_CHARGING = 0.0
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 289.642 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 64.78 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-01 05:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'aircont'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 276.35 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
# ...
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 10:29:59'AND Timestamp<='2016-12-02 10:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 10:29:59' ;
# BY USE alpha = 0.9 beta = 1.0 gamma = 0.5
# predicted watt is  39.4230147896 watt ||||| targeted watt at t is  29.3741262123 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 31.2625
# PV_CONSUMPTION = 31.2625
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 688.475968 ||| LEFTED LEVELBATT = 724.415968
# PV GENERATION = 68.7 ||| BATT_CHARGING = 35.94
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 10:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 138
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 10:29:59' ;
# the minimum MSE of prediction = 3.27470195768e-05 by alpha = 0.5 beta = 0.4 gamma = 0.9
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 10:44:59'AND Timestamp<='2016-12-02 10:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 10:44:59' ;
# BY USE alpha = 0.5 beta = 0.4 gamma = 0.9
# predicted watt is  30.1617513564 watt ||||| targeted watt at t is  22.4735499265 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 30.3958
# PV_CONSUMPTION = 30.3958
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 724.415968 ||| LEFTED LEVELBATT = 786.436
# PV GENERATION = 95.0 ||| BATT_CHARGING = 62.020032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 10:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 139
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 10:44:59' ;
# the minimum MSE of prediction = 1.94566692264e-05 by alpha = 0.9 beta = 0.5 gamma = 0.8
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 10:59:59'AND Timestamp<='2016-12-02 10:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 10:59:59' ;
# BY USE alpha = 0.9 beta = 0.5 gamma = 0.8
# predicted watt is  32.947572456 watt ||||| targeted watt at t is  24.5492679055 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 32.5083
# PV_CONSUMPTION = 32.5083
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 786.436 ||| LEFTED LEVELBATT = 855.644032
# PV GENERATION = 104.6 ||| BATT_CHARGING = 69.208032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 10:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 140
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 10:59:59' ;
# the minimum MSE of prediction = 7.76414911505e-06 by alpha = 0.9 beta = 0.7 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 11:14:59'AND Timestamp<='2016-12-02 10:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:14:59' ;
# BY USE alpha = 0.9 beta = 0.7 gamma = 0.2
# predicted watt is  43.1808490304 watt ||||| targeted watt at t is  32.1740921172 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 37.2167
# PV_CONSUMPTION = 37.2167
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 855.644032 ||| LEFTED LEVELBATT = 914.476
# PV GENERATION = 98.5 ||| BATT_CHARGING = 58.831968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 11:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 141
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:14:59' ;
# the minimum MSE of prediction = 2.59030793335e-05 by alpha = 0.4 beta = 0.8 gamma = 0.2
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 11:29:59'AND Timestamp<='2016-12-02 11:14:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:29:59' ;
# BY USE alpha = 0.4 beta = 0.8 gamma = 0.2
# predicted watt is  24.1763815405 watt ||||| targeted watt at t is  18.0138451237 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 34.3708
# PV_CONSUMPTION = 34.3708
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 914.476 ||| LEFTED LEVELBATT = 975.080032
# PV GENERATION = 97.5 ||| BATT_CHARGING = 60.604032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 11:29:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router', 'light_system'] = 3 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 142
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:29:59' ;
# the minimum MSE of prediction = 0.000285041430561 by alpha = 0.3 beta = 0.5 gamma = 0.3
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 11:44:59'AND Timestamp<='2016-12-02 11:29:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:44:59' ;
# BY USE alpha = 0.3 beta = 0.5 gamma = 0.3
# predicted watt is  38.139042318 watt ||||| targeted watt at t is  28.4174370896 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 31.1042
# PV_CONSUMPTION = 31.1042
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 975.080032 ||| LEFTED LEVELBATT = 1024.036
# PV GENERATION = 82.1 ||| BATT_CHARGING = 48.955968
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 11:44:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 143
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:44:59' ;
# the minimum MSE of prediction = 9.40907367159e-05 by alpha = 0.3 beta = 0.7 gamma = 0.1
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 11:59:59'AND Timestamp<='2016-12-02 11:44:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:59:59' ;
# BY USE alpha = 0.3 beta = 0.7 gamma = 0.1
# predicted watt is  34.3278704219 watt ||||| targeted watt at t is  25.5777292467 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 31.2833
# PV_CONSUMPTION = 31.2833
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1024.036 ||| LEFTED LEVELBATT = 1084.052032
# PV GENERATION = 93.8 ||| BATT_CHARGING = 60.016032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 11:59:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 144
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 11:59:59' ;
# the minimum MSE of prediction = 0.000120549770434 by alpha = 0.9 beta = 0.9 gamma = 1.0
# ______________________________________________________________________________________________
#
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp>='2016-11-02 12:14:59'AND Timestamp<='2016-12-02 11:59:59';
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 12:14:59' ;
# BY USE alpha = 0.9 beta = 0.9 gamma = 1.0
# predicted watt is  12.0289294176 watt ||||| targeted watt at t is  8.96276687099 watt
# ______________________________________________________________________________________________
#
# Consuming watt = 32.5708
# PV_CONSUMPTION = 32.5708
# BATT_CONSUMPTION = 0.0
# GRID_CONSUMPTION = 0.0
# PREVIOUS LEVELBATT = 1084.052032 ||| LEFTED LEVELBATT = 1145.808064
# PV GENERATION = 96.9 ||| BATT_CHARGING = 61.756032
# ______________________________________________________________________________________________
#
# ||| 15 Minutes Lefted You Consumed power from PEA about 0.0 watt
# ||| NOW YOUR ELECTRICAL BILL IS ABOUT 95.95 bath
# ______________________________________________________________________________________________
#
# Check status of appliances from
# SELECT * FROM thesis.measure_15devices_month3 WHERE  Timestamp = '2016-12-02 12:14:59';
# NOW !! you are turning ON ['refrigerator', 'wireless_router'] = 2 items
# ______________________________________________________________________________________________
#
#
# _____________________________  POWER CONSUMPTION IS OVER LIMIT________________________________
#
#
# m_air = 0.0 m_fan= 0.0 m_tv = 0.0 m_com = 0.0 m_iphon = 0.0 m_elec= 0.0 m_hair= 0.0 m_water = 0.0
#
#
#                              -------------------------------------
#
# data at : 145
# ______________________________________________________________________________________________
# SELECT Timestamp,total_watt FROM thesis.measure3rd_15devices_25 WHERE Timestamp = '2016-12-02 12:14:59' ;

# %%
print "count_active =" ,count_air+count_fan+count_tv+count_com+count_iphon+count_elec+count_hair+count_water
print "control_air-cont (times) ="      , count_air
print "control_fan (times) ="           , count_fan
print "control_tv (times) ="            , count_tv
print "control_computer (times) ="      , count_com
print "control_iphone_charger (times) =", count_iphon
print "control_elec_thermo (times) ="   , count_elec
print "control_hair_dryer (times) ="    , count_hair
print "control_water_heater (times) ="  , count_water
print sum_overpv/1000
