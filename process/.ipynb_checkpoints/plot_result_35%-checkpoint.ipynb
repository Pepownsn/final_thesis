# %% [markdown]
# ## plotting After-process data || 35 percent ||

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
from matplotlib.collections import PolyCollection
from matplotlib.colors import colorConverter
import matplotlib.pyplot as plt
import pandas as pd # v. 1.7
import numpy as np
import MySQLdb
import matplotlib.pyplot as plt
import pandas as pd
import sys
import time
import datetime 
import random
import statistics 
# %matplotlib inline  


"""
unit >> bill
"""

import pandas as pd
import matplotlib.pyplot as plt
import MySQLdb
import time

from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr

# x = raw_input('What about Ft?')
# Ft = float(x)
Ft = -0.048
t1 = 3.2484      # rate_1
t2 = 4.2218      # rate_2
t3 = 4.4217      # rate_3
ser = 38.22      # service_charge
u = symbols('u')

def bill(allpow):    
    ## Fundamental parameter
    if allpow == 0:
        bath = 0
    elif 1 <= allpow <= 150:
        bath = allpow*t1
    elif  151 <= allpow <= 400:
        power = allpow-150
        bath_1 = 150*t1
        bath_2 = power*t2
        bath = bath_1+bath_2
    else:
        power = allpow-150
        bath_1 = 150*t1
        power = power-250
        bath_2 = 250*t2
        bath_3 = power*t3
        bath = bath_1+bath_2+bath_3   
    service_price = 38.22  #permonth (fixed)   
    ## FT -33.2 satang/unit
    FT_price = allpow*Ft
    ## VAT 7%
    VAT_price = ((service_price+bath)+FT_price)*0.07
    bill = bath+service_price+FT_price+VAT_price
    return round(bill,2)

# %% [markdown]
# #### plotting month1 : October

# %%
conn= MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()

time_a = '2016-10-18 00:00:00'
time_b = '2016-10-20 23:59:59'

query= "SELECT Timestamp,old_watt,pv_consumption,batt_consumption,grid_consumption FROM thesis.main1st_35 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a,time_b)
df = pd.read_sql(query, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14*1, 8))
ax.set_title('Power Consumption every 15 minutes(PV 600 W & BATTERY 2.9 KW)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df.plot(ax=ax)
plt.show()

d = 31
time_a = pd.date_range('2016-10-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
print time_a[0],"to",time_b[-1]
query0 = "SELECT * FROM thesis.main1st_35 WHERE Timestamp >= '%s'AND  Timestamp <= '%s'; "% (time_a[0],time_b[-1])
df = pd.read_sql(query0, conn)
print "Total unit consumption || No-algorithm || equal to",df.old_watt.sum()/1000,"kW equal to", bill(df.old_watt.sum()/1000),"bath"
print "Total unit consumption || algorithm + PV&BATT ||equal to",df.watt.sum()/1000,"kW equal to", bill(df.watt.sum()/1000),"bath"
print "Total power consumption from PEA equal to",df.grid_consumption.sum()/1000,"kW equal to", bill(df.grid_consumption.sum()/1000),"bath"
print "Total predicted watt", df.predicted_watt.sum()/1000
print "Total target watt", df.target_watt.sum()/1000
print "Total watt", df.predicted_watt.sum()/1000*(1.0-0.35)
print "Total PV_genaration", df.PV_genarator.sum()/1000
# Out:
# 2016-10-01 00:00:00 to 2016-10-31 23:59:59
# Total unit consumption || No-algorithm || equal to 383.111085 kW equal to 1595.63 bath
# Total unit consumption || algorithm + PV&BATT ||equal to 323.7868703 kW equal to 1330.69 bath
# Total power consumption from PEA equal to 258.95236422 kW equal to 1041.14 bath
# Total predicted watt 358.975675429
# Total target watt 233.417873399
# Total watt 233.334189029
# Total PV_genaration 63.6605821256

# %% [markdown]
# #### plotting month2 : November

# %%
conn= MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()

time_a = '2016-11-18 00:00:00'
time_b = '2016-11-20 23:59:59'

query= "SELECT Timestamp,old_watt,pv_consumption,batt_consumption,grid_consumption FROM thesis.main2nd_35 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a,time_b)
df = pd.read_sql(query, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14*1, 8))
ax.set_title('Power Consumption every 15 minutes(PV 600 W & BATTERY 2.9 KW)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df.plot(ax=ax)
plt.show()

d = 30
time_a = pd.date_range('2016-11-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-11-01 00:14:59', periods=96*d, freq='15T')
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
print time_a[0],"to",time_b[-1]
query0 = "SELECT * FROM thesis.main2nd_35 WHERE Timestamp >= '%s'AND  Timestamp <= '%s'; "% (time_a[0],time_b[-1])
df = pd.read_sql(query0, conn)
print "Total unit consumption || No-algorithm || equal to",df.old_watt.sum()/1000,"kW equal to", bill(df.old_watt.sum()/1000),"bath"
print "Total unit consumption || algorithm + PV&BATT ||equal to",df.watt.sum()/1000,"kW equal to", bill(df.watt.sum()/1000),"bath"
print "Total power consumption from PEA equal to",df.grid_consumption.sum()/1000,"kW equal to", bill(df.grid_consumption.sum()/1000),"bath"
print "Total predicted watt", df.predicted_watt.sum()/1000
print "Total target watt", df.target_watt.sum()/1000
print "Total watt", df.predicted_watt.sum()/1000*(1.0-0.35)
print "Total PV_genaration", df.PV_genarator.sum()/1000
# Out:
# 2016-11-01 00:00:00 to 2016-11-30 23:59:59
# Total unit consumption || No-algorithm || equal to 386.3802557 kW equal to 1610.23 bath
# Total unit consumption || algorithm + PV&BATT ||equal to 308.9417918 kW equal to 1264.39 bath
# Total power consumption from PEA equal to 247.32433784 kW equal to 989.21 bath
# Total predicted watt 339.845870852
# Total target watt 223.634665278
# Total watt 220.899816053
# Total PV_genaration 62.74624179

# %% [markdown]
# #### plotting month3 : DECEMBER

# %%
conn= MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()

time_a = '2016-12-18 00:00:00'
time_b = '2016-12-20 23:59:59'

query= "SELECT Timestamp,old_watt,pv_consumption,batt_consumption,grid_consumption FROM thesis.main3rd_35 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a,time_b)
df = pd.read_sql(query, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14*1, 8))
ax.set_title('Power Consumption every 15 minutes(PV 600 W & BATTERY 2.9 KW)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df.plot(ax=ax)
plt.show()

d = 31
time_a = pd.date_range('2016-12-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2016-12-01 00:14:59', periods=96*d, freq='15T')
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
print time_a[0],"to",time_b[-1]
query0 = "SELECT * FROM thesis.main3rd_35 WHERE Timestamp >= '%s'AND  Timestamp <= '%s'; "% (time_a[0],time_b[-1])
df = pd.read_sql(query0, conn)
print "Total unit consumption || No-algorithm || equal to",df.old_watt.sum()/1000,"kW equal to", bill(df.old_watt.sum()/1000),"bath"
print "Total unit consumption || algorithm + PV&BATT ||equal to",df.watt.sum()/1000,"kW equal to", bill(df.watt.sum()/1000),"bath"
print "Total power consumption from PEA equal to",df.grid_consumption.sum()/1000,"kW equal to", bill(df.grid_consumption.sum()/1000),"bath"
print "Total predicted watt", df.predicted_watt.sum()/1000
print "Total target watt", df.target_watt.sum()/1000
print "Total watt", df.predicted_watt.sum()/1000*(1.0-0.35)
print "Total PV_genaration", df.PV_genarator.sum()/1000
# Out:
# 2016-12-01 00:00:00 to 2016-12-31 23:59:59
# Total unit consumption || No-algorithm || equal to 404.8734149 kW equal to 1693.86 bath
# Total unit consumption || algorithm + PV&BATT ||equal to 328.4575008 kW equal to 1351.54 bath
# Total power consumption from PEA equal to 264.96803111 kW equal to 1068.0 bath
# Total predicted watt 351.577605817
# Total target watt 218.300667422
# Total watt 228.525443781
# Total PV_genaration 64.6891

# %% [markdown]
# #### plotting month4 : JANUARY

# %%
conn= MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()

time_a = '2017-01-18 00:00:00'
time_b = '2017-01-20 23:59:59'

query= "SELECT Timestamp,old_watt,pv_consumption,batt_consumption,grid_consumption FROM thesis.main4th_35 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a,time_b)
df = pd.read_sql(query, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14*1, 8))
ax.set_title('Power Consumption every 15 minutes(PV 600 W & BATTERY 2.9 KW)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df.plot(ax=ax)
plt.show()

d = 31
time_a = pd.date_range('2017-01-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2017-01-01 00:14:59', periods=96*d, freq='15T')
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
print time_a[0],"to",time_b[-1]
query0 = "SELECT * FROM thesis.main4th_35 WHERE Timestamp >= '%s'AND  Timestamp <= '%s'; "% (time_a[0],time_b[-1])
df = pd.read_sql(query0, conn)
print "Total unit consumption || No-algorithm || equal to",df.old_watt.sum()/1000,"kW equal to", bill(df.old_watt.sum()/1000),"bath"
print "Total unit consumption || algorithm + PV&BATT ||equal to",df.watt.sum()/1000,"kW equal to", bill(df.watt.sum()/1000),"bath"
print "Total power consumption from PEA equal to",df.grid_consumption.sum()/1000,"kW equal to", bill(df.grid_consumption.sum()/1000),"bath"
print "Total predicted watt", df.predicted_watt.sum()/1000
print "Total target watt", df.target_watt.sum()/1000
print "Total watt", df.predicted_watt.sum()/1000*(1.0-0.35)
print "Total PV_genaration", df.PV_genarator.sum()/1000

# %% [markdown]
# #### plotting month5 : FEBRUAY

# %%
conn= MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()

time_a = '2017-02-18 00:00:00'
time_b = '2017-02-20 23:59:59'

query= "SELECT Timestamp,old_watt,pv_consumption,batt_consumption,grid_consumption FROM thesis.main5th_35 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a,time_b)
df = pd.read_sql(query, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14*1, 8))
ax.set_title('Power Consumption every 15 minutes(PV 600 W & BATTERY 2.9 KW)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df.plot(ax=ax)
plt.show()

d = 28
time_a = pd.date_range('2017-02-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2017-02-01 00:14:59', periods=96*d, freq='15T')
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
print time_a[0],"to",time_b[-1]
query0 = "SELECT * FROM thesis.main5th_35 WHERE Timestamp >= '%s'AND  Timestamp <= '%s'; "% (time_a[0],time_b[-1])
df = pd.read_sql(query0, conn)
print "Total unit consumption || No-algorithm || equal to",df.old_watt.sum()/1000,"kW equal to", bill(df.old_watt.sum()/1000),"bath"
print "Total unit consumption || algorithm + PV&BATT ||equal to",df.watt.sum()/1000,"kW equal to", bill(df.watt.sum()/1000),"bath"
print "Total power consumption from PEA equal to",df.grid_consumption.sum()/1000,"kW equal to", bill(df.grid_consumption.sum()/1000),"bath"
print "Total predicted watt", df.predicted_watt.sum()/1000
print "Total target watt", df.target_watt.sum()/1000
print "Total watt", df.predicted_watt.sum()/1000*(1.0-0.35)
print "Total PV_genaration", df.PV_genarator.sum()/1000

# %% [markdown]
# #### plotting month6 : MARCH

# %%
conn= MySQLdb.connect("localhost","conn","hems")
cursor = conn.cursor()

time_a = '2017-03-18 00:00:00'
time_b = '2017-03-20 23:59:59'

query= "SELECT Timestamp,old_watt,pv_consumption,batt_consumption,grid_consumption FROM thesis.main6th_35 WHERE Timestamp >= '%s'   AND Timestamp <= '%s'; " % (time_a,time_b)
df = pd.read_sql(query, conn,index_col=['Timestamp'])
fig, ax = plt.subplots(figsize=(14*1, 8))
ax.set_title('Power Consumption every 15 minutes(PV 600 W & BATTERY 2.9 KW)', fontsize=14)
plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('power(watt)', fontsize=14)
df.plot(ax=ax)
plt.show()

d = 31
time_a = pd.date_range('2017-03-01 00:00:00', periods=96*d, freq='15T')
time_b = pd.date_range('2017-03-01 00:14:59', periods=96*d, freq='15T')
conn = MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()
print time_a[0],"to",time_b[-1]
query0 = "SELECT * FROM thesis.main6th_35 WHERE Timestamp >= '%s'AND Timestamp <= '%s'; "% (time_a[0],time_b[-1])
df = pd.read_sql(query0, conn)
print "Total unit consumption || No-algorithm || equal to",df.old_watt.sum()/1000,"kW equal to", bill(df.old_watt.sum()/1000),"bath"
print "Total unit consumption || algorithm + PV&BATT ||equal to",df.watt.sum()/1000,"kW equal to", bill(df.watt.sum()/1000),"bath"
print "Total power consumption from PEA equal to",df.grid_consumption.sum()/1000,"kW equal to", bill(df.grid_consumption.sum()/1000),"bath"
print "Total predicted watt", df.predicted_watt.sum()/1000
print "Total target watt", df.target_watt.sum()/1000
print "Total watt", df.predicted_watt.sum()/1000*(1.0-0.35)
print "Total PV_genaration", df.PV_genarator.sum()/1000
