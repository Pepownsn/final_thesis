# %%
'''

การสร้างข้อมูลใน Database watt 15 mins
     --  รายอุปกรณ์  15 ชิ้น --
         

'''

import pandas as pd
import matplotlib.pyplot as plt
import MySQLdb
import time
from sympy import *
from sympy.solvers import solve
from sympy.parsing.sympy_parser import parse_expr

# Set parameters
j = 0
d = 182 #Day

# CONNECT TO MYSQL
conn= MySQLdb.connect("localhost","conn","hems")
c = conn.cursor()

# set table thesis.measure_15devices to empty 
# query_empty = """truncate table thesis.load""" 
# c.execute(query_empty)
# print " table thesis.load are Empty!!! \n"

# set 15 mins periods 
time_a = pd.date_range('2016-10-01', periods=96*d, freq='15T')
time_b = pd.date_range('2016-10-01 00:14:59', periods=96*d, freq='15T')

while (j <= (96*d)-1):
    
    if (j >= 0 and j <= 2975):
        query = "SELECT * FROM thesis.measure_15devices_month1 WHERE Timestamp >= '%s' AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
        df = pd.read_sql(query, conn)   
        c.execute("INSERT INTO thesis.load (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger, fan, tv, washing_machine, iron, rice_cooker, water_heater, light_system,total_watt) VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                  (time_b[j],df.refrigerator[0],df.wirelessrouter[0],df.aircont[0],df.computer[0],df.elec_thermo[0],df.hair_dryer[0],df.microwave[0],df.iphonecharger[0],df.fan[0],df.tv[0],df.washing_machine[0],df.iron[0],df.rice_cooker[0],df.water_heater[0],df.light_system[0],df.total_watt[0]))
        conn.commit() 
        
    elif (j >= 2976 and j<=5855):
        query = "SELECT * FROM thesis.measure_15devices_month2 WHERE Timestamp >= '%s' AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
        df = pd.read_sql(query, conn)   
        c.execute("INSERT INTO thesis.load (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger, fan, tv, washing_machine, iron, rice_cooker, water_heater, light_system,total_watt) VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                  (time_b[j],df.refrigerator[0],df.wirelessrouter[0],df.aircont[0],df.computer[0],df.elec_thermo[0],df.hair_dryer[0],df.microwave[0],df.iphonecharger[0],df.fan[0],df.tv[0],df.washing_machine[0],df.iron[0],df.rice_cooker[0],df.water_heater[0],df.light_system[0],df.total_watt[0]))         
        conn.commit() 
        
    elif (j >= 5856 and j<=8831):
        query = "SELECT * FROM thesis.measure_15devices_month3 WHERE Timestamp >= '%s' AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
        df = pd.read_sql(query, conn)   
        c.execute("INSERT INTO thesis.load (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger, fan, tv, washing_machine, iron, rice_cooker, water_heater, light_system,total_watt) VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                  (time_b[j],df.refrigerator[0],df.wirelessrouter[0],df.aircont[0],df.computer[0],df.elec_thermo[0],df.hair_dryer[0],df.microwave[0],df.iphonecharger[0],df.fan[0],df.tv[0],df.washing_machine[0],df.iron[0],df.rice_cooker[0],df.water_heater[0],df.light_system[0],df.total_watt[0]))         
        conn.commit() 
        
    elif (j >= 8832 and j<=11807):   
        query = "SELECT * FROM thesis.measure_15devices_month4 WHERE Timestamp >= '%s' AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
        df = pd.read_sql(query, conn)   
        c.execute("INSERT INTO thesis.load (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger, fan, tv, washing_machine, iron, rice_cooker, water_heater, light_system,total_watt) VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                  (time_b[j],df.refrigerator[0],df.wirelessrouter[0],df.aircont[0],df.computer[0],df.elec_thermo[0],df.hair_dryer[0],df.microwave[0],df.iphonecharger[0],df.fan[0],df.tv[0],df.washing_machine[0],df.iron[0],df.rice_cooker[0],df.water_heater[0],df.light_system[0],df.total_watt[0]))         
        conn.commit() 
        
    elif (j >= 11808 and j<= 14495):
        query = "SELECT * FROM thesis.measure_15devices_month5 WHERE Timestamp >= '%s' AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
        df = pd.read_sql(query, conn)   
        c.execute("INSERT INTO thesis.load (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger, fan, tv, washing_machine, iron, rice_cooker, water_heater, light_system,total_watt) VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                  (time_b[j],df.refrigerator[0],df.wirelessrouter[0],df.aircont[0],df.computer[0],df.elec_thermo[0],df.hair_dryer[0],df.microwave[0],df.iphonecharger[0],df.fan[0],df.tv[0],df.washing_machine[0],df.iron[0],df.rice_cooker[0],df.water_heater[0],df.light_system[0],df.total_watt[0]))         
        conn.commit()
        
    else:
        query = "SELECT * FROM thesis.measure_15devices_month6 WHERE Timestamp >= '%s' AND TimeStamp <= '%s'; "% (time_a[j],time_b[j])
        df = pd.read_sql(query, conn)   
        c.execute("INSERT INTO thesis.load (Timestamp, refrigerator, wirelessrouter, aircont, computer, elec_thermo, hair_dryer, microwave, iphonecharger, fan, tv, washing_machine, iron, rice_cooker, water_heater, light_system,total_watt) VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
                  (time_b[j],df.refrigerator[0],df.wirelessrouter[0],df.aircont[0],df.computer[0],df.elec_thermo[0],df.hair_dryer[0],df.microwave[0],df.iphonecharger[0],df.fan[0],df.tv[0],df.washing_machine[0],df.iron[0],df.rice_cooker[0],df.water_heater[0],df.light_system[0],df.total_watt[0]))         
        conn.commit()
        
    j += 1  
    print ".",
print(".DONE!")
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 
# ...
